# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '3000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 3044

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 4000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'phát thanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt tiền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ách tắc': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'có ích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đích thân': ["category7: 'Đại từ'"]
# --------------------
# Results for 'giảm sút': ["category2: 'Động từ'"]
# --------------------
# Results for 'tên miền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sai trái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'không phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhược điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngập úng': ["category2: 'Động từ'"]
# --------------------
# Results for 'giận dữ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sóng thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trục lợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa phương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cướp giật': ["category2: 'Động từ'"]
# --------------------
# Results for 'cộng sự': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phim ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ưu tú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thâm hụt': ["category2: 'Động từ'"]
# --------------------
# Results for 'lập luận': []
# --------------------
# Results for 'gián điệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường dẫn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xấu xí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tồn đọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghị sỹ': []
# --------------------
# Results for 'băng nhóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thẻ vàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'chống đối': ["category2: 'Động từ'"]
# --------------------
# Results for 'điện lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạm đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đến cùng': []
# --------------------
# Results for 'bộc bạch': ["category2: 'Động từ'"]
# --------------------
# Results for 'vấn nạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhàm chán': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thế mà': []
# --------------------
# Results for 'suôn sẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hảo tâm': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tối qua': []
# --------------------
# Results for 'phần trăm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mãnh liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nội trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàng trữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường băng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm chứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'liên hoan': []
# --------------------
# Results for 'luân chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà vườn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triều đình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sở trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiềm lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'do thám': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách ly': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ai nấy': ["category7: 'Đại từ'"]
# --------------------
# Results for 'đánh cá': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lập nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạm trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'chia cắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử thi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hấp thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngậm ngùi': ["category2: 'Động từ'"]
# --------------------
# Results for 'kín đáo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đề kháng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hôi thối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bất hạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỷ cương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đâu đó': ["category7: 'Đại từ'"]
# --------------------
# Results for 'vũ công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bàn thờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sai lệch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tham vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'vũ lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bi kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sở tại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghèo khó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bộ ngành': []
# --------------------
# Results for 'thanh long': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đèn đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao thừa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghị lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cổ vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thụ lý': ["category2: 'Động từ'"]
# --------------------
# Results for 'liệt kê': ["category2: 'Động từ'"]
# --------------------
# Results for 'án mạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát minh': []
# --------------------
# Results for 'hết lòng': []
# --------------------
# Results for 'bật mí': ["category2: 'Động từ'"]
# --------------------
# Results for 'như thể': []
# --------------------
# Results for 'hung khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'số đo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cụm từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'như ý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sung sướng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trúng thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tin vui': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ít ỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhìn chung': []
# --------------------
# Results for 'tắc nghẽn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'xáo trộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bổ ích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải thể': ["category2: 'Động từ'"]
# --------------------
# Results for 'giáp ranh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bế mạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'lớn lao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tẩy chay': ["category2: 'Động từ'"]
# --------------------
# Results for 'linh hồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chán nản': []
# --------------------
# Results for 'tan vỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá độ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiệp ước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'nửa đêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự vệ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'dân quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làn đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẩm vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ác liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lớn nhỏ': []
# --------------------
# Results for 'tuyên án': ["category2: 'Động từ'"]
# --------------------
# Results for 'chọn lọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'trông chờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'âm đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'y tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tập tin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'dương xỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên sâu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tra tấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'anh đào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều phối': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tương thích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tai biến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bối rối': []
# --------------------
# Results for 'đột nhiên': []
# --------------------
# Results for 'chăm chút': ["category2: 'Động từ'"]
# --------------------
# Results for 'truyền thuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trốn thuế': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà xe': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cờ bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ông bầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trọng trách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thâm nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'tinh dầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hưng phấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'biển báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trích dẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cãi vã': ["category2: 'Động từ'"]
# --------------------
# Results for 'bỏ cuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi sáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sáng chế': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tình nghi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ý đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bằng cấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyệt vọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'triệt phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập học': ["category2: 'Động từ'"]
# --------------------
# Results for 'sàng lọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tác nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội các': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xô xát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hôn mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'cư xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành thị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiêm minh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuyển dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ quản': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu vực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa hoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dứt khoát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà vua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sân khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kích cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tán thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên hạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bàn ghế': []
# --------------------
# Results for 'sinh lý': []
# --------------------
# Results for 'sinh trưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thú nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dịch chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ mặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp nối': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoảng sợ': []
# --------------------
# Results for 'truyện tranh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nam sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từng trải': []
# --------------------
# Results for 'trùng tu': ["category2: 'Động từ'"]
# --------------------
# Results for 'công du': ["category2: 'Động từ'"]
# --------------------
# Results for 'cột sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'y khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'an tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trước tiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vỏn vẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ấn phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đặc khu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn kiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thổ lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nổi loạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'biến cố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tưng bừng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cay đắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phương diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cộng tác': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời khắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiêu lưu': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đặt cọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỹ càng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lấp lánh': []
# --------------------
# Results for 'chủng tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'neo đậu': []
# --------------------
# Results for 'chân tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng bọn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quan tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạc cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân huỷ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sa sút': ["category2: 'Động từ'"]
# --------------------
# Results for 'truyền đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'vượt bậc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thần thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trại giam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nợ nần': []
# --------------------
# Results for 'sắc sảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mũi nhọn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dẫn chứng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ấp ủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ly dị': ["category2: 'Động từ'"]
# --------------------
# Results for 'choáng váng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thứ bảy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường nét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gửi gắm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời cơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khôn ngoan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoa văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả thuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gánh chịu': ["category2: 'Động từ'"]
# --------------------
# Results for 'vũ đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối chiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội tạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngắn gọn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sao chép': ["category2: 'Động từ'"]
# --------------------
# Results for 'thủ khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải độc': ["category2: 'Động từ'"]
# --------------------
# Results for 'khởi xướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyển thể': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân chúng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứa đựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tất bật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'côn đồ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'điều dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thâu tóm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nòng cốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực kì': []
# --------------------
# Results for 'lộn xộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhân khẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng rổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời sự': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bộ cánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngư lôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ưng ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'tay trái': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'giải tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'ng th': []
# --------------------
# Results for 'nhân tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cách chức': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngây thơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thứ hạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạm ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tập quán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quái vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bứt phá': []
# --------------------
# Results for 'đăng kiểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tố giác': ["category2: 'Động từ'"]
# --------------------
# Results for 'đưa đón': ["category2: 'Động từ'"]
# --------------------
# Results for 'trong lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hạn hán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dĩ nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thi cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'đổ nát': []
# --------------------
# Results for 'tuần lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhất quán': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lập trình': ["category2: 'Động từ'"]
# --------------------
# Results for 'sư đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sầu riêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân cận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giết hại': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước tiểu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chế tác': ["category2: 'Động từ'"]
# --------------------
# Results for 'uy hiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất an': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vòng quanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiết giáp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tranh giành': ["category2: 'Động từ'"]
# --------------------
# Results for 'loay hoay': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghi án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trấn an': ["category2: 'Động từ'"]
# --------------------
# Results for 'chắc hẳn': []
# --------------------
# Results for 'buồn bã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'điều chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'trưởng đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thảm sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'sữa tươi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiên cường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia cố': ["category2: 'Động từ'"]
# --------------------
# Results for 'tái diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'phủ sóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản nhạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chỗ đứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây cối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'táo bón': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ghế ngồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buồn nôn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xây lắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'thăng trầm': []
# --------------------
# Results for 'áp thuế': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn cắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến hạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đèn pha': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghi điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đỉnh điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoẻ khoắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nổi trội': []
# --------------------
# Results for 'tái phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngon miệng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tự lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'bưu điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghẹn ngào': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hay biết': ["category2: 'Động từ'"]
# --------------------
# Results for 'cải tổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đu đủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chật vật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoá trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'né tránh': ["category2: 'Động từ'"]
# --------------------
# Results for 'một mặt': []
# --------------------
# Results for 'ăn học': ["category2: 'Động từ'"]
# --------------------
# Results for 'phải chi': []
# --------------------
# Results for 'chửi bới': ["category2: 'Động từ'"]
# --------------------
# Results for 'tinh bột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh giản': ["category2: 'Động từ'"]
# --------------------
# Results for 'tẩu thoát': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự quản': ["category2: 'Động từ'"]
# --------------------
# Results for 'đàng hoàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cảm thông': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngắn ngủi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'san lấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'thứ sáu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thờ ơ': []
# --------------------
# Results for 'ấm cúng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bừa bãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'qua mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo hiệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'rượu vang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thầy thuốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tần số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'qui định': []
# --------------------
# Results for 'mẫu mã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần hoàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà xưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáp án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô vàn': []
# --------------------
# Results for 'hiến pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị phi': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'yên tĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nô lệ': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'một chiều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giữ chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'bong bóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội đô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khiếu kiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'tận tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuyệt chủng': ["category2: 'Động từ'"]
# --------------------
# Results for 'am hiểu': ["category2: 'Động từ'"]
# --------------------
# Results for 'sông nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'dây điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hải ngoại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kĩ thuật': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phức hợp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tin học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền sử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân ái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thân quen': []
# --------------------
# Results for 'bỗng nhiên': []
# --------------------
# Results for 'phụ trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu xếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại chúng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tàu hoả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thâm niên': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phúc lợi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lẽ ra': []
# --------------------
# Results for 'lồng ghép': ["category2: 'Động từ'"]
# --------------------
# Results for 'trấn áp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nấu nướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự giác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tay lái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người hùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiện toàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đổ xô': ["category2: 'Động từ'"]
# --------------------
# Results for 'ban công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thám hiểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng hương': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lôi cuốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉnh trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất tỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chê bai': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngổn ngang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biểu cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ám chỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khẩu trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trang trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thảo dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lớn mạnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tờ trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'loài người': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con trẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoang sơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưu động': ["category2: 'Động từ'"]
# --------------------
# Results for 'định dạng': []
# --------------------
# Results for 'binh sỹ': []
# --------------------
# Results for 'chuyển tiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'xấu số': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dương vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỷ nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rạn nứt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổng đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh thiêng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vòng tròn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô tội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cuồng nhiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'danh thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoai lang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát xít': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thân thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tang lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hữu hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhảy múa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đoàn tụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi tắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật lộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tai tiếng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dị tật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phê phán': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông quan': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ gia': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phi cơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuật ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chúng em': []
# --------------------
# Results for 'dương tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngập tràn': ["category2: 'Động từ'"]
# --------------------
# Results for 'liều lĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vui lòng': []
# --------------------
# Results for 'quốc dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hay là': []
# --------------------
# Results for 'giao ban': ["category2: 'Động từ'"]
# --------------------
# Results for 'cung điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gương mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu chữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'bổ dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mịn màng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'áp thấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà hợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiệu năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bố con': []
# --------------------
# Results for 'bền bỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sàn diễn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chôn cất': ["category2: 'Động từ'"]
# --------------------
# Results for 'vài ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yêu sách': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vô hình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nguyên bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'núi rừng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thường kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'con bé': []
# --------------------
# Results for 'sách vở': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'kỳ cựu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tê liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tôn tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuỳ tiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thơ mộng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đo lường': ["category2: 'Động từ'"]
# --------------------
# Results for 'tư thục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nước lớn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đo đạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội soi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô sinh': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bán trú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập ngũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đăng nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'đôi lúc': []
# --------------------
# Results for 'sắc lệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giống hệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nở rộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường đua': []
# --------------------
# Results for 'mặc định': ["category2: 'Động từ'"]
# --------------------
# Results for 'mộc mạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình như': []
# --------------------
# Results for 'cưỡng hiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cai trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'dạ hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh mạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàu bay': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mênh mông': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cạn kiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'sát sao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tỉ phú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt chước': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhất quyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'khét tiếng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đi sâu': ["category2: 'Động từ'"]
# --------------------
# Results for 'kinh khủng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe cộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trai trẻ': []
# --------------------
# Results for 'sơ kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'đơn thân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biên kịch': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nội lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh nghĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý báu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lừa dối': ["category2: 'Động từ'"]
# --------------------
# Results for 'phát điện': ["category2: 'Động từ'"]
# --------------------
# Results for 'xà phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khác nào': []
# --------------------
# Results for 'biến hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'than thở': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiện chí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trọng tải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tầm cỡ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc nổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháo binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dụ dỗ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bị động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh kẹo': []
# --------------------
# Results for 'ứng cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'một triệu': []
# --------------------
# Results for 'súng máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại hối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mong mỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'phổ cập': ["category2: 'Động từ'"]
# --------------------
# Results for 'hải đảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ lưu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lừng danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhanh nhẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hùng vĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngũ cốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao ốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồ sộ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nồng nhiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tình tứ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'số hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'chứng bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dang dở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dậy thì': []
# --------------------
# Results for 'súng trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sát cánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'trắng tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vui nhộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ký hiệu': []
# --------------------
# Results for 'võ sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hệ quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tò vò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương yêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đẹp đẽ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chồng chéo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cản phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường quay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bệ phóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ nợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân định': ["category2: 'Động từ'"]
# --------------------
# Results for 'tìm tòi': []
# --------------------
# Results for 'khác thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắp đặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cha ông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bức xạ': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'thuế quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiễm bệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tối tân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giường bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản xạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiếm giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cứu thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoà tan': ["category2: 'Động từ'"]
# --------------------
# Results for 'phạt đền': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trọng thương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'địa ốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính thống': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buồng trứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phim trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác mộng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá khích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lạ mặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cám ơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'quý vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội ngộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'gây dựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dàn xếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vi rút': []
# --------------------
# Results for 'nhiễm độc': ["category2: 'Động từ'"]
# --------------------
# Results for 'định mệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ti vi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỏ tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'hi sinh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thời thượng': []
# --------------------
# Results for 'truyện ngắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ giới': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'sau cùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lẩn trốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bao bọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mỹ quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thường lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phù thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nam tính': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ngành hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên hợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'học kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trau dồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuống nước': ["category2: 'Động từ'"]
# --------------------
# Results for 'kĩ năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'án treo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cổ kính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tổng lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gian nan': []
# --------------------
# Results for 'liên tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất chính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà bếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trình chiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'hối thúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩu đả': ["category2: 'Động từ'"]
# --------------------
# Results for 'phóng sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truy xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'mong ước': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'điện đàm': ["category2: 'Động từ'"]
# --------------------
# Results for 'la hét': ["category2: 'Động từ'"]
# --------------------
# Results for 'trọng đại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'liên hoàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máy bơm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồ án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'niên đại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghen tuông': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhãn mác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kế nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'chống chọi': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chậm chạp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giày dép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ông già': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trầm trồ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dạy dỗ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lịch lãm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sức lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hốt hoảng': []
# --------------------
# Results for 'thất thu': ["category2: 'Động từ'"]
# --------------------
# ...
# --------------------
# Results for 'cấp điện': []
# --------------------
# Results for 'ba lô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoái hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'đôi chút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đau nhức': []
# --------------------
# Results for 'bé nhỏ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiêu hao': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'thù lao': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vỗ tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoành hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm sàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiện cảm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biến áp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'địa vị': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'niêm phong': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp quản': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiệp sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo kê': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hoá giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá voi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân khối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vui tươi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tội lỗi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chồng con': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu vắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiệt sức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải nghệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khiêu dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biết đâu': []
# --------------------
# Results for 'rào chắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'pháp y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mày râu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân váy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khó lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ng tr': []
# --------------------
# Results for 'đặc hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hội hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'che chắn': ["category2: 'Động từ'"]
# --------------------
# Results for 'viễn cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại chiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng tối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu độc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'giải thoát': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triệu hồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực thụ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bưu chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấu thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'công lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mờ nhạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công lao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dưa chuột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lấy làm': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoàng hậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh ghen': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông suốt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thường vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổ ấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát âm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thăm quan': []
# --------------------
# Results for 'liệu pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ thuật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ép buộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'hào quang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'có hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quốc nội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả vờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ốm đau': []
# --------------------
# Results for 'đế chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rung động': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tra cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bóng bàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân chính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ưu việt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thượng nguồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi thoảng': []
# --------------------
# Results for 'cương quyết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nặng ký': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mỹ nghệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thái quá': []
# --------------------
# Results for 'sở dĩ': []
# --------------------
# Results for 'an táng': ["category2: 'Động từ'"]
# --------------------
# Results for 'áp suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dồn dập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cán sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng tài': []
# --------------------
# Results for 'cầu lông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'châu Mỹ': []
# --------------------
# Results for 'làm quà': ["category2: 'Động từ'"]
# --------------------
# Results for 'di dân': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hành tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ tuổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chứng thực': []
# --------------------
# Results for 'nước ngầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải mã': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuẩn xác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuyên dương': ["category2: 'Động từ'"]
# --------------------
# Results for 'xoa dịu': ["category2: 'Động từ'"]
# --------------------
# Results for 'co giật': ["category2: 'Động từ'"]
# --------------------
# Results for 'truyền nhiễm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'đế quốc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'sơ hở': []
# --------------------
# Results for 'nhắn nhủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hôn lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biên độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pha trộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tài hoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghiêm cấm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường ray': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo toàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếng vang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công tố': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung niên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cảm tình': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'toà soạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tam giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi pháp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên lớp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cũ kỹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên xuống': []
# --------------------
# Results for 'thần kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thăng tiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'quý tộc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phân tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham chiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bao cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoá thạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình an': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buông lỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'triệu phú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'can đảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'toàn vẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khiển trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'bão hoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lạ mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tái thiết': ["category2: 'Động từ'"]
# --------------------
# Results for 'rảnh rỗi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trung đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phớt lờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh thức': ["category2: 'Động từ'"]
# --------------------
# Results for 'sống còn': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trắc nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'biết điều': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đậu nành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo âu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguỵ trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'ảm đạm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'túi tiền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhật ký': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đi nữa': []
# --------------------
# Results for 'cần sa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ giúp': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt khác': []
# --------------------
# Results for 'chiếm lĩnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'song sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rộn ràng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xung phong': ["category2: 'Động từ'"]
# --------------------
# Results for 'khiếm khuyết': []
# --------------------
# Results for 'nhập cuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp giáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cất giấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên dùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lăng mộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tu bổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân thật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiếm dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lối thoát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạn mức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng suốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bốc lửa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ổ cứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khảo cổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pha chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'á quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trứng cá': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tạp hoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'săn đón': ["category2: 'Động từ'"]
# --------------------
# Results for 'đột kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'thở dài': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồ tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mùi vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lý lịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triều cường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năm xưa': []
# --------------------
# Results for 'nhấn chìm': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉn chu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'da màu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh xảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tống tiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'đeo bám': ["category2: 'Động từ'"]
# --------------------
# Results for 'sâu bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạt tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tươi đẹp': []
# --------------------
# Results for 'lãnh tụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuyết trình': ["category2: 'Động từ'"]
# --------------------
# Results for 'bỏ túi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đan xen': ["category2: 'Động từ'"]
# --------------------
# Results for 'tê giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thảm khốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thân mềm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'luân phiên': ["category2: 'Động từ'"]
# --------------------
# Results for 'thôi việc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đắc lực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm khó': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành quyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'đính hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đúng mức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả định': []
# --------------------
# Results for 'mơ hồ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hưởng thụ': ["category2: 'Động từ'"]
# --------------------
# Final results have been saved to 3000word.json
