# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '10000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 11234

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 11948):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'phối cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiên liệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'cô đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trần truồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'can trường': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'rì rào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vắn tắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'văn võ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lấm tấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ruy băng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuỷ nông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'y nguyên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'báo danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'số nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô thường': []
# --------------------
# Results for 'nguyện cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'mềm lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa nghi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đan lát': ["category2: 'Động từ'"]
# --------------------
# Results for 'tủm tỉm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghĩa bóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoả thiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nửa chừng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi lê': []
# --------------------
# Results for 'hằng số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buồn buồn': []
# --------------------
# Results for 'sính lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vùi đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'huyết quản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sung công': ["category2: 'Động từ'"]
# --------------------
# Results for 'rái cá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phẳng lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gậy gộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bưng bít': ["category2: 'Động từ'"]
# --------------------
# Results for 'vượt khung': []
# --------------------
# Results for 'tíu tít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phục chức': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhọn hoắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'áp chảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'ru ngủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'điên dại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kinh kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghi hoặc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đóng thùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'luân hồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vĩ nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên quán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngang tàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tống cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phật lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phá lưới': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra rìa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành tung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'loá mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'ở trần': ["category2: 'Động từ'"]
# --------------------
# Results for 'tính nết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần th': []
# --------------------
# Results for 'dị biệt': []
# --------------------
# Results for 'nghi kỵ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắt nghĩa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đo ván': ["category2: 'Động từ'"]
# --------------------
# Results for 'anh tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vả lại': []
# --------------------
# Results for 'đèn sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bằng vai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn cướp': ["category2: 'Động từ'"]
# --------------------
# Results for 'con rơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kim khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phấn rôm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp báo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm vang': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đông dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm phản': ["category2: 'Động từ'"]
# --------------------
# Results for 'vận hạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dẫn điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'trong ngoài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc chiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cõi âm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sân si': []
# --------------------
# Results for 'bức bách': ["category2: 'Động từ'"]
# --------------------
# Results for 'sần sật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trêu ngươi': ["category2: 'Động từ'"]
# --------------------
# Results for 'bùi của': []
# --------------------
# Results for 'phân ly': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại khái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thủ hoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'vòng vèo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nh trọng': []
# --------------------
# Results for 'y lệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tảo tần': ["category2: 'Động từ'"]
# --------------------
# Results for 'vương quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dã tâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lương tri': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca bin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo đức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thư tín': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiều tà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cổ xuý': ["category2: 'Động từ'"]
# --------------------
# Results for 'đi tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'rung cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuống thang': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'diễn từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giãy giụa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nheo nhóc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiểm thử': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường tròn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá bán': []
# --------------------
# Results for 'tướng mạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hài nhi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại phu': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sinh học': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tuỳ viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phóng uế': ["category2: 'Động từ'"]
# --------------------
# Results for 'vận khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thái bình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nội tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thám sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội quán': []
# --------------------
# Results for 'âm sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bắt bớ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên phú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấu sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giữ ghế': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắt bẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'u hũ': []
# --------------------
# Results for 'lỗ vốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'điện dung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ gõ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vẫy vùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sóng radio': ["category1: 'Danh từ'"]
# --------------------
# Results for 'long đong': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn làm': []
# --------------------
# Results for 'mềm yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mùn cưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyên náo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vỏ não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kì cựu': []
# --------------------
# Results for 'iên tiết': []
# --------------------
# Results for 'vù vù': []
# --------------------
# Results for 'một bề': []
# --------------------
# Results for 'siêu trường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác độc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải dương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thùng thình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngô đồng': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cai ngục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên quyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'bi tráng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầm tù': ["category2: 'Động từ'"]
# --------------------
# Results for 'nằm vùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu gió': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân doanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trĩu nặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giầy dép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lồng kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giục giã': ["category2: 'Động từ'"]
# --------------------
# Results for 'quạt gió': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ganh ghét': ["category2: 'Động từ'"]
# --------------------
# Results for 'âm tiết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ nhục': ["category2: 'Động từ'"]
# --------------------
# Results for 'cư xá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'loạn luân': ["category2: 'Động từ'"]
# --------------------
# Results for 'túc xá': []
# --------------------
# Results for 'văn đàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'số lẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạt mạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'suy tàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đè nén': ["category2: 'Động từ'"]
# --------------------
# Results for 'mũ nồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vãn hồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vi sóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đâm đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đu quay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cánh sen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiền ngẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường hoàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sứ thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gây chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'rón rén': []
# --------------------
# Results for 'niệu quản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'than bùn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân lân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hân hạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tử tuất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sán dây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuân vác': ["category2: 'Động từ'"]
# --------------------
# Results for 'diếp cá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rầm rầm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sương khói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tướng sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chắn bùn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy đồi': []
# --------------------
# Results for 'se se': []
# --------------------
# Results for 'u lo': []
# --------------------
# Results for 'mắm muối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đen sì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thách cưới': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiêu căng': []
# --------------------
# Results for 'số là': []
# --------------------
# Results for 'chủ nghĩ': []
# --------------------
# Results for 'đá hộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghệ sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chạy chọt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhỏ thó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh đu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyển lựa': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hát xoan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôn hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sa khoáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xào nấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lơ đãng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khuyên giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'dũng sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát xạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền sảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đói khổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhạc đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tử biển': []
# --------------------
# Results for 'tù túng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dự cảm': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nước xốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khỉ đột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngứa mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tướng cướp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tranh đua': ["category2: 'Động từ'"]
# --------------------
# Results for 'quyến luyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'đài thọ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dừa xiêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khôi ngô': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầu viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'mộng du': ["category2: 'Động từ'"]
# --------------------
# Results for 'sặc mùi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khoan khoái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'im ỉm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chơi chữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khu trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưu toan': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giáo đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô vị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mùa hè': []
# --------------------
# Results for 'phục viên': ["category2: 'Động từ'"]
# --------------------
# Results for 'tăng gia': ["category2: 'Động từ'"]
# --------------------
# Results for 'lực lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng hiện': []
# --------------------
# Results for 'tăm tắp': []
# --------------------
# Results for 'giày vò': ["category2: 'Động từ'"]
# --------------------
# Results for 'xay gió': []
# --------------------
# Results for 'nóng mắt': []
# --------------------
# Results for 'thuyền bè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngó nghiêng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh đạm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh tẻ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chữ thập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trầy trật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tốt tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khô héo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lòng dạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con con': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đạn đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ma mút': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sông núi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khâm liệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'chữ nhật': []
# --------------------
# Results for 'bánh trái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phố đông': []
# --------------------
# Results for 'mô típ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sông rạch': []
# --------------------
# Results for 'đóng đô': ["category2: 'Động từ'"]
# --------------------
# Results for 'rét buốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phật ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'so bì': ["category2: 'Động từ'"]
# --------------------
# Results for 'khải hoàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiên đàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi tập': []
# --------------------
# Results for 'cá trắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sóng sánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưỡng hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hung bạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả bộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ướt át': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc thử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu bối': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'truy hô': ["category2: 'Động từ'"]
# --------------------
# Results for 'tầng nấc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gọi thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoa cử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xú uế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quán cóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bi luỵ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô lễ': []
# --------------------
# Results for 'sút cân': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại giao': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hoàn hồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưỡng cực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'để bụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia giáo': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tiêu bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư dinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình làng': []
# --------------------
# Results for 'luống tuổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương cảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 've sầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiền nhiễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quai hàm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe ủi': []
# --------------------
# Results for 'nem rán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồi tỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tể tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiển cận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hát rong': ["category2: 'Động từ'"]
# --------------------
# Results for 'cười cười': []
# --------------------
# Results for 'xốn xang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đười ươi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo xa': ["category2: 'Động từ'"]
# --------------------
# Results for 'mừng thầm': ["category2: 'Động từ'"]
# --------------------
# Results for 'sắc độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xao động': ["category2: 'Động từ'"]
# --------------------
# Results for 'quạt trần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng nhân': []
# --------------------
# Results for 'đi bụi': ["category2: 'Động từ'"]
# --------------------
# Results for 'oàn khu': []
# --------------------
# Results for 'xích đu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'được cái': []
# --------------------
# Results for 'mặn mòi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chia lìa': ["category2: 'Động từ'"]
# --------------------
# Results for 'muối khoáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hẩm hiu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng giám': ["category2: 'Động từ'"]
# --------------------
# Results for 'cải cúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xóm giềng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hôi hám': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tày trời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chư vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vỗ ngực': ["category2: 'Động từ'"]
# --------------------
# Results for 'cẩn mật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặt để': ["category2: 'Động từ'"]
# --------------------
# Results for 'giòn rụm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bơ phờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thu nhặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'vợ bé': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ruột gan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bưu cục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu bút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chém giết': ["category2: 'Động từ'"]
# --------------------
# Results for 'gột rửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'học kì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'êm xuôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lập quốc': []
# --------------------
# Results for 'công bộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội gián': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mỹ viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chế tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'gay go': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nửa mùa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khẩn cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tả ngạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bị chú': ["category2: 'Động từ'"]
# --------------------
# Results for 'quá chén': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồi xuân': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội sở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vận đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếc rẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'vì cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngã bệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'mạch nha': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phấn son': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nặng kí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trà sữa': []
# --------------------
# Results for 'màng cứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thăm nuôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'điềm nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dấu chấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ham thích': []
# --------------------
# Results for 'tiên sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cân treo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu quốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'khai khẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiếc bóng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tà đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vệ sỹ': []
# --------------------
# Results for 'nhà lao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khét lẹt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'liêm khiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thoái lui': ["category2: 'Động từ'"]
# --------------------
# Results for 'tang tóc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trông ngóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia cường': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thâm trầm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhận thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'an vui': []
# --------------------
# Results for 'bộc trực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tít tắp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lang quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân kế': []
# --------------------
# Results for 'ham hố': ["category2: 'Động từ'"]
# --------------------
# Results for 'kí hiệu': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'rành rọt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn tạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoạt hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi tỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh hỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trở trời': []
# --------------------
# Results for 'ăn nằm': ["category2: 'Động từ'"]
# --------------------
# Results for 'mồn một': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tinh vân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rau đay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chai sạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngon mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dược chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyện dài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phẫn uất': ["category2: 'Động từ'"]
# --------------------
# Results for 'mấy mươi': []
# --------------------
# Results for 'ban mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đích đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khó coi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ta luy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'u tối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lỗ chỗ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chật ních': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chữ nổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp hiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chụp giật': ["category2: 'Động từ'"]
# --------------------
# Results for 'rượu nếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tứ phía': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ong mật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quả nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dại khờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chủng viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'may vá': ["category2: 'Động từ'"]
# --------------------
# Results for 'sông Cái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triệt thoái': []
# --------------------
# Results for 'nghênh ngang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thoai thoải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cải xoong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bủn rủn': []
# --------------------
# Results for 'cảm tạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lả lơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tâm khảm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỹ nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vui thú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mơ tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ba rọi': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đánh đổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'gà nòi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nặng tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yêu quái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyên răn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ng trắng': []
# --------------------
# Results for 'hình nón': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lập thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'móng giò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'có hiếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'địa tầng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tai mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngấu nghiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vị thanh': []
# --------------------
# Results for 'bút tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lười nhác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuyên doanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đứng số': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên đèn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lãng đãng': []
# --------------------
# Results for 'bám víu': ["category2: 'Động từ'"]
# --------------------
# Results for 'yếu mềm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên thanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bãi công': ["category2: 'Động từ'"]
# --------------------
# Results for 'cung tiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'đăm chiêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cong vút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngăn trở': ["category2: 'Động từ'"]
# --------------------
# Results for 'phiền não': []
# --------------------
# Results for 'hiền từ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ng tim': []
# --------------------
# Results for 'mua lẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt tăm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ác động': []
# --------------------
# Results for 'lầm lì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xét nét': ["category2: 'Động từ'"]
# --------------------
# Results for 'tri kỉ': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ý nhị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khu trục': []
# --------------------
# Results for 'huyện thị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chểnh mảng': []
# --------------------
# Results for 'khai hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuật viên': []
# --------------------
# Results for 'vi phẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên thân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bong gân': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo thủ': []
# --------------------
# Results for 'diêm dúa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phương pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia đình': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'vái lạy': ["category2: 'Động từ'"]
# --------------------
# Results for 'ng thiếu': []
# --------------------
# Results for 'giáo huấn': []
# --------------------
# Results for 'ngành dọc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quay cóp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ậm ừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'niên sử': []
# --------------------
# Results for 'cái răng': []
# --------------------
# Results for 'sóng ngầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sưng húp': ["category2: 'Động từ'"]
# --------------------
# Results for 'móc ngoặc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân tinh': []
# --------------------
# Results for 'vi hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân nhạc': []
# --------------------
# Results for 'nhạo báng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lật đật': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mệnh đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'hát văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tột đỉnh': []
# --------------------
# Results for 'lá mầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hớt hải': []
# --------------------
# Results for 'hiệp lực': ["category2: 'Động từ'"]
# --------------------
# Results for 'giải viên': []
# --------------------
# Results for 'lên thẳng': []
# --------------------
# Results for 'bò cạp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trà đá': []
# --------------------
# Results for 'tự vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuốc tiêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đoan trang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nắn nót': ["category2: 'Động từ'"]
# --------------------
# Results for 'tảo mộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sờ mó': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bãi nại': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắc lẹm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải khuây': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm giao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ức hiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'đô thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngàn xưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giò lụa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuối tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xình xịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đứt ruột': []
# --------------------
# Results for 'con buôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đâu đây': ["category7: 'Đại từ'"]
# --------------------
# Results for 'so le': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giao thiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ằng nhằng': []
# --------------------
# Results for 'u uất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tĩnh mịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh đôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúa mỳ': []
# --------------------
# Results for 'đồng ca': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thâm độc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cô hầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hôn thú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lấn cấn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'anh vũ': ["category1: 'Danh từ'", "category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tri giác': []
# --------------------
# Results for 'dân chuyên': []
# --------------------
# Results for 'nữ sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phúc lộc': []
# --------------------
# Results for 'lễ bái': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia chánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thượng thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tù trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chịu tang': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạ thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giải ngũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe thồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sóng điện': []
# --------------------
# Results for 'đa diện': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bà chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cừ khôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền chiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tréo ngoe': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tẩm quất': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu thời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'sao chụp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên soái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bát giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gái nhảy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếng lóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quảng canh': ["category2: 'Động từ'"]
# --------------------
# Results for 'quần soóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ hoành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vây ráp': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn cục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hương thảo': []
# --------------------
# Results for 'kinh tởm': []
# --------------------
# Results for 'thuận hoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đình hoãn': []
# --------------------
# Results for 'biến th': []
# --------------------
# Results for 'mười ba': []
# --------------------
# Results for 'vô lê': ["category2: 'Động từ'"]
# --------------------
# Results for 'phu thê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mầu sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trở mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'đấu thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lảng vảng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nín nhịn': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoái chí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đứt quãng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn bớt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hào khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cỏ may': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều kinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'cua rơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đi tắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp kiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'tận lực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'son sắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tử chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh nguội': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghị sự': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảng màu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiêng kị': ["category2: 'Động từ'"]
# --------------------
# Results for 'bặm trợn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'câu nệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lợi lộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhấp nhổm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xem chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉ suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phật giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lễ đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toả nhiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'uỷ mị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công tác': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hàm số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh anh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cháo lòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đuổi nghiệp': []
# --------------------
# Results for 'tẩy não': ["category2: 'Động từ'"]
# --------------------
# Results for 'tha th': []
# --------------------
# Results for 'lí nhí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngôi thứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'muối bỏ': []
# --------------------
# Results for 'tàn lụi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đỏ au': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ổ trâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'róc rách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khá khẩm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'họ tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chẳng đã': []
# --------------------
# Results for 'loa kèn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình nguyện viên': []
# --------------------
# Results for 'bình luận viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm soát': ["category2: 'Động từ'"]
# --------------------
# Results for 'mấy chốc': []
# --------------------
# Results for 'bậc thang': []
# --------------------
# Results for 'bản doanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyền hình cáp': []
# --------------------
# Results for 'độ sứ': []
# --------------------
# Results for 'xách tay': []
# --------------------
# Results for 'xuất phát điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quốc ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm định viên': []
# --------------------
# Results for 'giáo dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'viễn vọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tết nguyên đán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công nghiệp hoá': []
# --------------------
# Results for 'an viên': []
# --------------------
# Results for 'cầu khẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa hoá': []
# --------------------
# Results for 'giáo khoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bất đắc dĩ': []
# --------------------
# Results for 'lục chiến': []
# --------------------
# Results for 'bàn phim': []
# --------------------
# Results for 'ký sinh trùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lập trình viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'át chủ bài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cánh cụt': []
# --------------------
# Results for 'ma cà rồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành công': []
# --------------------
# Results for 'chứng minh thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư vấn viên': []
# --------------------
# Results for 'sốt vó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tham mưu trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công chứng viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nồi cơm điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ẩn khúc': []
# --------------------
# Results for 'bài trùng': []
# --------------------
# Results for 'công anh': []
# --------------------
# Results for 'côn cầu': []
# --------------------
# Results for 'muôn hình': []
# --------------------
# Results for 'vạn trạng': []
# --------------------
# Results for 'nhân hoá': []
# --------------------
# Results for 'thiên niên kỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn phòng phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ban giám hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời khoá biểu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuần phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mỹ tục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa cương': ["category1: 'Danh từ'"]
# --------------------
# Final results have been saved to 10000word.json
