# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '1000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 1053

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 2000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'vùng đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ thiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'góp mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'động thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tại chỗ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nói riêng': []
# --------------------
# Results for 'ngôn ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bắt buộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu hoạch': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phát sóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm thanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuôn mặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá khứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hầu như': []
# --------------------
# Results for 'mặt trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mầm non': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phong độ': []
# --------------------
# Results for 'hứa hẹn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên ngành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hải quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe tăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc lá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lừa đảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực thi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cân nhắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'do đó': []
# --------------------
# Results for 'tương đối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đối phó': ["category2: 'Động từ'"]
# --------------------
# Results for 'con cái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trình bày': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyển giao': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham khảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông điệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khó chịu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cô giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khiếu nại': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng minh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tiêu biểu': []
# --------------------
# Results for 'xe đạp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biên bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn đàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng thể': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bất chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'trái cây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dẫn dắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thủ môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'loại hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẩm định': ["category2: 'Động từ'"]
# --------------------
# Results for 'lập tức': []
# --------------------
# Results for 'khoẻ mạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tư cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bằng chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khởi nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tài nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trạng thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cắt giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phủ nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoảnh khắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chấp hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'viễn thông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ứng viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao tốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiên tiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đảng viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khởi động': ["category2: 'Động từ'"]
# --------------------
# Results for 'ly hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu thập': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhạy cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cánh cứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'mạng lưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di dời': ["category2: 'Động từ'"]
# --------------------
# Results for 'không quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉ lệ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tổng cộng': ["category2: 'Động từ'"]
# --------------------
# Results for 'giảng dạy': ["category2: 'Động từ'"]
# --------------------
# Results for 'đề tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng tiền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyến cáo': []
# --------------------
# Results for 'bài học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vi khuẩn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năng suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiết thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công bằng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sân nhà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôi khi': []
# --------------------
# Results for 'tập trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoa hậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghĩa vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xúc động': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lộ trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghề nghiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp pháp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xét nghiệm': []
# --------------------
# Results for 'căn bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỏ qua': ["category2: 'Động từ'"]
# --------------------
# Results for 'công văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trọng lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần đảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toà án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay vợt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tương ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bàn tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truy cập': ["category2: 'Động từ'"]
# --------------------
# Results for 'triệu chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'thân thiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấu giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiến bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàng xóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thí điểm': []
# --------------------
# Results for 'đồng hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung ương': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bạn đọc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xăng dầu': []
# --------------------
# Results for 'phong phú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bị can': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng không': ["category2: 'Động từ'"]
# --------------------
# Results for 'đột phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực tiễn': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'biên chế': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vui chơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'bí ẩn': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đẳng cấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chinh phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'anh chàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiến quân': []
# --------------------
# Results for 'đường dây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chi trả': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạm thời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bỏ phiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'thi đua': ["category2: 'Động từ'"]
# --------------------
# Results for 'thẩm mỹ': []
# --------------------
# Results for 'diễn xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiêu hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng tỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuê bao': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vướng mắc': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hỗn hợp': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trọng điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thích thú': []
# --------------------
# Results for 'cẩn thận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chữa cháy': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiết mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh dấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'binh sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điển hình': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hậu vệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giàu có': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đình chỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự định': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nữ sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chấp thuận': ["category2: 'Động từ'"]
# --------------------
# Results for 'sưu tập': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giáo sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'ứng xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo quản': ["category2: 'Động từ'"]
# --------------------
# Results for 'hẹn hò': ["category2: 'Động từ'"]
# --------------------
# Results for 'gần gũi': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'văn minh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cải tiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo mật': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mẹ con': []
# --------------------
# Results for 'phòng thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tập huấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'lãng mạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biến động': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nhất trí': []
# --------------------
# Results for 'chúc mừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'người lớn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vết thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ước mơ': []
# --------------------
# Results for 'lãng phí': ["category2: 'Động từ'"]
# --------------------
# Results for 'phát động': ["category2: 'Động từ'"]
# --------------------
# Results for 'không kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩm thực': ["category2: 'Động từ'"]
# --------------------
# Results for 'hy sinh': []
# --------------------
# Results for 'viên chức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đau đớn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dạ dày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giá cả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình báo': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chi nhánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên minh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quản trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'chi tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lý tưởng': []
# --------------------
# Results for 'trẻ trung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấu trúc': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'học bổng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dấu ấn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khắp nơi': []
# --------------------
# Results for 'nghỉ ngơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân sự': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nam giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'anh hùng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thu giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bình chọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'áo dài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất cập': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vệ tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyện vọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhắc nhở': ["category2: 'Động từ'"]
# --------------------
# Results for 'châu Phi': []
# --------------------
# Results for 'bản quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giảng viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân gian': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trực thăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ứng phó': ["category2: 'Động từ'"]
# --------------------
# Results for 'sức ép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hài hước': []
# --------------------
# Results for 'tuyển dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'danh mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngọt ngào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'một nửa': []
# --------------------
# Results for 'cố tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỷ phú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tin tức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người nhà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'to lớn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiện diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'ùn tắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'huyền thoại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân chủ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hải sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đô la': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước thải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trinh sát': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đón nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'lành mạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xe khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây xanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảm hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh tế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưu trữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'huy chương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phá huỷ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phổ thông': ["category3: 'Tính từ'", "category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quy chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư duy': []
# --------------------
# Results for 'khách quan': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trọng tâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẳng thắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuất bản': ["category2: 'Động từ'"]
# --------------------
# Results for 'hữu nghị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'từ bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh nhật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trang điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phần nào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chỉ định': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vô tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ông bà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khống chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiểu biết': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'làm đẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'rối loạn': []
# --------------------
# Results for 'sơ thẩm': ["category2: 'Động từ'"]
# --------------------
# Results for 'vị thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đăng quang': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhìn nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'nông sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thập niên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghỉ dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'linh hoạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nếu như': []
# --------------------
# Results for 'tham mưu': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chiến thuật': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đồng nghĩa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tính cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'song phương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xôn xao': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'dữ dội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tranh thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chất thải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiến trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'luật pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sôi động': ["category2: 'Động từ'"]
# --------------------
# Results for 'lạm phát': []
# --------------------
# Results for 'nội thất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cống hiến': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chiến binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năng động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'văn học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự phòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồi dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chênh lệch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xe hơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá tải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối ngoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'phòng ngự': ["category2: 'Động từ'"]
# --------------------
# Results for 'thầy trò': []
# --------------------
# Results for 'tức là': []
# --------------------
# Results for 'đền bù': ["category2: 'Động từ'"]
# --------------------
# Results for 'cổ vũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nắng nóng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiện hành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tổ hợp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công lập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trước mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tính mạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dài hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiên quyết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khởi công': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiến sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trân trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bác sỹ': []
# --------------------
# Results for 'thường trực': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'doanh số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy móc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thắc mắc': []
# --------------------
# Results for 'làm nên': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghị quyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rèn luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán đảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tin cậy': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao tiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'trang trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần kinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giữ gìn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoá đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vui mừng': []
# --------------------
# Results for 'cách thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cung ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'giờ đây': ["category7: 'Đại từ'"]
# --------------------
# Results for 'vững chắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dịch bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đàn bà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khôi phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'chẩn đoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỹ sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm hứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thập kỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rực rỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thắng lợi': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sân chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bê tông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạm dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chất liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giám định': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lý giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'sợ hãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiệt tình': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thân hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triệt để': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc thù': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lắng nghe': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiến trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quan niệm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'khuyết tật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lớp học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vòng loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàm lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đỉnh cao': []
# --------------------
# Results for 'rác thải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành tựu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh bắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'kim loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng tình': []
# --------------------
# Results for 'ngộ độc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đột ngột': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sát hại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôn giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'số phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu mối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền mặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng bỏng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chất vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chẳng hạn': []
# --------------------
# Results for 'hành lang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tôn vinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy tố': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước sạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực đoan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bận rộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'băn khoăn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thời đại': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thực hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung vệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh học': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'dao động': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giảm thiểu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đấu thầu': []
# --------------------
# Results for 'trái phiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà cửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tác chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'có khi': []
# --------------------
# Results for 'xâm nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền lương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mật độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyết áp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cản trở': []
# --------------------
# Results for 'xuống cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự trữ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cô dâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồ ăn': []
# --------------------
# Results for 'đề cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao su': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trao tặng': ["category2: 'Động từ'"]
# --------------------
# Results for 'học phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc hại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tình nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'cân đối': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'cửa khẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'khéo léo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nổi dậy': ["category2: 'Động từ'"]
# --------------------
# Results for 'thận trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vượt trội': ["category2: 'Động từ'"]
# --------------------
# Results for 'ám ảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sáng kiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất xứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hải quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng ngừa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hương vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngăn ngừa': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham vọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bởi vì': []
# --------------------
# Results for 'giá thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại tệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khởi đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhắn tin': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản lĩnh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'mỹ phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồi phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'thăm dò': ["category2: 'Động từ'"]
# --------------------
# Results for 'không những': []
# --------------------
# Results for 'giải toả': ["category2: 'Động từ'"]
# --------------------
# Results for 'im lặng': []
# --------------------
# Results for 'bác bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khu phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tháo gỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trộm cắp': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đau đầu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cửa sổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mưa rào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản hồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vũ trụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh hoàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thị phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chức danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cố định': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'sáp nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'danh tiếng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'gói thầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỳ lạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tranh luận': ["category2: 'Động từ'"]
# --------------------
# Results for 'thượng đỉnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạc quan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trợ giúp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân thành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhân tạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tàu chiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dụng cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bước đi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải ngân': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghi vấn': []
# --------------------
# Results for 'tứ kết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao đẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồ chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ cánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tranh cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiện ích': []
# --------------------
# Results for 'đình đám': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân công': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặt hàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bùng nổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'gay gắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trí tuệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đảm nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'khen ngợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng loạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bình tĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lân cận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiển thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'ồn ào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhập cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'hào hứng': []
# --------------------
# Results for 'tự nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'xúc tiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngày một': []
# --------------------
# Results for 'chuyển biến': []
# --------------------
# Results for 'tiền bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'báo động': ["category2: 'Động từ'"]
# --------------------
# Results for 'vóc dáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lương thực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thầy cô': []
# --------------------
# Results for 'nắm bắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc sắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sở thích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'em gái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mong đợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'bề mặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thu mua': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngưỡng mộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất ổn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt cóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bệnh tật': []
# --------------------
# Results for 'cấp uỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mã lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tị nạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước biển': []
# --------------------
# Results for 'mái tóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tưởng tượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bài tập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bước đầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền tệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hết mình': []
# --------------------
# Results for 'hàng hải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đất liền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gian lận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phụ kiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảnh quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia hạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'liệt sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm biến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mồ hôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'để ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà thờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trợ cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân loại': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ chức': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kê khai': ["category2: 'Động từ'"]
# --------------------
# Results for 'thường niên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tư thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng thuận': []
# --------------------
# Results for 'triệu tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'qua lại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỷ giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'tò mò': []
# --------------------
# Results for 'giới tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghĩa là': []
# --------------------
# Results for 'chào đón': ["category2: 'Động từ'"]
# --------------------
# Results for 'bến xe': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buôn lậu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đẹp mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chịu đựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngành nghề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều hoà': ["category3: 'Tính từ'", "category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'yêu mến': ["category2: 'Động từ'"]
# --------------------
# Results for 'kim ngạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạ sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây trồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cho dù': []
# --------------------
# Results for 'tự chủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dạy học': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiềm ẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tập hợp': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hoang mang': ["category2: 'Động từ'"]
# --------------------
# Results for 'bình đẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiệu ứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân bón': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khả thi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưu giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hài hoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'những ai': ["category7: 'Đại từ'"]
# --------------------
# Results for 'nuôi dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự xưng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trợ lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nảy sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'mới mẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyển thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vinh dự': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thư giãn': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật dụng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lên đường': ["category2: 'Động từ'"]
# --------------------
# Results for 'cài đặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoành tráng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thất nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'rải rác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồng bằng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai trương': ["category2: 'Động từ'"]
# --------------------
# Results for 'trọn vẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chăm lo': []
# --------------------
# Results for 'đối xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'lên án': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngắn hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt gặp': ["category2: 'Động từ'"]
# --------------------
# Results for 'độc quyền': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ấm áp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hô hấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đoàn viên': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đổ bộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiểu thuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng cứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tồi tệ': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bài toán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triển vọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều động': ["category2: 'Động từ'"]
# --------------------
# Results for 'công sức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áp đặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chữ ký': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tim mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn chỉnh': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hoá học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yếu kém': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rắc rối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tương tác': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cố vấn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thủ tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giản dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiếp thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ưa chuộng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo tàng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sạch sẽ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiểm toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiềm chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'lên ngôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoả mãn': []
# --------------------
# Results for 'nhân đạo': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thể loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rò rỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xâm hại': ["category2: 'Động từ'"]
# --------------------
# Results for 'lan toả': ["category2: 'Động từ'"]
# --------------------
# Results for 'gợi ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghệ nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngăn cản': ["category2: 'Động từ'"]
# --------------------
# Results for 'dung lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoác áo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thủ công': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sơ sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trầm trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mưa lũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuận tiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thể lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khám chữa': []
# --------------------
# Results for 'đột biến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều khoản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hưởng ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'khám nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'chất độc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gắn kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'diễn tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'tư liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiến tạo': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# ...
# Results for 'âm mưu': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'danh dự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con cháu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước mắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự toán': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mỹ nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khái niệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phê bình': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầu ra': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dễ thương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tâm hồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trụ cột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uỷ quyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'vợ con': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân bố': ["category2: 'Động từ'"]
# --------------------
# Results for 'màn ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỹ lưỡng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'môi giới': []
# --------------------
# Results for 'vũ trang': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhân tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu bang': []
# --------------------
# Results for 'lo sợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'rõ rệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'anh chị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bùng phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'lời nói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình yên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lấn chiếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tốn kém': ["category2: 'Động từ'"]
# --------------------
# Results for 'luyện tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu nhi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoài trời': []
# --------------------
# Results for 'kiểm định': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo giới': []
# --------------------
# Results for 'viện trợ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tầng lớp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhãn hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiễm trùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'riêng tư': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sơ tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm huyết': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'vào vai': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăm chỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thần tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đúng đắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đến nơi': []
# --------------------
# Results for 'bí quyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lý thuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kim cương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bầu trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ưu thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoang dã': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đội trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lượt đi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiện thực': []
# --------------------
# Results for 'khoáng sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'coi trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'con em': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa khoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'em trai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca hát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đoàn thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khủng khiếp': []
# --------------------
# Results for 'sụt giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tín nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải trình': ["category2: 'Động từ'"]
# --------------------
# Results for 'quả tang': []
# --------------------
# Results for 'nhà nghỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉnh sửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'động tác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự bị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sư phạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa hồng': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cố ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kích hoạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy tắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dây chuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giới chức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sa thải': ["category2: 'Động từ'"]
# --------------------
# Results for 'vừa rồi': []
# --------------------
# Results for 'mặt nạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vĩ đại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cư trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'mơ ước': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phát ngôn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hữu ích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vắng mặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làng nghề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh bạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt đới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cổ truyền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kế toán': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sống sót': ["category2: 'Động từ'"]
# --------------------
# Results for 'kháng sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạo hiểm': []
# --------------------
# Results for 'trước hết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngày mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'làn sóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà ga': ["category1: 'Danh từ'"]
# --------------------
# Results for 'địa phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gian hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạ tiết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàng rào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vừa phải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia cầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xếp hàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm quen': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiên trì': []
# --------------------
# Results for 'nhân văn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầm quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'tủ lạnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra quân': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'khuôn viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phê chuẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân dịp': []
# --------------------
# Results for 'xâm phạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'vinh danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc tịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên bang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung thành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quan ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tức giận': ["category2: 'Động từ'"]
# --------------------
# Results for 'đơn thuần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thăm hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'du học': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều tiết': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sinh sản': ["category2: 'Động từ'"]
# --------------------
# Results for 'tín đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dũng cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phúc thẩm': ["category2: 'Động từ'"]
# --------------------
# Results for 'góc độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiều tối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tội danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cà chua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chóng mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'khắc nghiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiểu đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao tuổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cô đơn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'liên ngành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ống kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháo hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cất cánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử cung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sổ đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giấc ngủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân bổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rào cản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lan truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'cũng nên': []
# --------------------
# Results for 'bộ môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dị ứng': []
# --------------------
# Results for 'trẻ con': ["category1: 'Danh từ'", "category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'siêu mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'loại trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường ống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thông tấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'khung thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ đoạn': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đảm nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngày đêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn nghệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vĩ mô': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'gìn giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghệ sỹ': []
# --------------------
# Results for 'ghi hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất đồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giúp việc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổn thất': []
# --------------------
# Results for 'thể chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kẻ thù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dần dần': []
# --------------------
# Results for 'chuyên đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ý chí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ động': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bế tắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khiêm tốn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tích luỹ': []
# --------------------
# Results for 'khởi kiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất lợi': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phong thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bước tiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cho nên': []
# --------------------
# Results for 'xổ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cuộc gọi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tháo dỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhận lời': ["category2: 'Động từ'"]
# --------------------
# Results for 'nấu ăn': ["category2: 'Động từ'"]
# --------------------
# Results for 'sụp đổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao tầng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu bảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầm quyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'thầy giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểu dáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'tang vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trong sáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhận diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu niệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'trầm cảm': []
# --------------------
# Results for 'tạo hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'lớn tuổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia súc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy thoái': ["category2: 'Động từ'"]
# --------------------
# Final results have been saved to 1000word.json
