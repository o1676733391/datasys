# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '9000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 9035

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 10000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'công hiệu': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trừ phi': []
# --------------------
# Results for 'lề lối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đưa đẩy': ["category2: 'Động từ'"]
# --------------------
# Results for 'cột trụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân đạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vạch mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tề tựu': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ sơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tầm tã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô kể': []
# --------------------
# Results for 'xung trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tình trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân bua': ["category2: 'Động từ'"]
# --------------------
# Results for 'đưa tiễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngon giấc': ["category2: 'Động từ'"]
# --------------------
# Results for 'rồi đây': []
# --------------------
# Results for 'si tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoằn ngoèo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tĩnh tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'run sợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giằng xé': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà lớn': []
# --------------------
# Results for 'loan báo': ["category2: 'Động từ'"]
# --------------------
# Results for 'lởm chởm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'răng cưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tập tành': ["category2: 'Động từ'"]
# --------------------
# Results for 'gian truân': []
# --------------------
# Results for 'đạn nổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chán ngán': []
# --------------------
# Results for 'heo hút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'co bóp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ổ cắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa gần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luyện kim': ["category2: 'Động từ'"]
# --------------------
# Results for 'cùng đường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lập lờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tần tảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối lưu': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'soát xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu đói': ["category2: 'Động từ'"]
# --------------------
# Results for 'phong bao': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'chân đế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá vàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'túi bụi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sâu nặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mỏi mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phục tùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'câu đố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mắng mỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cò mồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trù dập': ["category2: 'Động từ'"]
# --------------------
# Results for 'bài chòi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mơn mởn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luật gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lắt léo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mầm mống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nói nhỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưu cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyển ngữ': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'phô bày': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạch dương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trầm mặc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biết mấy': []
# --------------------
# Results for 'oan ức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'không lẽ': []
# --------------------
# Results for 'sát viên': []
# --------------------
# Results for 'luận cứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khó ở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trừ tà': ["category2: 'Động từ'"]
# --------------------
# Results for 'đun nấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tệp tin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quang điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bột giặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yêu dấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm xuyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ thực': []
# --------------------
# Results for 'biên dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'vòng vo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phì cười': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy chụp': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàn lương': ["category2: 'Động từ'"]
# --------------------
# Results for 'dạ tiệc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máu me': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nước hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quát tháo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuê mướn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cử tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'thính lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cằn cỗi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô trùng': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ra dáng': []
# --------------------
# Results for 'ngồi thiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhấm nháp': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sang chấn': []
# --------------------
# Results for 'canh chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đỏ hoe': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đỗ đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thợ may': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vẩy nến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân không': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại ý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoang đường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chỉ điểm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bần bật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sử ký': ["category1: 'Danh từ'"]
# --------------------
# Results for 'góc quay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối đãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'kế sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mới tinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đối sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hữu hình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vượt cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'xót thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'ghẻ lạnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân rết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lục bát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lướt ván': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh đố': ["category2: 'Động từ'"]
# --------------------
# Results for 'chà đạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tứ chi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'móng vuốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngọt lịm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'y chang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trói buộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đạo chích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuỷ quái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cự tuyệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá mú': ["category1: 'Danh từ'", "category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bách bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất gia': ["category2: 'Động từ'"]
# --------------------
# Results for 'súc vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đỏng đảnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồng thanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tẩy xoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'lạp xưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lũ lượt': []
# --------------------
# Results for 'cứu rỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghỉ chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'chí hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xả thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao ước': []
# --------------------
# Results for 'ôm đồm': ["category2: 'Động từ'"]
# --------------------
# Results for 'an bài': ["category2: 'Động từ'"]
# --------------------
# Results for 'sớm mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'co cụm': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấu kiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia phả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đanh thép': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thô thiển': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ruộng vườn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiêu khiển': ["category2: 'Động từ'"]
# --------------------
# Results for 'hậu mãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dưỡng khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà khí': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'kiệm lời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bẽ mặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm tới': ["category2: 'Động từ'"]
# --------------------
# Results for 'phương ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'muối ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu chiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoà nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trẩy hội': ["category2: 'Động từ'"]
# --------------------
# Results for 'đùng đùng': []
# --------------------
# Results for 'lình xình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thần công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngô nghê': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hương ước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chôn chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc phục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ước chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàn dư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lì lợm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cất nhắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mát lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quấy nhiễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ốm nghén': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chơi đẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bột giấy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'rẻ mạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'uy quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xay xát': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu tàu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điểm chỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuyền thúng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóp nghẹt': ["category2: 'Động từ'"]
# --------------------
# Results for 'lai rai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lém lỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'u nang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dâu tằm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dần dà': []
# --------------------
# Results for 'cổ suý': ["category2: 'Động từ'"]
# --------------------
# Results for 'nôn nao': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô định': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhân sinh': []
# --------------------
# Results for 'chạy án': ["category2: 'Động từ'"]
# --------------------
# Results for 'có dễ': []
# --------------------
# Results for 'tam thất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bức tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'cốt cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phồn hoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đói khát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xã phường': []
# --------------------
# Results for 'rạp hát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sơn cước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dư vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gà tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lăng quăng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đầu thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'tín chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chợ mới': []
# --------------------
# Results for 'các tông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vắng lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật vờ': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhân nhượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tò he': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô can': ["category3: 'Tính từ'"]
# --------------------
# Results for 'so găng': ["category2: 'Động từ'"]
# --------------------
# Results for 'câm điếc': []
# --------------------
# Results for 'thú tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay sai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lí giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguồn cơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiến diện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuyệt đỉnh': []
# --------------------
# Results for 'nguyên hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điên điển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngón cái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mở thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh tao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấu vật': ["category2: 'Động từ'"]
# --------------------
# Results for 'mái hiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thừa thãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khai vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'thỉnh cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'rác rưởi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường bắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vết tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiếu xạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúa mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuynh đảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cam sành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hao mòn': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy nổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'keo kiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ưu tư': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ nhỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bừa bộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nối mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dài dòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mặc sức': []
# --------------------
# Results for 'thô ráp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bom xăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạm bạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tổng t': []
# --------------------
# Results for 'thi vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi lao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khả dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ng tiếng': []
# --------------------
# Results for 'cống rãnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đá dăm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xà lan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyến tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản quang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu cuối': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'công xưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao siêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngót nghét': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đập tràn': []
# --------------------
# Results for 'gắng gượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trách cứ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy phạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tệ bạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'danh từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán sỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đám hỏi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần tự': []
# --------------------
# Results for 'chới với': ["category2: 'Động từ'"]
# --------------------
# Results for 'quái đản': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mề đay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đút túi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu chúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngụp lặn': ["category2: 'Động từ'"]
# --------------------
# Results for 'túng thiếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đạo ôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hăm hở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khuấy đảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiền hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'lấp lửng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giết thịt': ["category2: 'Động từ'"]
# --------------------
# Results for 'huyết tương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá trích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vàng lá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào xới': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạ thế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khảo thí': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm phép': ["category2: 'Động từ'"]
# --------------------
# Results for 'pháp quy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biệt phái': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'siêu phàm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đúng ra': []
# --------------------
# Results for 'nói tục': ["category2: 'Động từ'"]
# --------------------
# Results for 'bằng không': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vang vọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xúc tác': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảng thốt': []
# --------------------
# Results for 'định luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao sang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại cỡ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'màn kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ đạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'diều hâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại tiệc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất định': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'khẩn thiết': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đồng diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tai ương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lẳng lơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hậm hực': ["category2: 'Động từ'"]
# --------------------
# Results for 'su su': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thể nghiệm': []
# --------------------
# Results for 'nạo phá': []
# --------------------
# Results for 'băng hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh đấm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghe đâu': []
# --------------------
# Results for 'giật dây': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trăng tròn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng sự': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rối nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rơm rớm': ["category2: 'Động từ'"]
# --------------------
# Results for 'yên ắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trả chậm': ["category2: 'Động từ'"]
# --------------------
# Results for 'va quệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'sục sôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'nao núng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phế tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng loã': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thể nào': []
# --------------------
# Results for 'phẩm giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'viển vông': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thực lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phòng bị': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'bánh trôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiêu khê': ["category3: 'Tính từ'"]
# --------------------
# Results for 'như thanh': []
# --------------------
# Results for 'học việc': ["category2: 'Động từ'"]
# --------------------
# Results for 'lỗ đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạo tác': []
# --------------------
# Results for 'sự tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiễm xạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lĩnh hội': ["category2: 'Động từ'"]
# --------------------
# Results for 'óng ả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bọt biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trằn trọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ý tứ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'oan uổng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cự li': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trị sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huống hồ': []
# --------------------
# Results for 'mếu máo': ["category2: 'Động từ'"]
# --------------------
# Results for 'còi cọc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cơ nghiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhẹ tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lỉnh kỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phòng thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuộc hạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quyền uy': []
# --------------------
# Results for 'thành kiến': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hành tỏi': []
# --------------------
# Results for 'mù mờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thượng tầng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nề hà': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưu mô': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'kiêng khem': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoai môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khấn vái': ["category2: 'Động từ'"]
# --------------------
# Results for 'trực giác': []
# --------------------
# Results for 'phá phách': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngũ vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trong trắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'duyên phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giữ mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'hốc hác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấp số': []
# --------------------
# Results for 'đèn điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'công nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành sự': []
# --------------------
# Results for 'da dầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quẩn quanh': []
# --------------------
# Results for 'trắc ẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tin buồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'soạn giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kén chọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiêu dụ': []
# --------------------
# Results for 'bả vai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đấu khẩu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quỹ đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lượn lờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỹ nghệ': []
# --------------------
# Results for 'nhu nhược': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tươi thắm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luồng lạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chẳng là': []
# --------------------
# Results for 'nên chăng': []
# --------------------
# Results for 'an nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cốt cán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyệt diệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xơ xác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chúng bạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hề hấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bó buộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bấn loạn': []
# --------------------
# Results for 'ruồng bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đá tảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chim sẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ình nguyện': []
# --------------------
# Results for 'nháo nhào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trường kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình khúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngữ cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hộ lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cúng lễ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nứt toác': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơn dầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phố xá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dung nhan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cải bắp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chết tr': []
# --------------------
# Results for 'đoái hoài': ["category2: 'Động từ'"]
# --------------------
# Results for 'vòi vĩnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉnh trưởng': []
# --------------------
# Results for 'thoi thóp': ["category2: 'Động từ'"]
# --------------------
# Results for 'kinh giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đế vương': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hèn nhát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'méo mặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngụ cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhãn tiền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiên nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gối đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh âm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất bát': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự tại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tư gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh mệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hào sảng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lủng lẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rành mạch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cúng tế': ["category2: 'Động từ'"]
# --------------------
# Results for 'đoạn tuyệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'vệ binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ẩn dụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoái thác': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân gian': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần bò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lỗi lạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hết thảy': ["category7: 'Đại từ'"]
# --------------------
# Results for 'siêu hạng': []
# --------------------
# Results for 'gợi tình': []
# --------------------
# Results for 'đài các': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chó săn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắc thuế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'căm phẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngón trỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ký giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính trực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lũng đoạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'dây dưa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đất hứa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'võ đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diện kiến': []
# --------------------
# Results for 'phát hoả': ["category2: 'Động từ'"]
# --------------------
# Results for 'đau nhói': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cổ hủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tú tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hùng ca': []
# --------------------
# Results for 'hấp hối': ["category2: 'Động từ'"]
# --------------------
# Results for 'gà chọi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'muộn phiền': []
# --------------------
# Results for 'dân tuý': []
# --------------------
# Results for 'thần bí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tan tác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thang cuốn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định tính': ["category2: 'Động từ'"]
# --------------------
# Results for 'mênh mang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'đâu đấy': ["category7: 'Đại từ'"]
# --------------------
# Results for 'trêu ghẹo': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ứng lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực lực': []
# --------------------
# Results for 'kiếm hiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nấm rơm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'không lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tối mật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc Nam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh khiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đích thị': []
# --------------------
# Results for 'thứ yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thoát ly': ["category2: 'Động từ'"]
# --------------------
# Results for 'mò mẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ba má': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện trở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhịn đói': ["category2: 'Động từ'"]
# --------------------
# Results for 'miệng ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trùng điệp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bia hơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chào giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'dài dài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mùi mẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm chi': []
# --------------------
# Results for 'hải cảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sang tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'bát ngát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hun đúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'luộm thuộm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tháo vát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ở vậy': ["category2: 'Động từ'"]
# --------------------
# Results for 'số đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô sản': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'xinh xinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chưởng lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mốc son': []
# --------------------
# Results for 'phập phù': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thơm nức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dưa lê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quyền quý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'triết gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành nhân': []
# --------------------
# Results for 'chiến trận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuếch đại': ["category2: 'Động từ'"]
# --------------------
# Results for 'xanh biếc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhàn nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cũ kĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nội thị': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'khư khư': []
# --------------------
# Results for 'bạc nhược': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn không': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhanh nhảu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngổ ngáo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'màng trinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nể trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hò hẹn': ["category2: 'Động từ'"]
# --------------------
# Results for 'dây xích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ríu rít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chấp bút': ["category2: 'Động từ'"]
# --------------------
# Results for 'phổ quát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giới tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả lập': []
# --------------------
# Results for 'lòng chảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xung điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa dầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phong trần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khò khè': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lao phổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia thất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngủ đông': ["category2: 'Động từ'"]
# --------------------
# Results for 'xây đắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'trầm lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuột đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản mệnh': []
# --------------------
# Results for 'chân giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thư tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhật thực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rầy nâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỏi cung': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhúng tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'tập tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bực dọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu nạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuột túi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng râm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dạt dào': []
# --------------------
# Results for 'rộng lượng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đò ngang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đèn xanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lượng hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuỳ tùng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ngang dọc': []
# --------------------
# Results for 'xà beng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn bám': ["category2: 'Động từ'"]
# --------------------
# Results for 'lớp lớp': []
# --------------------
# Results for 'cán bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'u hồi': []
# --------------------
# Results for 'đi tu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà mồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tương truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'giang mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất diệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mật danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản quốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'hùng hổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thủ pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị uy': ["category2: 'Động từ'"]
# --------------------
# Results for 'án phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mát rượi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sửa soạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'êm ả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vãn cảnh': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lồi lõm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'uẩn khúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài nghệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá chình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên luỵ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoanh tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'phủ định': []
# --------------------
# Results for 'ngang trái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hợp khẩu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tắm giặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cuồng phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dụng ý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dòm ngó': ["category2: 'Động từ'"]
# --------------------
# Results for 'mộ phần': []
# --------------------
# Results for 'hồi giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cửu vạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm bếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đả động': ["category2: 'Động từ'"]
# --------------------
# Results for 'đắm say': ["category2: 'Động từ'"]
# --------------------
# Results for 'khí cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trơ trọi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đậu bắp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầm đìa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'búa rìu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngày kia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồ đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vảy nến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều lệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tẩm bổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giáo hoàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm nghĩ': []
# --------------------
# Results for 'bí danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tu nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắc cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'xúng xính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lẻ loi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dẫn điện': ["category2: 'Động từ'"]
# --------------------
# Results for 'thỉnh giảng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chê cười': ["category2: 'Động từ'"]
# --------------------
# Results for 'mức nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần chú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dò xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'đời đời': []
# --------------------
# Results for 'phụ bạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'lối xóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tán đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'rách nát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tứ tuần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chất dẻo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'võ đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra trò': []
# --------------------
# Results for 'bán rong': ["category2: 'Động từ'"]
# --------------------
# Results for 'truyền đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sành sỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chăm bẵm': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sò huyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm tiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'quạt điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh thông': ["category2: 'Động từ'"]
# --------------------
# Results for 'ông tổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sờ soạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'rập khuôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chế ngự': ["category2: 'Động từ'"]
# --------------------
# Results for 'bù nhìn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'được giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'vĩnh biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'dừa nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào ngũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thái cực': ["category1: 'Danh từ'"]
# --------------------
# ...
# --------------------
# Results for 'phân cực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sách lược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nắm đấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xóc đĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đa điểm': []
# --------------------
# Results for 'vàng đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đời nào': []
# --------------------
# Results for 'bứt rứt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chực chờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'đốt phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'thượng viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vương giả': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'yếu điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhởn nhơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công minh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá trắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tô son': []
# --------------------
# Results for 'giao đấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'xông nhà': ["category2: 'Động từ'"]
# --------------------
# Results for 'chúng mày': ["category7: 'Đại từ'"]
# --------------------
# Results for 'thấp khớp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trồi sụt': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'siêu việt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiệt hơn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoang mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phục thù': ["category2: 'Động từ'"]
# --------------------
# Results for 'lèo lái': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'gan dạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vàng ròng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bão táp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quốc tang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tái cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'bẽn lẽn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiếp chính': ["category2: 'Động từ'"]
# --------------------
# Results for 'thạch nhũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyện lỵ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị phạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'gây chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhúc nhích': ["category2: 'Động từ'"]
# --------------------
# Results for 'nh tình': []
# --------------------
# Results for 'công tước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất học': []
# --------------------
# Results for 'cồn cào': []
# --------------------
# Results for 'vuông vắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buồn tủi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khinh thường': ["category2: 'Động từ'"]
# --------------------
# Results for 'thạch tín': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bào tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán dạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'lủi thủi': []
# --------------------
# Results for 'mệt nhoài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'về vườn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hương sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhãn cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đen nhẻm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đường cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trời giáng': []
# --------------------
# Results for 'chính th': []
# --------------------
# Results for 'thảm cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lãnh chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tản bộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nối gót': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiêng cữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'điện báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cuốn chiếu': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hoan hỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhắm mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưỡi liềm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chọc ghẹo': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồi thẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng ngời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngóng chờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ven đô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại phẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rạo rực': ["category2: 'Động từ'"]
# --------------------
# Results for 'thơ văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyền đạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'sáng mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấp tập': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tắt thở': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'thợ hồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỏi đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước ối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính biến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán trung': []
# --------------------
# Results for 'hao hao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cáo chung': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăng nữa': []
# --------------------
# Results for 'bóng loáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mông lung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mất tăm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra đi': []
# --------------------
# Results for 'văn công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuống tay': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'quân cảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rèn giũa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hộ đê': ["category2: 'Động từ'"]
# --------------------
# Results for 'điệu bộ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trở mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'giun sán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chạy sô': ["category2: 'Động từ'"]
# --------------------
# Results for 'mây khói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hữu trách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chài lưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'túng quẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bốn mươi': []
# --------------------
# Results for 'quản gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác quỷ': []
# --------------------
# Results for 'dao cạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chinh phạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'quản chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'đất hiếm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tằn tiện': []
# --------------------
# Results for 'ngã giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'mách nước': ["category2: 'Động từ'"]
# --------------------
# Results for 'mộc bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khăn quàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trí lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc chất': []
# --------------------
# Results for 'bờ cõi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành xác': ["category2: 'Động từ'"]
# --------------------
# Results for 'dâng hiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn chặn': ["category2: 'Động từ'"]
# --------------------
# Results for 'trấn tĩnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'phục hưng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thợ máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mười mươi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'diễn nghĩa': ["category2: 'Động từ'"]
# --------------------
# Results for 'quấy rầy': ["category2: 'Động từ'"]
# --------------------
# Results for 'lựu pháo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chữ kí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bùn lầy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ích kỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đá ong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bim bim': []
# --------------------
# Results for 'việt dã': []
# --------------------
# Results for 'trầm tư': []
# --------------------
# Results for 'hớt tóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'con thoi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uy nghiêm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nổi cáu': ["category2: 'Động từ'"]
# --------------------
# Results for 'kinh tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phai mờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bà cô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà vốn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giáp xác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đưa rước': []
# --------------------
# Results for 'đồng tử': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lưu chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'té ngửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoạn quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện cực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm cỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đứt đoạn': []
# --------------------
# Results for 'siêu thoát': ["category2: 'Động từ'"]
# --------------------
# Results for 'lẻ tẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá nục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lực lưỡng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vỗ béo': ["category2: 'Động từ'"]
# --------------------
# Results for 'dung mạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sốt giá': []
# --------------------
# Results for 'thanh nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cương lĩnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện ngầm': []
# --------------------
# Results for 'khứu giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mây mù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chịu nhiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đục ngầu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tản văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'còi xương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bến nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cáng đáng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xi nhan': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'phân hạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoái trào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng hoà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bề trên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ướt đẫm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lẩm bẩm': ["category2: 'Động từ'"]
# --------------------
# Results for 'vụn vặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hang ổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chế định': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nước ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu tranh': []
# --------------------
# Results for 'nhãn lồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vu cáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thâm quầng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'êm dịu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầu mây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại liên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá bống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiệm chức': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa lợi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc súng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'võ nghệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vắt vẻo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhãn quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghê sợ': []
# --------------------
# Results for 'âm hộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhung lụa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắt đá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khôi hài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gượng ép': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luyến tiếc': ["category2: 'Động từ'"]
# --------------------
# Results for 'loạn lạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chì chiết': ["category2: 'Động từ'"]
# --------------------
# Results for 'núi đồi': []
# --------------------
# Results for 'biểu thuế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mớn nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tháo lắp': []
# --------------------
# Results for 'nhất nhất': []
# --------------------
# Results for 'quả đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhu động': ["category2: 'Động từ'"]
# --------------------
# Results for 'văn bia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đành lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'điếu cày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thúc thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dữ tợn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ích lợi': []
# --------------------
# Results for 'nũng nịu': []
# --------------------
# Results for 'cao hứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rơi rụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân rã': []
# --------------------
# Results for 'châu báu': ["category1: 'Danh từ'"]
# --------------------
# Final results have been saved to 9000word.json
