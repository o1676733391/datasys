# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '7000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 7007

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 8000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'bước đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'núi non': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội diễn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại cảm': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tắc trách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'huyết thống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bãi nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt mật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cẳng chân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca dao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tê tê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngặt nghèo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'minh oan': ["category2: 'Động từ'"]
# --------------------
# Results for 'cạm bẫy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thu phát': []
# --------------------
# Results for 'uất ức': ["category2: 'Động từ'"]
# --------------------
# Results for 'may rủi': []
# --------------------
# Results for 'thùng xe': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiện ngập': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắp chân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trôi chảy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'linh chi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dài lâu': []
# --------------------
# Results for 'ngây ngô': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chư hầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bút danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thờ tự': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàn lâm': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bươn chải': ["category2: 'Động từ'"]
# --------------------
# Results for 'quý khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường phèn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạn nạn': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tung hứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chắt chiu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân danh': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tiềm thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóp méo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời bình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay trên': []
# --------------------
# Results for 'hàng xách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di chỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nơm nớp': ["category2: 'Động từ'"]
# --------------------
# Results for 'băng tuyết': []
# --------------------
# Results for 'sắm sửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạm quyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuất siêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sánh vai': ["category2: 'Động từ'"]
# --------------------
# Results for 'vú sữa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngụ ý': []
# --------------------
# Results for 'nhã nhặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thảo nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mưu đồ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hồng cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên nghỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'rừng già': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rơi vãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vỗ về': ["category2: 'Động từ'"]
# --------------------
# Results for 'buôn làng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quấn quýt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hắt hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'trắng đen': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phát đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh quản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâu lâu': []
# --------------------
# Results for 'ăn ngủ': []
# --------------------
# Results for 'cường lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đàm thoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'sớm muộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rơm rạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mồng tơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biến chuyển': []
# --------------------
# Results for 'ngôn luận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tất niên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghĩa quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lở loét': []
# --------------------
# Results for 'phân vùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thôi miên': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mới đầu': []
# --------------------
# Results for 'đánh bài': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ giã': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy kiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cam đoan': ["category2: 'Động từ'"]
# --------------------
# Results for 'bật lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ấn bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nào là': []
# --------------------
# Results for 'khẩu chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'quái dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bơ vơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc ngủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiễn đưa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nấm hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối nội': ["category2: 'Động từ'"]
# --------------------
# Results for 'liệu trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động chạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xô bồ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'băng hà': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'cơ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chín muồi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'du ký': []
# --------------------
# Results for 'đã đành': []
# --------------------
# Results for 'trung hoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấm đoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt kích': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ăn tiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'tu hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiến kế': ["category2: 'Động từ'"]
# --------------------
# Results for 'tẩu tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'du ngoạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'lục đục': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nhạt nhẽo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhẹ dạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phung phí': ["category2: 'Động từ'"]
# --------------------
# Results for 'xơ vữa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đâu đâu': ["category7: 'Đại từ'"]
# --------------------
# Results for 'muộn màng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá rô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoan nhượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chửi mắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trinh tiết': []
# --------------------
# Results for 'mụn nhọt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hà khắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vừa miệng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hợp phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu ngạch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trần gian': ["category1: 'Danh từ'"]
# --------------------
# Results for 'băng đĩa': []
# --------------------
# Results for 'đời đầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trân châu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khô cằn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sơ khai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vạch trần': ["category2: 'Động từ'"]
# --------------------
# Results for 'dồn ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'những tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vườn ươm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cáu gắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'trưng dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'máu thịt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rôm rả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiệt trùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mã vạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà cái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mất hút': ["category2: 'Động từ'"]
# --------------------
# Results for 'nốt nhạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đặc hiệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nan y': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hiệp đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm cự': ["category2: 'Động từ'"]
# --------------------
# Results for 'vừa ý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chu toàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'này nọ': ["category7: 'Đại từ'"]
# --------------------
# Results for 'thăm viếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt chiêu': []
# --------------------
# Results for 'kháng viêm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bánh bao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả dối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mới toanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưng chừng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ma thuật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tranh tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưới xin': ["category2: 'Động từ'"]
# --------------------
# Results for 'đất cát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'neo đơn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ốc đảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đĩa đệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mưa nắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cất công': ["category2: 'Động từ'"]
# --------------------
# Results for 'thư từ': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ước lượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lọt lưới': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiết canh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình bóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trừu tượng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bi đát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhường nhịn': ["category2: 'Động từ'"]
# --------------------
# Results for 'xao xuyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'cô cậu': []
# --------------------
# Results for 'công tắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phạm luật': ["category2: 'Động từ'"]
# --------------------
# Results for 'công tơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sứ giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôi lứa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phóng đại': ["category2: 'Động từ'"]
# --------------------
# Results for 'rau câu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mềm dẻo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sinh quyển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự túc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôn thờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chết não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vây hãm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngất ngây': ["category3: 'Tính từ'"]
# --------------------
# Results for 'là hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'gọi vốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'dịch thuật': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiểu cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc chiếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân bản': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bao tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành kính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trăm nghìn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phồn vinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhen nhóm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thấp thoáng': ["category2: 'Động từ'"]
# --------------------
# Results for 'rượu trắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiêng ngả': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại lai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiết tấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mộc nhĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rau răm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chớp mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuột rút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhẫn nhịn': ["category2: 'Động từ'"]
# --------------------
# Results for 'duyên nợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân xác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thổ cư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiệp thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'ào ạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiểu ban': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thợ xây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoàng tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đương chức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phát quang': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'miệt thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyển tập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mỏi mệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'áo ấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá cơm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trượt băng': ["category2: 'Động từ'"]
# --------------------
# Results for 'công ước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ai ai': ["category7: 'Đại từ'"]
# --------------------
# Results for 'sôi sục': []
# --------------------
# Results for 'lên đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mua vui': ["category2: 'Động từ'"]
# --------------------
# Results for 'xong xuôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chẳng lẽ': []
# --------------------
# Results for 'bảng hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phốt pho': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh máy': ["category2: 'Động từ'"]
# --------------------
# Results for 'chồng lấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhẫn nại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắn dây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chợ phiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đề cương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hộ sinh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đô vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ổ khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoài luồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'uốn nắn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thái dương': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thiết nghĩ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kịch nói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh ý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cần câu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiệt quệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bởi thế': []
# --------------------
# Results for 'pháp chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quay vòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'quay cuồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hẳn hoi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biên đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiến cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'buông tha': ["category2: 'Động từ'"]
# --------------------
# Results for 'sổ mũi': ["category2: 'Động từ'"]
# --------------------
# Results for 'sang nhượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ào ào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vãng lai': ["category2: 'Động từ'"]
# --------------------
# Results for 'bóng bẩy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cam thảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiển hiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'tương ái': []
# --------------------
# Results for 'động từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giặt giũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tương trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngứa ngáy': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiện thân': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ăn liền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cước phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giám hộ': []
# --------------------
# Results for 'cầu toàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưới hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'muôn đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sức bền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'màu mè': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tổng lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giam cầm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phù phép': []
# --------------------
# Results for 'phân phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'di ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sứ quán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'tu sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sấm sét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mọi khi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khiêm nhường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh quy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ba gác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dỗ dành': ["category2: 'Động từ'"]
# --------------------
# Results for 'thai nghén': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nông nổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'cận thị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tươi rói': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phóng hoả': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhấn nhá': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầu từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dư chấn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm trò': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồi ức': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hổ thẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dôi dư': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thụt lùi': ["category2: 'Động từ'"]
# --------------------
# Results for 'là là': ["category2: 'Động từ'"]
# --------------------
# Results for 'làng chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trinh thám': ["category2: 'Động từ'", "category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cứu cánh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải trừ': []
# --------------------
# Results for 'biếm hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khổ luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'chạm mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh trừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính vụ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rậm rạp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đùm bọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'độ vĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ vựng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ma sát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'báo hiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao áp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá thu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần đảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quốc vương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mong ngóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc chủng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tinh chỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao vút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngữ văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xâm thực': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi tốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quang cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lẳng lặng': []
# --------------------
# Results for 'bù lỗ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cùng cực': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ghê rợn': []
# --------------------
# Results for 'trăng hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xương rồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường đua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cung cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hữu tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gây tê': ["category2: 'Động từ'"]
# --------------------
# Results for 'da trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thấp tầng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuộc cấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhợt nhạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thêu dệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'sản khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao khoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'mê đắm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạch hầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thí dụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ô mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'túc cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo an': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sử thi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chia ly': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư bản': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ngũ hành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thăm thú': ["category2: 'Động từ'"]
# --------------------
# Results for 'tương thân': []
# --------------------
# Results for 'ngộ nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'hớn hở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia tiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tường tận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tàn khốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lẫy lừng': []
# --------------------
# Results for 'tâm sức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ thỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặt vòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nô đùa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt thành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'án ngữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mua chuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mắng chửi': ["category2: 'Động từ'"]
# --------------------
# Results for 'luận điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiêu ngạo': []
# --------------------
# Results for 'đi đứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ý nguyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'dạo đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bay hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'rau ngót': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trượt giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trăm tuổi': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hỗn độn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ứng trực': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngòi nổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngữ pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cẩm nang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tụt dốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mũm mĩm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tập sự': ["category2: 'Động từ'"]
# --------------------
# Results for 'chạy nhảy': []
# --------------------
# Results for 'tắc kè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gái gọi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự cường': ["category2: 'Động từ'"]
# --------------------
# Results for 'y sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cách nhiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'câu khách': ["category2: 'Động từ'"]
# --------------------
# Results for 'đi khách': ["category2: 'Động từ'"]
# --------------------
# Results for 'bầu bí': []
# --------------------
# Results for 'khó nhọc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phụng sự': ["category2: 'Động từ'"]
# --------------------
# Results for 'khập khiễng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'niên thiếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'căn nguyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'râm ran': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiếu khách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chót vót': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hả hê': []
# --------------------
# Results for 'cứng đầu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sốt sắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vọng cổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áp giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'chua chát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàng cung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trầm ngâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'che kín': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhập ngoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiến quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ công': ["category3: 'Tính từ'"]
# --------------------
# Results for 'như chơi': []
# --------------------
# Results for 'nản chí': ["category2: 'Động từ'"]
# --------------------
# Results for 'lịch thiệp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gây gổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngẩn ngơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn mày': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trù phú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thầy bói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lá lốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạc nhẹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nôm na': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lão nông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng hộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mảy may': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nuông chiều': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh võng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưỡng lự': ["category2: 'Động từ'"]
# --------------------
# Results for 'lam lũ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cường kích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn mỹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cà ri': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xế chiều': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhỏ nhoi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chắc nịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lặt vặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân bình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ai lại': []
# --------------------
# Results for 'khảo nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'rỉ tai': ["category2: 'Động từ'"]
# --------------------
# Results for 'trực ban': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'rượu chè': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhảy nhót': ["category2: 'Động từ'"]
# --------------------
# Results for 'niên vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện áp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nàng thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thư sinh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'khói lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lọt thỏm': ["category2: 'Động từ'"]
# --------------------
# Results for 'công danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiền sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâu bền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khí huyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giọng điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dính dáng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự khán': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuộc tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lông mi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hải cẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đậu đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẫn thờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà chứa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buồn vui': []
# --------------------
# Results for 'phương cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay không': []
# --------------------
# Results for 'nhục nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nào ngờ': []
# --------------------
# Results for 'dầu lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tột độ': []
# --------------------
# Results for 'uốn ván': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất thế': ["category2: 'Động từ'"]
# --------------------
# Results for 'đảng uỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm ngư': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươm tất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cặp bồ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phát t': []
# --------------------
# Results for 'đơn cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường trường': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giá vốn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chênh vênh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quyền năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh nhai': ["category2: 'Động từ'"]
# --------------------
# Results for 'biến hình': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tinh khôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương xót': ["category2: 'Động từ'"]
# --------------------
# Results for 'tính khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thô lỗ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô thức': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'luật chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tăng ni': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra vẻ': []
# --------------------
# Results for 'phật thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'êm ấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tối tăm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nguyên sơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ẩn danh': []
# --------------------
# Results for 'công sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu siêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trợ lực': ["category2: 'Động từ'"]
# --------------------
# Results for 'lạ kỳ': []
# --------------------
# Results for 'trọng lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây bụi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gấu trúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dư âm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'dung túng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phi tần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồi đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'miệt vườn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thắng cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'làng xã': []
# --------------------
# Results for 'nền nã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'san ủi': ["category2: 'Động từ'"]
# --------------------
# Results for 'khu xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'đo đếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'cheo leo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gặm nhấm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bánh canh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'có thể': []
# --------------------
# Results for 'giảm phát': []
# --------------------
# Results for 'giẫm đạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'mắt kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giá sàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hù doạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giá trần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ quỹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trọng án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mờ ám': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vĩ độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chạy điện': ["category2: 'Động từ'"]
# --------------------
# Results for 'lùng sục': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngon ngọt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nắng gió': []
# --------------------
# Results for 'mở hàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cần tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần duyên': ["category2: 'Động từ'"]
# --------------------
# Results for 'qui hoạch': []
# --------------------
# Results for 'cách trở': ["category2: 'Động từ'"]
# --------------------
# Results for 'đùn đẩy': ["category2: 'Động từ'"]
# --------------------
# Results for 'giận hờn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hùng hồn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiệt hạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uể oải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lăn tăn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'na ná': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dĩ vãng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vua chúa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phục chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'mải miết': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm chủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh vệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh mảnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bí hiểm': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sinh lợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'luận điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc lào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thưởng nóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'gò bó': []
# --------------------
# Results for 'tảo hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàm ếch': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'công nương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'su hào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bát đĩa': []
# --------------------
# Results for 'hạ bệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sông ngòi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công nợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe ngựa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ham mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhan đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'y án': ["category2: 'Động từ'"]
# --------------------
# Results for 'con cả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiên ngang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trắng muốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trại hè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mã đề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điệu nghệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mốc giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hãi hùng': []
# --------------------
# Results for 'vị tha': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cổ chân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thử hỏi': []
# --------------------
# Results for 'lên đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'bão lụt': []
# --------------------
# Results for 'con nít': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo thù': ["category2: 'Động từ'"]
# --------------------
# Results for 'bon chen': ["category2: 'Động từ'"]
# --------------------
# Results for 'thắm thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'miễn sao': []
# --------------------
# Results for 'ngải cứu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt mày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mệt nhọc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đắng cay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đề bài': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngư nghiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tích góp': ["category2: 'Động từ'"]
# --------------------
# Results for 'khắc khoải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thông thái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cao bằng': []
# --------------------
# Results for 'xối xả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khấm khá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nằm mơ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt mệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'niềm nở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tử trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'giông bão': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công ơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụng dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xưng hô': ["category2: 'Động từ'"]
# --------------------
# Results for 'siêu nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ly tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'sứt mẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mãng cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoả tốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhờ vả': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhăn nheo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiêu bài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơm bữa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áo cưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dị nhân': []
# --------------------
# Results for 'câu kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'bọ cạp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chốc lát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghe ngóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'xương chậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dung nạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ở ẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngợi ca': ["category2: 'Động từ'"]
# --------------------
# Results for 'khẩu đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu an': ["category2: 'Động từ'"]
# --------------------
# Results for 'nữ công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tranh đấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'sánh đôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hùng biện': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà xác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đả kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu lạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường hàng': []
# --------------------
# Results for 'tức tưởi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn vận': []
# --------------------
# Results for 'hộ sản': []
# --------------------
# Results for 'miền xuôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉnh lẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồ thị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kẻ cướp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự lực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chín tới': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngợi khen': ["category2: 'Động từ'"]
# --------------------
# Results for 'gồ ghề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuỷ lôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bay lượn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ôm chầm': ["category2: 'Động từ'"]
# --------------------
# Results for 'gang thép': ["category3: 'Tính từ'"]
# --------------------
# ...
# --------------------
# Results for 'nước máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời cuộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phép tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đội lốt': ["category2: 'Động từ'"]
# --------------------
# Results for 'trần tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'già dặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cậu ấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'mười hai': []
# --------------------
# Results for 'cầm chắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngã ngũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao ngất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hồi môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'canh bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sa ngã': ["category2: 'Động từ'"]
# --------------------
# Results for 'đỡ đần': ["category2: 'Động từ'"]
# --------------------
# Results for 'bù trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quyết chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'phù trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lâm trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tá túc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mơ màng': []
# --------------------
# Results for 'vũ bão': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kếch xù': ["category3: 'Tính từ'"]
# --------------------
# Results for 'có chăng': []
# --------------------
# Results for 'liều mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'mách bảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắt cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'sử học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sao chổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vẹn toàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thất tình': []
# --------------------
# Results for 'chắt lọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất khuất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giãn nở': ["category2: 'Động từ'"]
# --------------------
# Results for 'đức tin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khéo tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tự thiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao thượng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thèm muốn': []
# --------------------
# Results for 'vượt cạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuỳ thích': ["category2: 'Động từ'"]
# --------------------
# Results for 'nuôi cấy': ["category2: 'Động từ'"]
# --------------------
# Results for 'bá chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoang vu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuyền buồm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dung nham': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỉ luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sự vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ẩm thấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sĩ diện': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt hảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cố hữu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu đá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tục tĩu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tài sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mờ ảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phù điêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tử vi': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mòn mỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'doạ nạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hớ hênh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bộ dạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'châu thổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạch lạc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'rạch ròi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đen ngòm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'toàn văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thái giám': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiêu đốt': ["category2: 'Động từ'"]
# --------------------
# Results for 'viễn tưởng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mềm mỏng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh bèo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vỡ lở': ["category2: 'Động từ'"]
# --------------------
# Results for 'xanh lam': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ê chề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dây dẫn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo nghĩ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xê dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'măng tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấm cửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngắm nghía': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhảy vọt': ["category2: 'Động từ'"]
# --------------------
# Results for 'kim hoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoang vắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đổ bể': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự tôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoả ước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vẻn vẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khiếm thính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chủ biên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấp dưỡng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vận hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vớ vẩn': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'sát khuẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chà xát': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp tiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xây xát': []
# --------------------
# Results for 'điên đảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thủ dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước lã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lực sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âu lo': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo liệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lũ ống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chắp cánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'vượt rào': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu uý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lan tràn': ["category2: 'Động từ'"]
# --------------------
# Results for 'khổ qua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc đạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'múa lân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thao trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gom góp': ["category2: 'Động từ'"]
# --------------------
# Results for 'diệu kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc mệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'siêu vi': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nể nang': ["category2: 'Động từ'"]
# --------------------
# Results for 'giáo lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tơi tả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giả sử': []
# --------------------
# Results for 'công nông': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thượng hạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yêu chiều': ["category2: 'Động từ'"]
# --------------------
# Results for 'thập kỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hanh thông': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thể diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tù tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'bún bò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chợ cóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áy náy': ["category2: 'Động từ'"]
# --------------------
# Results for 'siêng năng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đeo đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôm thẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ân tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'báo viết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thông gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ứng tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ dịch': []
# --------------------
# Results for 'trần trụi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân kỳ': ["category2: 'Động từ'"]
# --------------------
# Results for 'màu nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bắt chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'chua xót': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sa lầy': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạnh kiểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bông tai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn nguyên': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tủi nhục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chân giò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâng lâng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dây leo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh tinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vũ phu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tinh quái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chây ì': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt phẳng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mù tạt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đón dâu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quán xuyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'lão làng': []
# --------------------
# Results for 'thân thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tất tả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà quê': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phân quyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'diêm dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ tâm': []
# --------------------
# Results for 'châm cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồi truỵ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỳ ảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghị trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đỡ đẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'yên ả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dạy bảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'trái mùa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tạm trữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tất thảy': ["category7: 'Đại từ'"]
# --------------------
# Results for 'giáo hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rau diếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao kết': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'phi thuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sổ tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu liên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đi đêm': ["category2: 'Động từ'"]
# --------------------
# Results for 'hương hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiên âm': ["category2: 'Động từ'"]
# --------------------
# Results for 'kí kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'cằn nhằn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi mát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công quỹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cua đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'son phấn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiên chức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách thuỷ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'rắn lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quản giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yêu kiều': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lơ mơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lảng tránh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồn chồn': []
# --------------------
# Results for 'nhiệm sở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá trê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chèo lái': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'động tĩnh': []
# --------------------
# Results for 'gật gù': ["category2: 'Động từ'"]
# --------------------
# Results for 'làng mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'manh nha': ["category2: 'Động từ'"]
# --------------------
# Results for 'du mục': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thượng uý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mười lăm': []
# --------------------
# Results for 'nước màu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dòng tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàng th': []
# --------------------
# Results for 'phép thuật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dưới trướng': []
# --------------------
# Results for 'nức lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trúng độc': ["category2: 'Động từ'"]
# --------------------
# Final results have been saved to 7000word.json
