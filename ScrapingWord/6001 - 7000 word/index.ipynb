# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '6000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 6043

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 7000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'hình vẽ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỷ suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạ mi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồn cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiên lượng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'dày dạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vương triều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vượt ngục': ["category2: 'Động từ'"]
# --------------------
# Results for 'mù chữ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ái ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'gạo tẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa rời': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu hoả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngư trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miễn cưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'khai khoáng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tướng quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáo sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô ích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lưu huỳnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nấm mốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạnh nhạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vi chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tại gia': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tận thế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'điềm tĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nóng lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khai trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phải lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'qua loa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ổn thoả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sáng rực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngang ngửa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lãnh sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mẹ kế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tung hoành': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm ruộng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phũ phàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lành lặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cam chịu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lật ngược': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối trọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghị án': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'năng nổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ân xá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt nhiên': []
# --------------------
# Results for 'ăn vạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu may': ["category2: 'Động từ'"]
# --------------------
# Results for 'than vãn': ["category2: 'Động từ'"]
# --------------------
# Results for 'manh mún': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trung tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trình diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'vòi nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xoa bóp': ["category2: 'Động từ'"]
# --------------------
# Results for 'oi bức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lăng xê': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưỡng đoạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'bóp cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'minh mẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tẩy trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính đảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miên man': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính kiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồng hào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiệm cận': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân phố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng the': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nông lâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng ban': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt mũi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xơ gan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đỡ đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tri hô': ["category2: 'Động từ'"]
# --------------------
# Results for 'trí não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bấy lâu': ["category7: 'Đại từ'"]
# --------------------
# Results for 'trứ danh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sinh tử': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'di vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xương máu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ân ái': []
# --------------------
# Results for 'nuột nà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nứt nẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ca múa': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơm nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thấp thỏm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rắn độc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền túi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dòng điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính tả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạt tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'liên miên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ẩn nấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tín chỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sum họp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ôm ấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàm ý': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'dị đoan': []
# --------------------
# Results for 'hoang tàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'linh động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'du hành': []
# --------------------
# Results for 'mít tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ổ nhóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàn nhang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng quan': []
# --------------------
# Results for 'kháng thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'câu đối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tính chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'cực hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gieo cấy': ["category2: 'Động từ'"]
# --------------------
# Results for 'chê trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'thức tỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thạch cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoái khẩu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gian khó': []
# --------------------
# Results for 'điện lưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phe phái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ chung': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'luẩn quẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'an lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiêm nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'hời hợt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoá lỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đóng hộp': ["category2: 'Động từ'"]
# --------------------
# Results for 'quái ác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bồi bổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'rau màu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm vườn': ["category2: 'Động từ'"]
# --------------------
# Results for 'xanh tươi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trang nghiêm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lót tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'ổ đĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kho bãi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà nghề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn tiến': []
# --------------------
# Results for 'bao tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'hô hào': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'tích cóp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyện trò': ["category2: 'Động từ'"]
# --------------------
# Results for 'mai mối': ["category2: 'Động từ'"]
# --------------------
# Results for 'tại chức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quả cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tức thì': []
# --------------------
# Results for 'lạm thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lành tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'già yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chủ đích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con nợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáo phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rời rạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hơi hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gợi mở': ["category2: 'Động từ'"]
# --------------------
# Results for 'khởi nguồn': []
# --------------------
# Results for 'đối đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần mộ': []
# --------------------
# Results for 'đúng sai': []
# --------------------
# Results for 'bò sát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỏ bê': ["category2: 'Động từ'"]
# --------------------
# Results for 'báo giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'giai thoại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác ý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chào mời': ["category2: 'Động từ'"]
# --------------------
# Results for 'man rợ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thống lĩnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'lộng hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'lau chùi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cam go': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truyền thanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm nguyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạ thường': []
# --------------------
# Results for 'da giày': []
# --------------------
# Results for 'kỳ bí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiều hối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cả tin': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cô hồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vừa vặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghệ danh': []
# --------------------
# Results for 'phản pháo': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảnh thơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cai quản': ["category2: 'Động từ'"]
# --------------------
# Results for 'nóng giận': []
# --------------------
# Results for 'tự dưng': []
# --------------------
# Results for 'lay động': ["category2: 'Động từ'"]
# --------------------
# Results for 'rất đỗi': []
# --------------------
# Results for 'hạt dẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khiếm nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thôi thì': []
# --------------------
# Results for 'lăng nhăng': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lợi tiểu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ấm no': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khoe khoang': ["category2: 'Động từ'"]
# --------------------
# Results for 'đập tan': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời chiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giá rét': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trơn tru': ["category3: 'Tính từ'"]
# --------------------
# Results for 'con ruột': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phủ quyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'kêu ca': ["category2: 'Động từ'"]
# --------------------
# Results for 'chạy tàu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán dẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bẻ khoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'dày dặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xua tan': ["category2: 'Động từ'"]
# --------------------
# Results for 'căn dặn': ["category2: 'Động từ'"]
# --------------------
# Results for 'luận văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyển dạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên do': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sông suối': []
# --------------------
# Results for 'tác vụ': []
# --------------------
# Results for 'đầu nậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán độ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bí ngô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cư ngụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết tinh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 've chai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gang tấc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một tí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nương rẫy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếc thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuống giống': ["category2: 'Động từ'"]
# --------------------
# Results for 'buồn rầu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhỏ hẹp': []
# --------------------
# Results for 'đặc vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dư địa': []
# --------------------
# Results for 'trái lại': []
# --------------------
# Results for 'hồi tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dễ thở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cật lực': []
# --------------------
# Results for 'ngăn cấm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nề nếp': []
# --------------------
# Results for 'hoang tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'than đá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bãi tập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vững chãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỵ binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hộ tịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyện uỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nuốt chửng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'súp lơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều tiếng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khả ái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vùng biên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuồn chuồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chi chít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phủ đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất hủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buông xuôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vụ lợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'gai góc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cuồn cuộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường không': ["category1: 'Danh từ'"]
# --------------------
# Results for 'được mùa': ["category2: 'Động từ'"]
# --------------------
# Results for 'giờ giấc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ốm yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máy quét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bẩn thỉu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bóc lột': ["category2: 'Động từ'"]
# --------------------
# Results for 'dư lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xà cừ': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ly kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bình phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lánh nạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'liên hiệp': []
# --------------------
# Results for 'chí ít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sững sờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vạn vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'soi mói': ["category2: 'Động từ'"]
# --------------------
# Results for 'san sát': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bảnh bao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tài phiệt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàng đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cho xong': []
# --------------------
# Results for 'chẳng những': []
# --------------------
# Results for 'hồi âm': []
# --------------------
# Results for 'nh tr': []
# --------------------
# Results for 'giáo dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'già nua': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khốn đốn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nên thơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gốc rễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần đùi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đậu đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường biên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gió mùa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'riêng rẽ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ánh kim': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diệt chủng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp vốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết liễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôn kính': ["category2: 'Động từ'"]
# --------------------
# Results for 'thưởng ngoạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn ý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nền nếp': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'khai cuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúa mì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc bổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khăn gói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tồn dư': ["category2: 'Động từ'"]
# --------------------
# Results for 'móc nối': ["category2: 'Động từ'"]
# --------------------
# Results for 'dáng dấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'súng cối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn nhậu': ["category2: 'Động từ'"]
# --------------------
# Results for 'chông gai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại thắng': []
# --------------------
# Results for 'đặc trị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tài tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'danh bạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chạy chữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhạc phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thơ ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khô khan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lắp ghép': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường thẳng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lợn rừng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tròn trịa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'siêu cường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'rút ruột': ["category2: 'Động từ'"]
# --------------------
# Results for 'thổn thức': ["category2: 'Động từ'"]
# --------------------
# Results for 'chòm sao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nọc độc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chế giễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngóc ngách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'lý thú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chi hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bé bỏng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính hiệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nóng nảy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'liên đới': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô ý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ba mươi': []
# --------------------
# Results for 'phòng trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'một mạch': []
# --------------------
# Results for 'ho gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tơ lụa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dựng đứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tích tắc': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thân tình': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lòng thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gò má': ["category1: 'Danh từ'"]
# --------------------
# Results for 'võng mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn lưu': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu vùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lán trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình vuông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhan nhản': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiếu tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân ngũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoan hồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dược sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng nực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trông nom': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tung hô': ["category2: 'Động từ'"]
# --------------------
# Results for 'động kinh': []
# --------------------
# Results for 'trang nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thoả thích': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chức sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân nửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'anh cả': []
# --------------------
# Results for 'giếng khoan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắc phong': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuần thục': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tuỳ ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉnh giấc': ["category2: 'Động từ'"]
# --------------------
# Results for 'lừa gạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngang ngược': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cận cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao ráo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khó dễ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tật nguyền': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cha anh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ống nghiệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đột tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơn mài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà đàm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xói lở': ["category2: 'Động từ'"]
# --------------------
# Results for 'xác đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngang hàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phương thuốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhịp điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bổn phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'an nghỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ki ốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung uý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàn sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thực tại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà thuận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành uỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thổ dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần jean': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa lan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai hội': ["category2: 'Động từ'"]
# --------------------
# Results for 'lãng tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm lành': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ tết': []
# --------------------
# Results for 'đại ngàn': []
# --------------------
# Results for 'tôm sú': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trở tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'xông hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngon ăn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dương lịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp tốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đua tranh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bại trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'vui tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'du xuân': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm nhục': ["category2: 'Động từ'"]
# --------------------
# Results for 'mướp đắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyến nông': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồi lấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bình xịt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiếu thảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'từ trần': ["category2: 'Động từ'"]
# --------------------
# Results for 'uỷ nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'châm biếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xui xẻo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuyên canh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sắm vai': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến tranh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bí đao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giác quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao phối': ["category2: 'Động từ'"]
# --------------------
# Results for 'kho bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng loại': []
# --------------------
# Results for 'nói năng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường tồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cù lao': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tình địch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiệu lệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lượng tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'núp bóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'linh dương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tụ họp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nóng vội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khuôn mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tràn trề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thổi phồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cứu vớt': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặc công': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lu mờ': []
# --------------------
# Results for 'tống đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhạc công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhồi nhét': ["category2: 'Động từ'"]
# --------------------
# Results for 'vi trùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyên nhủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'phim nổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phóng thích': ["category2: 'Động từ'"]
# --------------------
# Results for 'mừng tuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'y hệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ma mị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thụ án': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngu ngốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cô chú': []
# --------------------
# Results for 'mộng mơ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưu mang': ["category2: 'Động từ'"]
# --------------------
# Results for 'đình chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kết dính': ["category2: 'Động từ'"]
# --------------------
# Results for 'thạc sỹ': []
# --------------------
# Results for 'che khuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'vun vén': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyên chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'nham nhở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kích dục': ["category2: 'Động từ'"]
# --------------------
# Results for 'chôm chôm': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bỏ mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ôn luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'bàn đạp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ hộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thôn bản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đổ máu': ["category2: 'Động từ'"]
# --------------------
# Results for 'pháp quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thể tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'đợi chờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'em út': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nổ mìn': ["category2: 'Động từ'"]
# --------------------
# Results for 'khắc khổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cơ mà': []
# --------------------
# Results for 'loanh quanh': []
# --------------------
# Results for 'làm luật': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưng chiều': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuất tất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máy sấy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truy tặng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ì ạch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đức tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'béo bở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiết tha': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ruột thịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tươi vui': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bề thế': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ngăn nắp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phối khí': ["category2: 'Động từ'"]
# --------------------
# Results for 'hợp lí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vốn liếng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vùi dập': ["category2: 'Động từ'"]
# --------------------
# Results for 'binh chủng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kể ra': []
# --------------------
# Results for 'dịch tễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động thổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'vừa lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'diễn thuyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'lung tung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giàn giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một hai': []
# --------------------
# Results for 'giận dỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thì thầm': []
# --------------------
# Results for 'đánh tiếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sắp sửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe kéo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làng xóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tức tốc': []
# --------------------
# Results for 'mắc cạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ vĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đệm bóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghiễm nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuất kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'quét dọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'trầm tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lừng lẫy': []
# --------------------
# Results for 'chân chất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khổ đau': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nội đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quần lót': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hận thù': []
# --------------------
# Results for 'to tát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mất cắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ao hồ': []
# --------------------
# Results for 'tri kỷ': []
# --------------------
# Results for 'xã viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khước từ': ["category2: 'Động từ'"]
# --------------------
# Results for 'áo choàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát giác': ["category2: 'Động từ'"]
# --------------------
# Results for 'trưởng Phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tháng giêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyền miệng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ấn hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'bỏ dở': ["category2: 'Động từ'"]
# --------------------
# Results for 'khôn lớn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngã ngửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'lục soát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh tú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quá độ': ["category2: 'Động từ'"]
# --------------------
# Results for 'động trời': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'mậu dịch': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vuốt ve': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra bộ': []
# --------------------
# Results for 'hiện thời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lột tả': ["category2: 'Động từ'"]
# --------------------
# Results for 'ước nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại bác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấu kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'đốt sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rủ rê': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ thực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca nô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bào chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'tục lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỷ yếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng nước': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tinh tuý': []
# --------------------
# Results for 'bọ gậy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vui buồn': []
# --------------------
# Results for 'xúi giục': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô bờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh tét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chơi bời': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăm chăm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phục trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vòi rồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lành nghề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'da gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thơm lừng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồng quê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huân chương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trà trộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bội chi': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạc đà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biến chất': ["category2: 'Động từ'"]
# --------------------
# Results for 'bận bịu': []
# --------------------
# Results for 'nha khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản vệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký gửi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thướt tha': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hào hoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nỗi lòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô hiệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tráng lệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thi ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt cắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhậu nhẹt': ["category2: 'Động từ'"]
# --------------------
# Results for 'trong vắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phác hoạ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bóng chày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoài cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chợ nổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tán thưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nữ quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tẻ nhạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chỉ giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pho mát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tung tăng': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy luận': []
# --------------------
# Results for 'cử hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân tiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vỏ chai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáng sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'xi lanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đem lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sử sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chẳng qua': []
# --------------------
# Results for 'ba ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phúc khảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'huy hoàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tinh chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trong veo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuất chúng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dẫn giải': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đỏ đen': []
# --------------------
# Results for 'sống mũi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nông trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngùn ngụt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lộ thiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'săn tìm': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm chứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chối cãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'lại sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm lí': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hợp xướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiếu động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tôn chỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lễ phép': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thuộc lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phù nề': []
# --------------------
# Results for 'bến tàu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sử gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngay ngắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'băng thông': []
# --------------------
# Results for 'biện hộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dưỡng lão': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự ái': ["category2: 'Động từ'"]
# --------------------
# Results for 'sát trùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phương trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thổ nhưỡng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áp giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'ma trận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngũ quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'canh giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'im ắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ký sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy chiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoái cảm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu cung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạ miệng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kế cận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quậy phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'sừng sững': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thô tục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dìu dắt': []
# --------------------
# Results for 'sung mãn': ["category3: 'Tính từ'"]
# --------------------
# ...
# --------------------
# Results for 'dị dạng': []
# --------------------
# Results for 'lai tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'dù rằng': []
# --------------------
# Results for 'vùng đệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sỉ nhục': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nằm xuống': ["category2: 'Động từ'"]
# --------------------
# Results for 'nô nức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nuôi nấng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăn thả': ["category2: 'Động từ'"]
# --------------------
# Results for 'cực khổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tổng duyệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'tì vết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rộn rã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tay ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuỷ văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tường bao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'n tính': []
# --------------------
# Results for 'kín mít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thị giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhàn rỗi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giáo phái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vương vãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân sâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngày trước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoát vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'sư phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tù treo': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguôi ngoai': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xoay chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'thánh đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'axit amin': []
# --------------------
# Results for 'hộp thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'song ngữ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia trưởng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lô cốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghĩa cử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điệp khúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hố ga': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bức thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc nam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sự thân': []
# --------------------
# Results for 'lạng lách': ["category2: 'Động từ'"]
# --------------------
# Results for 'hò hét': ["category2: 'Động từ'"]
# --------------------
# Results for 'an cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'hao hụt': ["category2: 'Động từ'"]
# --------------------
# Results for 'vi lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường trục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu loại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tay áo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vi mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu kì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sĩ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng nội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay đôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ỷ lại': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngõ ngách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thấm đẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nồng ấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quan lại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngượng ngùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đùa giỡn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuy vậy': []
# --------------------
# Results for 'chu trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay trắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh hãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngọc nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sự vụ': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chập chững': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gạ gẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'mù loà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lạc lõng': []
# --------------------
# Results for 'cá cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản lề': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội họp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắn răng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dựa dẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất trắc': []
# --------------------
# Results for 'thông đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nặc danh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thảm bại': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trống rỗng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'không khéo': []
# --------------------
# Results for 'thù hận': []
# --------------------
# Results for 'bồ nhí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'mở mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'triệt hạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy tư': []
# --------------------
# Results for 'ngoại vi': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bánh xèo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lai dắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhẫn cưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'li ti': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'chìm đắm': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiện tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công thần': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ứ đọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trìu mến': []
# --------------------
# Results for 'quyền Anh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trau chuốt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ ngơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'la ó': ["category2: 'Động từ'"]
# --------------------
# Results for 'hủ tục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mì chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại tiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'reo hò': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân xưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giảm tốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thìa canh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh dịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạch kim': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cướp bóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'sống chết': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên tác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'binh lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra vào': []
# --------------------
# Results for 'bạn hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ùn ùn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'này khác': ["category7: 'Đại từ'"]
# --------------------
# Results for 'phấn chấn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ước muốn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cao thấp': []
# --------------------
# Results for 'gào thét': ["category2: 'Động từ'"]
# --------------------
# Results for 'hết mức': []
# --------------------
# Results for 'bào mòn': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy điệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'con thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gần xa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dư dả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bún chả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giảm xóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhào lộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'kìm nén': ["category2: 'Động từ'"]
# --------------------
# Results for 'rau má': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáng ra': []
# --------------------
# Results for 'sư thầy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thua thiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'khí chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô cơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khấu hao': ["category2: 'Động từ'"]
# --------------------
# Results for 'pháo thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước khoáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vị giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chất chứa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhuận bút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phong lan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sung sức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia tốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bày biện': ["category2: 'Động từ'"]
# --------------------
# Results for 'ông cha': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mê hồn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thả lỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa phùn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạch cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại xâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'niên hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồi hoàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuất ngũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh số': ["category2: 'Động từ'"]
# --------------------
# Results for 'tu dưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao to': []
# --------------------
# Results for 'bi thảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quyền anh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kí ức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại tu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàn ác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biên cương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khổ cực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuỷ sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'úng ngập': ["category2: 'Động từ'"]
# --------------------
# Results for 'huy hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rốt ráo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kéo co': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tán dương': ["category2: 'Động từ'"]
# --------------------
# Results for 'khứ hồi': []
# --------------------
# Results for 'tạo hoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điềm đạm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gấp gáp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuyên giáo': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nháy mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bếp núc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sát nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'bão tuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đậm đặc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nếm trải': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mất mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'qui mô': []
# --------------------
# Results for 'đánh đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao thế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hừng hực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khởi phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'xì dầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bệnh hoạn': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phụ tải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiếu chiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trống trải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghĩa đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kĩ lưỡng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ma quái': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hi hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoa lá': ["category1: 'Danh từ'", "category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đường hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vùng vẫy': ["category2: 'Động từ'"]
# --------------------
# Results for 'mở mang': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoan dung': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiểu tiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'buồn phiền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đông đủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mặc nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phóng sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sai số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bà già': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chơi xấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đê biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trống đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thầy cúng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phảng phất': ["category2: 'Động từ'"]
# --------------------
# Results for 'phá giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'lác đác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hờ hững': ["category3: 'Tính từ'"]
# --------------------
# Final results have been saved to 6000word.json
