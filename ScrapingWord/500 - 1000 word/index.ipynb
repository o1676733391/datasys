# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '500word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 501

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 1001):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'hội nghị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiến dịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bối cảnh': []
# --------------------
# Results for 'đổi mới': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giúp đỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kêu gọi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đời sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo lắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nông dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính xác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'miêu tả': ["category2: 'Động từ'"]
# --------------------
# Results for 'đàm phán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tương đương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dữ liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kết luận': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quan chức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động cơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áp lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hơn nữa': []
# --------------------
# Results for 'bắt giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'như thế': []
# --------------------
# Results for 'tuyên truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'chế biến': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'xu hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huy động': ["category2: 'Động từ'"]
# --------------------
# Results for 'cà phê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp theo': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiêu thụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh tra': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lãi suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiến nghị': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tâm lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất bại': []
# --------------------
# Results for 'phát huy': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên môn': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chiến tranh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tác dụng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'giải trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'vệ sinh': ["category1: 'Danh từ'", "category3: 'Tính từ'", "category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'chặt chẽ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trật tự': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'sinh hoạt': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'căng thẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phản ứng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nổi bật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tình huống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bầu cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'doanh thu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'liên tiếp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuyên nghiệp': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tổng số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phức tạp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'không khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thử nghiệm': []
# --------------------
# Results for 'giải thưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chung cư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo diễn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tổng hợp': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trình diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chứng kiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'có lẽ': []
# --------------------
# Results for 'mới đây': []
# --------------------
# Results for 'phê duyệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'bức xúc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gương mặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngăn chặn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng chí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải thích': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiến thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự tin': ["category2: 'Động từ'"]
# --------------------
# Results for 'bền vững': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tài khoản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ tịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phẫu thuật': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cấp cứu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lái xe': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lễ hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ huynh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp lý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tốt nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ chối': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'đăng tải': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mức độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu quả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ trương': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tiếp nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'trái phép': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cha mẹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năm ngoái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vận hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'trụ sở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cuộc đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nâng cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bố trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ưu tiên': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lên tiếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm xúc': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'mặc dù': []
# --------------------
# Results for 'vì vậy': []
# --------------------
# Results for 'thảo luận': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy nghĩ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đẩy mạnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tác giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiện tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà bình': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tài xế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tập đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bà con': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xinh đẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần mềm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sức mạnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn biến': []
# --------------------
# Results for 'chủ đề': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thú vị': []
# --------------------
# Results for 'tình dục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị xã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trải nghiệm': []
# --------------------
# Results for 'kinh phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáng kể': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tín dụng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giám đốc': []
# --------------------
# Results for 'phản đối': ["category2: 'Động từ'"]
# --------------------
# Results for 'tính năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chấn thương': []
# --------------------
# Results for 'mặt hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ô nhiễm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế kỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lo ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham nhũng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khảo sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời tiết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thay vì': []
# --------------------
# Results for 'thống kê': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quyết tâm': []
# --------------------
# Results for 'công nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'độc đáo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phong trào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vì thế': []
# --------------------
# Results for 'thách thức': []
# --------------------
# Results for 'tập thể': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tiến độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự báo': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân cư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyệt vời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bao nhiêu': ["category7: 'Đại từ'"]
# --------------------
# Results for 'văn phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình luận': ["category2: 'Động từ'"]
# --------------------
# Results for 'dường như': []
# --------------------
# Results for 'thiệt mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cư dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng minh': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quy trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'người mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẩm quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ý tưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thức ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rà soát': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồi thường': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỹ năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mua bán': ["category2: 'Động từ'"]
# --------------------
# Results for 'xử phạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'lãnh thổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khổng lồ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sửa đổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đội ngũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỷ lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di động': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền vệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một vài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguồn gốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc lập': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'công suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toàn quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'màu sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'anh em': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miễn phí': ["category2: 'Động từ'"]
# --------------------
# Results for 'công dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rủi ro': []
# --------------------
# Results for 'hạ tầng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải phóng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đồng hồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoải mái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'người yêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt bằng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chia tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn diện': []
# --------------------
# Results for 'nhà hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phần lớn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khác biệt': []
# --------------------
# Results for 'tiếp xúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh sống': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chị em': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trực tuyến': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đường sắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xếp hạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại giao': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'chuyển nhượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'quần áo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học trò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xét xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'trình độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sửa chữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm sự': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đòi hỏi': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'kỷ luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dinh dưỡng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cập nhật': []
# --------------------
# Results for 'nguyên liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lúc nào': ["category7: 'Đại từ'"]
# --------------------
# Results for 'tin tưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiềm năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhận thức': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'huấn luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'di tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công chúng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bổ nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ trích': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uy tín': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quan sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ cấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cáo buộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tham quan': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đam mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời hạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cuộc chiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mua sắm': ["category2: 'Động từ'"]
# --------------------
# Results for 'địa chỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiệm kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bí mật': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nói chuyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàng không': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tranh chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuyến khích': ["category2: 'Động từ'"]
# --------------------
# Results for 'sau này': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn uống': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách mạng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'pháp lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khủng hoảng': []
# --------------------
# Results for 'liên lạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiêu chí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'cải cách': []
# --------------------
# Results for 'kết hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ vọng': []
# --------------------
# Results for 'bàn giao': ["category2: 'Động từ'"]
# --------------------
# Results for 'định hướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thi hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổng thống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phỏng vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chấm dứt': ["category2: 'Động từ'"]
# --------------------
# Results for 'phòng chống': ["category2: 'Động từ'"]
# --------------------
# Results for 'thật sự': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tố cáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhận xét': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chuyển đổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhất định': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yêu thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'luật sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vui vẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xe tải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiến trúc': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nói chung': []
# --------------------
# Results for 'nền tảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sai phạm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đồng nghiệp': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vào khoảng': []
# --------------------
# Results for 'nguyên tắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao lưu': []
# --------------------
# Results for 'triển lãm': []
# --------------------
# Results for 'đi lại': ["category2: 'Động từ'"]
# --------------------
# Results for 'công chức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khởi tố': ["category2: 'Động từ'"]
# --------------------
# Results for 'trọng tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trừng phạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiệu lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hôn nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thói quen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động viên': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu thông': ["category2: 'Động từ'"]
# --------------------
# Results for 'công cộng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thế này': []
# --------------------
# Results for 'dẫn đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'tính toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'giấy phép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'họp báo': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà thầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự hào': []
# --------------------
# Results for 'vật liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâu dài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vào cuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghiêm túc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dự thảo': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tiêu cực': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đại gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hài lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lợi thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vùng biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chờ đợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuyết phục': []
# --------------------
# Results for 'tỷ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chỉ huy': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tốt đẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên nhiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khí hậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điện ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một chút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đám cưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiết lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'quyết liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấu tranh': []
# --------------------
# Results for 'liên hệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chế tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm ơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'phạm vi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ trì': ["category2: 'Động từ'"]
# --------------------
# Results for 'biểu hiện': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đa dạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngư dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ý thức': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'kể cả': []
# --------------------
# Results for 'nhân lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tập luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'có vẻ': []
# --------------------
# Results for 'bình quân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thông thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đội hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sự thật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn tất': ["category2: 'Động từ'"]
# --------------------
# Results for 'cử tri': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trưởng thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ thuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàu ngầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giấy tờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'can thiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ưu đãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vất vả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tại sao': []
# --------------------
# Results for 'bảo hiểm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nhà báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khối lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xác minh': ["category2: 'Động từ'"]
# --------------------
# Results for 'hôm qua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mâu thuẫn': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'làm sao': []
# --------------------
# Results for 'ý định': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghi ngờ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhẹ nhàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xin lỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'mệt mỏi': []
# --------------------
# Results for 'định cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng bào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh bại': ["category2: 'Động từ'"]
# --------------------
# Results for 'đạo đức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạp chí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạc sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai mạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'ánh sáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổn thương': []
# --------------------
# Results for 'tranh cãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'khoảng cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo tồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sắp xếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'giảm giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'gặp gỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'giám khảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quyền lợi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năm học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xung đột': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'biểu tình': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyển sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'phiên toà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chứng khoán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vỉa hè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kích thước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thưởng thức': ["category2: 'Động từ'"]
# --------------------
# Results for 'cải tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoàn hảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thái độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gắn bó': []
# --------------------
# Results for 'chủ quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khẩn cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đóng cửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'tận dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ghi bàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'lần lượt': []
# --------------------
# Results for 'bất thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngược lại': []
# --------------------
# Results for 'số liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khám phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối phương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tôn trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tế bào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'động lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quảng bá': ["category2: 'Động từ'"]
# --------------------
# Results for 'công cụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trò chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiên liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đề cập': ["category2: 'Động từ'"]
# --------------------
# Results for 'biến đổi': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'buôn bán': ["category2: 'Động từ'"]
# --------------------
# Results for 'quen thuộc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chức vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tên tuổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực kỳ': []
# --------------------
# Results for 'đồng bộ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đất đai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự đoán': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'loại bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất tích': ["category2: 'Động từ'"]
# --------------------
# Results for 'doanh nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nặng nề': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chăn nuôi': []
# --------------------
# Results for 'sang trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc trưng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tích hợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cân bằng': ["category3: 'Tính từ'", "category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'một mình': []
# --------------------
# Results for 'sai lầm': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quyền lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạng mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán kết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dứt điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xứng đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quyến rũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'rộng rãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quê hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoá chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sâu sắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phát sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'giới hạn': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'biệt thự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạo lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tín hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sạt lở': ["category2: 'Động từ'"]
# --------------------
# Results for 'tin đồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trưng bày': ["category2: 'Động từ'"]
# --------------------
# Results for 'phục hồi': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe buýt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tăng giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiểu học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chú trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'theo đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'mở cửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuân thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguồn lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hư hỏng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đối đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đoàn kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội thảo': []
# --------------------
# Results for 'độc giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biểu tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trái tim': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuôn khổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'củng cố': ["category2: 'Động từ'"]
# --------------------
# Results for 'ví dụ': []
# --------------------
# Final results have been saved to 500word.json
