# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '8000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 8042

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 9000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'đồng áng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'băng dính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dễ tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhảm nhí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuỷ sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cắt xén': ["category2: 'Động từ'"]
# --------------------
# Results for 'sát nút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xù xì': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh tráo': ["category2: 'Động từ'"]
# --------------------
# Results for 'biểu đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chết yểu': ["category2: 'Động từ'"]
# --------------------
# Results for 'vay lãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngân quỹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chật cứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cà tím': ["category1: 'Danh từ'"]
# --------------------
# Results for 'u xơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tao nhã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giai nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một hơi': []
# --------------------
# Results for 'dòng dõi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mát tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chất phác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ôn đới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn sắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yến sào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ tốn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trấn giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nực cười': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bé con': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trí óc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giác ngộ': []
# --------------------
# Results for 'cú pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh cảm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quyết thắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm lụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'gập ghềnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bốc đồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bác học': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'mỹ mãn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lố bịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhớ nhung': ["category2: 'Động từ'"]
# --------------------
# Results for 'dáng vóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mâm xôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'túi mật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hòm thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hải tặc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu luyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'an nhàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thầy lang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vẹn nguyên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'y dược': []
# --------------------
# Results for 'tơ tằm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vạm vỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khêu gợi': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'áp chót': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thong thả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu đàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngờ vực': ["category2: 'Động từ'"]
# --------------------
# Results for 'lão luyện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gieo rắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'kính râm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hối lỗi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vĩ tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dung tục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cách âm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thác loạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giao hợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tức tối': []
# --------------------
# Results for 'trông cậy': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giàu mạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giao kèo': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'thơm phức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lênh láng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ thiên': ["category2: 'Động từ'"]
# --------------------
# Results for 'độ pH': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truy vấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thân mến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mây mưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'inh ỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đại tướng': []
# --------------------
# Results for 'gia sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền nong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'áp phích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vũ đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mừng rỡ': []
# --------------------
# Results for 'cưỡng ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'thâm tâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chan hoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'cứu mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cỏ cây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cân não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tua rua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lộ liễu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ bi': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'xóm làng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tước đoạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngập ngừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp lời': ["category2: 'Động từ'"]
# --------------------
# Results for 'quân lính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'goá phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đinh lăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'húng quế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quản thúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ước vọng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ngũ sắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'không trách': []
# --------------------
# Results for 'viễn chinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thấm nhuần': ["category2: 'Động từ'"]
# --------------------
# Results for 'dưỡng sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuốc mê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dửng dưng': []
# --------------------
# Results for 'thuốc thang': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'quyết đấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh cược': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyết thanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường thi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguỵ biện': ["category2: 'Động từ'"]
# --------------------
# Results for 'xập xệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'từ mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ruột non': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tháng chạp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉ mẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cà vạt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thính giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mê cung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh vần': ["category2: 'Động từ'"]
# --------------------
# Results for 'đanh đá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ấu thơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân cách': ["category2: 'Động từ'"]
# --------------------
# Results for 'vòng hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sẩy thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'thả nổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'lá sen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dữ dằn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máy cày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa tai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thảm thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ắt hẳn': []
# --------------------
# Results for 'giấy bạc': []
# --------------------
# Results for 'cổng chào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàn the': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giáo xứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nằng nặc': []
# --------------------
# Results for 'đi cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạo bệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vũ nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khăng khít': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cãi cọ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trợ thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lắc lư': ["category2: 'Động từ'"]
# --------------------
# Results for 'phù dâu': []
# --------------------
# Results for 'nông hộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiện cáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'máy gặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biên nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'bụ bẫm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khuyên can': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng nát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'báo thức': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoăn thoắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiểu cách': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cá lăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảm tưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'căm ghét': ["category2: 'Động từ'"]
# --------------------
# Results for 'bốc xếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bào ngư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cúng bái': ["category2: 'Động từ'"]
# --------------------
# Results for 'võ công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoảng hồn': []
# --------------------
# Results for 'tận diệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chửi rủa': ["category2: 'Động từ'"]
# --------------------
# Results for 'loè loẹt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đổ bệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'là lạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bao hàm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước lợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'niệu đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp viện': ["category2: 'Động từ'"]
# --------------------
# Results for 'đá gà': []
# --------------------
# Results for 'phế phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lẩn tránh': ["category2: 'Động từ'"]
# --------------------
# Results for 'quên mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'chế nhạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biển thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ganh đua': ["category2: 'Động từ'"]
# --------------------
# Results for 'học vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài phán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tránh né': ["category2: 'Động từ'"]
# --------------------
# Results for 'độc đoán': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lứa đôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiếm hữu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lập dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mồ mả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự thú': ["category2: 'Động từ'"]
# --------------------
# Results for 'sần sùi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biến thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hun hút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành bại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tối thượng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nối ngôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'khả dĩ': []
# --------------------
# Results for 'sát phạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'bài làm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh thời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vi vu': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thiểu năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồ lô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân thọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'oái oăm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'oanh kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'sền sệt': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'máy kéo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phó mặc': ["category2: 'Động từ'"]
# --------------------
# Results for 'múa rối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xinh tươi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mục nát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kháng án': ["category2: 'Động từ'"]
# --------------------
# Results for 'áp bức': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành lễ': []
# --------------------
# Results for 'ăn đủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sợ sệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'kinh qua': ["category2: 'Động từ'"]
# --------------------
# Results for 'âm phủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẳng tắp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đắm đuối': ["category2: 'Động từ'"]
# --------------------
# Results for 'tư sản': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nghĩ ngợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'lăn xả': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ cục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chè xanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lương bổng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thèm khát': ["category2: 'Động từ'"]
# --------------------
# Results for 'văn xuôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉnh lỵ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đội giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàu xe': []
# --------------------
# Results for 'nhựa đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gia thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thỏi son': []
# --------------------
# Results for 'bình lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh bạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tăm tối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tàu bè': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xã luận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân tín': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vỡ mộng': ["category2: 'Động từ'"]
# --------------------
# Results for 'án tích': []
# --------------------
# Results for 'cá nóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thịnh nộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chứng thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tá tràng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ân oán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bãi thải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuần lộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lầm lũi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hối cải': ["category2: 'Động từ'"]
# --------------------
# Results for 'con rối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chán chường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải sâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chằm chằm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngưng trệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cờ tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'êm đẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phai nhạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ canh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'co ro': ["category2: 'Động từ'"]
# --------------------
# Results for 'ái quốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn chia': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguồn cội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiền muộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bọ xít': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quy cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đông du': ["category2: 'Động từ'"]
# --------------------
# Results for 'dột nát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chăm bón': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường thọ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách mạng': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thấp điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngòi bút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phối trộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'mục sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'non sông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'oanh liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngự trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'dù vậy': []
# --------------------
# Results for 'hoa lệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'loang lổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dung môi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạm cư': ["category2: 'Động từ'"]
# --------------------
# Results for 'coi nhẹ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy củ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhớ đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'thạch anh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'múi giờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nửa vời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lọt lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dè bỉu': ["category2: 'Động từ'"]
# --------------------
# Results for 'phố thị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thúc ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'đá phiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bùi ngùi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dung dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầm phá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chu vi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồn điền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyên bảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cố chấp': []
# --------------------
# Results for 'cốt yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền giấy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xông đất': ["category2: 'Động từ'"]
# --------------------
# Results for 'dăm ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hưng thịnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phút chốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đông nghịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoa đăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo bối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rối ren': []
# --------------------
# Results for 'bốc dỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu nhớt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính ngạch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'văng tục': ["category2: 'Động từ'"]
# --------------------
# Results for 'phối màu': ["category2: 'Động từ'"]
# --------------------
# Results for 'cay nghiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ước ao': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội hàm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'hà mã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi thố': ["category2: 'Động từ'"]
# --------------------
# Results for 'buông thả': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngăn kéo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôi co': ["category2: 'Động từ'"]
# --------------------
# Results for 'xanh xao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vàng son': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa xăm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu đọc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc sâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cải chính': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân th': []
# --------------------
# Results for 'lụp xụp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lính dù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quản ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhuận tràng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhòm ngó': ["category2: 'Động từ'"]
# --------------------
# Results for 'dục vọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tôn nghiêm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thanh tịnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xì gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đám ma': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ứng biến': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến hữu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'li dị': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoái vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyển quân': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường cát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rượu cần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bổ túc': ["category2: 'Động từ'"]
# --------------------
# Results for 'mẫu đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bướng bỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hưởng thọ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm trịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'xà bông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nặng trĩu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đố kỵ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm quan': []
# --------------------
# Results for 'nh thánh': []
# --------------------
# Results for 'nghịch cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạch tạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mưu trí': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'địa lan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành tài': ["category2: 'Động từ'"]
# --------------------
# Results for 'xoắn ốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhấp nháy': ["category2: 'Động từ'"]
# --------------------
# Results for 'thôn tính': ["category2: 'Động từ'"]
# --------------------
# Results for 'lá cải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'oán trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỹ tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chi đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân chủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rối rắm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quen mặt': []
# --------------------
# Results for 'đất nung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'hương khói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cải trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'sa đà': ["category2: 'Động từ'"]
# --------------------
# Results for 'thính giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước mũi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con bài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình thật': []
# --------------------
# Results for 'sít sao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đèn chiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vớt vát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu phục': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'cắm sừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bát hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưỡng cư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thờ phụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhỏ nhẹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kêu trời': ["category2: 'Động từ'"]
# --------------------
# Results for 'dịch viên': []
# --------------------
# Results for 'ống khói': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bi thương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'pháp sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên hồi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoa giấy': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trạm xá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rắn chắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân tách': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lò sưởi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hảo hạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vốn sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kĩ sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghét bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trinh nữ': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'dịch tả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đâm ra': ["category2: 'Động từ'"]
# --------------------
# Results for 'thính phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tôm cá': []
# --------------------
# Results for 'mở miệng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đường nhựa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc đắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô hồn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quần quật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lá ngón': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biệt tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa xa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bại lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đất đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quai bị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phù du': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóc mẽ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội ý': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đóng khung': ["category2: 'Động từ'"]
# --------------------
# Results for 'tang thương': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chánh án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kĩ càng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thú thật': ["category2: 'Động từ'"]
# --------------------
# Results for 'tán loạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tế lễ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chạy vạy': ["category2: 'Động từ'"]
# --------------------
# Results for 'ủ trắng': []
# --------------------
# Results for 'phân liệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'xem bói': ["category2: 'Động từ'"]
# --------------------
# Results for 'bức bối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghe nhìn': []
# --------------------
# Results for 'ái tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyền kỳ': []
# --------------------
# Results for 'bàn là': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chưng cất': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngốc nghếch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xanh ngắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hải trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng chảy': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'che lấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'năm mươi': []
# --------------------
# Results for 'liều mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'gốc gác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đây đó': ["category7: 'Đại từ'"]
# --------------------
# Results for 'ước mong': []
# --------------------
# Results for 'diệt vong': ["category2: 'Động từ'"]
# --------------------
# Results for 'qui trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tan tành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hầm lò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lùi bước': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất biến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'săn đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoa mỹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'dị thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lợi suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lanh lợi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiều tuỵ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhăn nhó': []
# --------------------
# Results for 'hát hò': ["category2: 'Động từ'"]
# --------------------
# Results for 'chữ nghĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tập dượt': ["category2: 'Động từ'"]
# --------------------
# Results for 'bước sóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoan cố': ["category3: 'Tính từ'"]
# --------------------
# Results for 'môn sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'linh đình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngân hà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cẳng tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lãi ròng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chức quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thầm kín': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phỉ báng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tranh ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hắt hủi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội thao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biên lai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỏ tù': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyệt mỹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xâm lăng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hip hop': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghê tởm': []
# --------------------
# Results for 'gắng sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'kính yêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩm mốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khai trường': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bình phẩm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ốc sên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dương cầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vĩnh hằng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thị chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngông cuồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuần hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'du dương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tụ hội': ["category2: 'Động từ'"]
# --------------------
# Results for 'như không': []
# --------------------
# Results for 'bão tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mánh khoé': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'to đùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tàn tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gió bão': []
# --------------------
# Results for 'binh đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất minh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lương duyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hệ trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'diệt trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đằng đẵng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cửa mở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bầu bĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dùi cui': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiện chiến': ["category3: 'Tính từ'"]
# --------------------
# Results for 'loạng choạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô cực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'e ấp': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'khuếch tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tặc lưỡi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đốc thúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'võ sỹ': []
# --------------------
# Results for 'xoá nhoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'dồn nén': ["category2: 'Động từ'"]
# --------------------
# Results for 'đìu hiu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công nghệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lấm lem': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngây ngất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đúc rút': ["category2: 'Động từ'"]
# --------------------
# Results for 'chí mạng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thải loại': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhỏ con': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mai phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'ác cảm': []
# --------------------
# Results for 'muôn thuở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mập mạp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thứ thiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quằn quại': ["category2: 'Động từ'"]
# --------------------
# Results for 'trai tráng': []
# --------------------
# Results for 'bốn phương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công hàm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuyên chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'án từ': []
# --------------------
# Results for 'lăng kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'náo nức': ["category2: 'Động từ'"]
# --------------------
# Results for 'vươn mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhanh trí': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kín kẽ': []
# --------------------
# Results for 'tổng chi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xây cất': ["category2: 'Động từ'"]
# --------------------
# Results for 'liệt dương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính nghĩa': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'uy nghi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sào huyệt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngắt quãng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chơi trội': ["category2: 'Động từ'"]
# --------------------
# Results for 'thách đố': ["category2: 'Động từ'"]
# --------------------
# Results for 'vụng trộm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chở che': ["category2: 'Động từ'"]
# --------------------
# Results for 'ga lăng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lâm bệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạch đàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngày mùa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi hào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm u': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vu vơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cử chức': []
# --------------------
# Results for 'măng cụt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quát mắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nem chua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'coi chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyệt phẩm': []
# --------------------
# Results for 'độ kinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lái buôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đỗ quyên': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'kế tục': ["category2: 'Động từ'"]
# --------------------
# Results for 'biến thiên': ["category2: 'Động từ'"]
# --------------------
# Results for 'y đức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xiêu lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đẹp đôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'diễn xướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô chủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thất sủng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chịu trận': ["category2: 'Động từ'"]
# --------------------
# Results for 'mường tượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trộm cướp': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thánh thiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đua đòi': ["category2: 'Động từ'"]
# --------------------
# Results for 'trăng mật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tước hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô bổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hậu thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bụng dưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kết mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chút xíu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cắt lớp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'xảo quyệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiễu loạn': []
# --------------------
# Results for 'viết lách': ["category2: 'Động từ'"]
# --------------------
# Results for 'lái đò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buộc lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kia mà': []
# --------------------
# Results for 'nha sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiệp đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tứ quý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lân la': ["category2: 'Động từ'"]
# --------------------
# Results for 'thủ tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'văn thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thứ ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tia sáng': []
# --------------------
# Results for 'nguội lạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hạ nguồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc tôn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cảm thụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm mù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'duyên số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đớn đau': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gọi là': []
# --------------------
# Results for 'muối mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thu ngân': ["category2: 'Động từ'"]
# --------------------
# Results for 'chua chua': []
# --------------------
# Results for 'ngạo mạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nguyên văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bệnh phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh gục': ["category2: 'Động từ'"]
# --------------------
# Results for 'màn bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự khắc': []
# --------------------
# Results for 'lợn nái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàn độc': []
# --------------------
# Results for 'hoà thượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đâm chém': ["category2: 'Động từ'"]
# --------------------
# Results for 'đàm tiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'rau cần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bưu kiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'như ai': []
# --------------------
# Results for 'đen kịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dưỡng sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'vuông vức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngọc bích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chông chênh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phát lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lặng im': []
# --------------------
# Results for 'cung nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất thanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bất nhất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đạn xuyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lao công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh niên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầu phao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bắp tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đùa nghịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'cào bằng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật học': []
# --------------------
# Results for 'cay cú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tham số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm mướn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nồng hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đấm đá': ["category2: 'Động từ'"]
# --------------------
# Results for 'giáp mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại loại': []
# --------------------
# Results for 'dân cử': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn đường': ["category2: 'Động từ'"]
# --------------------
# Results for 'đậu hũ': ["category1: 'Danh từ'"]
# ...
# --------------------
# Results for 'quân chủng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá đuối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bến thuỷ': []
# --------------------
# Results for 'thắng thế': ["category2: 'Động từ'"]
# --------------------
# Results for 'số mệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngấm ngầm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thái hậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhấp nhô': []
# --------------------
# Results for 'sức bật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quà cáp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kể lể': ["category2: 'Động từ'"]
# --------------------
# Results for 'thường tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mãn nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thơm tho': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luật hoá': []
# --------------------
# Results for 'ngày giờ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đĩa bay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà thổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thôn xóm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiễn biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạ lệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự mãn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguy nga': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhún nhảy': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu cá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạ màn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đào thoát': []
# --------------------
# Results for 'thương thuyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'khơi mào': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ nghi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thợ mộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lợi tức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải giáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn hiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'ý niệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'canh cánh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'suy tính': ["category2: 'Động từ'"]
# --------------------
# Results for 'xì xào': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tới bến': []
# --------------------
# Results for 'suýt nữa': []
# --------------------
# Results for 'hiệu nghiệm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chấp pháp': ["category2: 'Động từ'"]
# --------------------
# Results for 'quang phổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huống chi': []
# --------------------
# Results for 'nối nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền đồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc bắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kết thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'phòng dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'máy bay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chua cay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiêng kỵ': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'lấp ló': ["category2: 'Động từ'"]
# --------------------
# Results for 'doạ dẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rối bời': []
# --------------------
# Results for 'lý học': []
# --------------------
# Results for 'tăng trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chợ búa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trùng lắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bất hiếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường máu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đoán định': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu là': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộc phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'để phần': ["category2: 'Động từ'"]
# --------------------
# Results for 'hì hục': []
# --------------------
# Results for 'tay ngang': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'toàn tập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sâu bọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công sản': []
# --------------------
# Results for 'chân mày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mai sau': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rần rần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rắn rỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhân tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình trụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dậy mùi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yên ấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buồn tẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nguyền rủa': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ thu': []
# --------------------
# Results for 'đại thụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh hoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'không tặc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trói chân': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp phối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiềm khích': []
# --------------------
# Results for 'phôi thai': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ân nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'luồn lách': ["category2: 'Động từ'"]
# --------------------
# Results for 'mạnh miệng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngựa vằn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xả hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'dũng khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'di lý': ["category2: 'Động từ'"]
# --------------------
# Results for 'lộ giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'súng lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cát sê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuột dốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'phạm trù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thắt cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạc màu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thịnh soạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương hại': ["category2: 'Động từ'"]
# --------------------
# Results for 'phúc đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệm kì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cửa miệng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đông nghẹt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dò hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đứng đắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành thục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phù phiếm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'loạn xạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trong suốt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'li hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'vỡ lẽ': ["category2: 'Động từ'"]
# --------------------
# Results for 'mờ mịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'may mà': []
# --------------------
# Results for 'nhào nặn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiệu phó': []
# --------------------
# Results for 'thì thôi': []
# --------------------
# Results for 'tiểu xảo': []
# --------------------
# Results for 'thư hùng': []
# --------------------
# Results for 'bài trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thấu kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bó hẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầu lâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hung thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu tài': ["category2: 'Động từ'"]
# --------------------
# Results for 'bà ba': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ung bướu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối nghịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tấm tắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'chu du': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầu lưỡi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'da dẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'sừng sỏ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'run run': []
# --------------------
# Results for 'chứng tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá tầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'to nhỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhốn nháo': ["category2: 'Động từ'"]
# --------------------
# Results for 'khổ tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tồi tàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuề xoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiểu luận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xử sự': ["category2: 'Động từ'"]
# --------------------
# Results for 'cân xứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thốt nốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhớ thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'lợn thịt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rau dền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huỳnh quang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bát nháo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoa tiêu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhi khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lóng ngóng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'dàn cảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'chầm chậm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khổ chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tục ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'no đủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đàn bầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nay mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cõi đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà tấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trầm hương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xiêu vẹo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mở toang': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàm chứa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoà trộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chùa chiền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước lèo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khắc tinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'no ấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tô vẽ': ["category2: 'Động từ'"]
# --------------------
# Results for 'điên loạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khởi sự': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuôn hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bánh rán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biệt dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kền kền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháo hạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khen tặng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nài nỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngút ngàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đội viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thượng phong': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sờ gáy': []
# --------------------
# Results for 'xông xáo': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'vướng bận': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ ý': ["category2: 'Động từ'"]
# --------------------
# Results for 'bằng lăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'leo trèo': ["category2: 'Động từ'"]
# --------------------
# Results for 'hớp hồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'óng ánh': []
# --------------------
# Results for 'gượng gạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tra hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'mẫn cảm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sủng ái': ["category2: 'Động từ'"]
# --------------------
# Results for 'một cái': []
# --------------------
# Results for 'thẩm mĩ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bài chỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiêu kỳ': []
# --------------------
# Results for 'định tuyến': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm mến': ["category2: 'Động từ'"]
# --------------------
# Results for 'đô hộ': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nhà lầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'săm soi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu gì': []
# --------------------
# Results for 'tiếp liệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôi luyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'trận mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chết đứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'liệt giường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chối từ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tan tầm': ["category2: 'Động từ'"]
# --------------------
# Results for 'cây viết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân giới': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm loạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh bị': []
# --------------------
# Final results have been saved to 8000word.json
