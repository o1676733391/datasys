# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '2000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 2045

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 3000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'thông số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đương nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chào mừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bày bán': []
# --------------------
# Results for 'trả giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'học hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo hộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiết yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ca ngợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắt nguồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghĩa trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tối ưu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cáo trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dịu dàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'huỷ bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đều đặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kết cấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lập công': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiếm hoi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bài bản': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'sương mù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'địa lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngày xưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'leo thang': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khối u': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chú rể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khen thưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hối lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'túi xách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyên phạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'luôn luôn': []
# --------------------
# Results for 'minh chứng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'trở ngại': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hữu cơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiệu suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khí đốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sâu rộng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hạt giống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xu thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'y học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xứ sở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giật mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy nã': ["category2: 'Động từ'"]
# --------------------
# Results for 'quần chúng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngần ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'chảy máu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quyền hạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dọn dẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'biệt danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'riêng biệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dày đặc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trúng tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'thư viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đặc nhiệm': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'khí thải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại sứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà giải': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế chấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký ức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhận biết': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'cưỡng chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'chính đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cảm ứng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bảo trì': ["category2: 'Động từ'"]
# --------------------
# Results for 'tái tạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'tình tiết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản cảm': []
# --------------------
# Results for 'thủ phạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tác hại': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chuyển hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'phải biết': []
# --------------------
# Results for 'trang sức': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quý giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quay phim': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiến sỹ': []
# --------------------
# Results for 'thu hẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'an sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khả quan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiêm kích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khánh thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'cánh tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ca nhạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thỉnh thoảng': []
# --------------------
# Results for 'vô số': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chìa khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xa lạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dầu mỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phá sản': ["category2: 'Động từ'"]
# --------------------
# Results for 'tăng tốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ hạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tràn lan': []
# --------------------
# Results for 'kéo theo': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh giác': []
# --------------------
# Results for 'mặt trận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyết điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mô tô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'song song': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tỉnh táo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lượt về': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năm tháng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý hiếm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'một ít': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại dương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuổi trẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường kính': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hợp nhất': ["category2: 'Động từ'"]
# --------------------
# Results for 'lục địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xi măng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiêu mộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉnh thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tri ân': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàu thuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giây phút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng khám': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biên phòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà trọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ưu điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộc lộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thao tác': []
# --------------------
# Results for 'ca sỹ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn mừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đụng độ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ly khai': ["category2: 'Động từ'"]
# --------------------
# Results for 'liên doanh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổn hại': []
# --------------------
# Results for 'xe ôm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghị sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sôi nổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'côn trùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyển động': ["category2: 'Động từ'"]
# --------------------
# Results for 'dồi dào': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiếc nuối': ["category2: 'Động từ'"]
# --------------------
# Results for 'cường quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạnh dạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bản địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'năm tuổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trào lưu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chào bán': ["category2: 'Động từ'"]
# --------------------
# Results for 'mới lạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiêm ngưỡng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuống đường': ["category2: 'Động từ'"]
# --------------------
# Results for 'quen biết': ["category2: 'Động từ'"]
# --------------------
# Results for 'thất thoát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đề phòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm giàu': ["category2: 'Động từ'"]
# --------------------
# Results for 'chọn lựa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguy kịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quốc hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xấu hổ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bảo lãnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'lâu đời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu vào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội tụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'họ hàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toàn thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàn phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiêu huỷ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sóng gió': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồ hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mở màn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể dục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điển trai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiệt thòi': []
# --------------------
# Results for 'cởi mở': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tụ tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm linh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tân binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuyến mãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'vùng cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương lái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'canh tác': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiếp dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế trận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'háo hức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phu nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh lịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'môn học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm lịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuẩn mực': []
# --------------------
# Results for 'bộ binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thai nhi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đau lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghiêm ngặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bánh mì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dung tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'búp bê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ nhiệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đến nỗi': []
# --------------------
# Results for 'cứu hoả': ["category2: 'Động từ'"]
# --------------------
# Results for 'lão hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'võ thuật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đắt đỏ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tố tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước nhà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'số ít': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu vượt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vội vàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sân cỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vậy mà': []
# --------------------
# Results for 'dòng chảy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuyền trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiện lợi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sáng tỏ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà tù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rút lui': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả mạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoá thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xúc phạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'âm thầm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tái hiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'truyền tải': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm số': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'vương miện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ban ngày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cường độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khán đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lây lan': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuyến mại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuổi thọ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu hụt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiểu thương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nổ súng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bấy giờ': ["category7: 'Đại từ'"]
# --------------------
# Results for 'hiện hữu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tình cờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghiêm khắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vận dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiến triển': ["category2: 'Động từ'"]
# --------------------
# Results for 'ấn định': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhậm chức': ["category2: 'Động từ'"]
# --------------------
# Results for 'lật đổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoà nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'mạch máu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại ô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngôi vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung gian': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lỗ hổng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân mật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ưa thích': ["category2: 'Động từ'"]
# --------------------
# Results for 'lặng lẽ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đương kim': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hành hung': ["category2: 'Động từ'"]
# --------------------
# Results for 'núi lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tù nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cổ tức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hấp thụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lộng lẫy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sư tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nữ tính': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tương đồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật tư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dầu thô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chu kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sứ mệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quyên góp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoả hoạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đột nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'khung cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai báo': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồ đạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiện trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kích cỡ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình dáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạo dáng': []
# --------------------
# Results for 'bạo hành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình ổn': []
# --------------------
# Results for 'tri thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thể chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vành đai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nuôi trồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bỏ hoang': ["category2: 'Động từ'"]
# --------------------
# Results for 'công dụng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tràn ngập': []
# --------------------
# Results for 'bao lâu': ["category7: 'Đại từ'"]
# --------------------
# Results for 'chứng từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoai tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vừa mới': []
# --------------------
# Results for 'phấn khởi': []
# --------------------
# Results for 'thuyền viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quán triệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp bách': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tàng hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'quán quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bình dân': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhầm lẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đề cao': ["category2: 'Động từ'"]
# --------------------
# Results for 'con giáp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công đoạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ bé': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giam giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bù đắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'cục bộ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'do vậy': []
# --------------------
# Results for 'lôi kéo': ["category2: 'Động từ'"]
# --------------------
# Results for 'phản công': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoạn mục': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kháng cáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy chuẩn': []
# --------------------
# Results for 'cô lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà hát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh đập': ["category2: 'Động từ'"]
# --------------------
# Results for 'diện mạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'đóng tàu': []
# --------------------
# Results for 'trăn trở': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân dung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứng rắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thương vong': []
# --------------------
# Results for 'đường lối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát tán': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'gió giật': []
# --------------------
# Results for 'mất mát': []
# --------------------
# Results for 'uỷ ban': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh hài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bệnh nhi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'có điều': []
# --------------------
# Results for 'thạc sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đàn em': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoả lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chị gái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh vi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'toạ đàm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thích ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'duyên dáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ranh giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đắc cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấp nước': []
# --------------------
# Results for 'quy tụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trình làng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảm đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôn đốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'biểu dương': ["category2: 'Động từ'"]
# --------------------
# Results for 'ưu ái': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyển hướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đường bay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sinh động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chung cuộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh điển': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sức sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thống trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân chia': ["category2: 'Động từ'"]
# --------------------
# Results for 'cự ly': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đa năng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiện nghi': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ghi nhớ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bệnh lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ý muốn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất lực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô tư': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lệ phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chào đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'nữ hoàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ồ ạt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mưu sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghỉ việc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thăng hoa': ["category2: 'Động từ'"]
# --------------------
# Results for 'xâm lược': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh cáo': ["category2: 'Động từ'"]
# --------------------
# Results for 'sản phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xem lại': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thịnh vượng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vận tốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'răn đe': ["category2: 'Động từ'"]
# --------------------
# Results for 'hội chợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kích động': []
# --------------------
# Results for 'khốc liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tịch thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lây nhiễm': ["category2: 'Động từ'"]
# --------------------
# Results for 'một khi': []
# --------------------
# Results for 'đánh đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuổi thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiền lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cảm động': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'mãi mãi': []
# --------------------
# Results for 'con nhỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bao vây': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh cắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'lý luận': []
# --------------------
# Results for 'lữ hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá thể': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tải trọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá tra': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghi lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mở đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngẫu nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm khách': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ từ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chấn động': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoài ra': []
# --------------------
# Results for 'kinh ngạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'dàn dựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sản sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'dễ chịu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuỳ thuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'danh giá': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'máy chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phàn nàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'vững mạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phế liệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỷ trọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình thế': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'huỷ diệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hải lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoài nghi': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trái đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'hộp số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiêu chảy': []
# --------------------
# Results for 'hứng thú': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phụ cấp': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chế tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biết bao': []
# --------------------
# Results for 'tập kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'ông xã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ít nhiều': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buộc tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'xấp xỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'căn bản': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'chuyên trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'binh lính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu bếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mật khẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thích nghi': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ dẫn': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phong tục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miễn dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'vĩnh viễn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầu thang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ đạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắc màu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương lượng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguy hại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thường trú': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ thị': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tha thứ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hệ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quỹ đạo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quyết toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'đổ vỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quy luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bẩm sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'có thai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật lý': []
# --------------------
# Results for 'thực ra': []
# --------------------
# Results for 'ba mẹ': []
# --------------------
# Results for 'tù giam': ["category2: 'Động từ'"]
# --------------------
# Results for 'giai điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân làng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công sở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiên nhẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'số một': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vương quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lòng đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đột quỵ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thẩm phán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thay mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tượng trưng': ["category2: 'Động từ'", "category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'số hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nạo vét': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết án': ["category2: 'Động từ'"]
# --------------------
# Results for 'mềm mại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chi phối': ["category2: 'Động từ'"]
# --------------------
# Results for 'trả thù': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghiệm thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổ tiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lũ lụt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tín ngưỡng': []
# --------------------
# Results for 'phần thưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỏ rơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân thường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu niên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá sấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lang thang': ["category2: 'Động từ'"]
# --------------------
# Results for 'cây cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dòng họ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tất yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quanh năm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tạo dựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dấu vết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hệ luỵ': []
# --------------------
# Results for 'hàng hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bàn phím': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tưởng chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cốt lõi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giết mổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà riêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồ dùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ bắp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công phu': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hữu hiệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trước kia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hành xử': []
# --------------------
# Results for 'hình dung': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'oxy hoá': []
# --------------------
# Results for 'mạnh tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hứng chịu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đẩy lùi': ["category2: 'Động từ'"]
# --------------------
# Results for 'châu lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiêng liêng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhất thiết': []
# --------------------
# Results for 'đời thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khoả thân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lịch trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm bão': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gây rối': ["category2: 'Động từ'"]
# --------------------
# Results for 'phẫn nộ': []
# --------------------
# Results for 'thí nghiệm': []
# --------------------
# Results for 'gián đoạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hậu thuẫn': []
# --------------------
# Results for 'dệt may': []
# --------------------
# Results for 'chạy đua': ["category2: 'Động từ'"]
# --------------------
# Results for 'vắc xin': []
# --------------------
# Results for 'năng khiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sành điệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khởi điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cải lương': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'áo khoác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khát vọng': []
# --------------------
# Results for 'vé số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuỷ tinh': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hộ chiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thung lũng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thông cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhận dạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sữa chua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng phạm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra tay': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơn sốt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xác lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'biết ơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần cứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghị định': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trình duyệt': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'bàn bạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'hang động': []
# --------------------
# Results for 'khích lệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'để dành': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ khí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con tin': ["category1: 'Danh từ'"]
# --------------------
# Results for 'siêu âm': ["category1: 'Danh từ'", "category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đặc tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất kể': []
# --------------------
# Results for 'hộ khẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉ mỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mồ côi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hộ tống': ["category2: 'Động từ'"]
# --------------------
# Results for 'gọn gàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tái xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sa mạc': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ghi chép': []
# --------------------
# Results for 'bao bì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khắt khe': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đảo chính': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'lập trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngang nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bàng hoàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhộn nhịp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'độc thân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phóng xạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiên thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu kỳ': []
# --------------------
# Results for 'trình tự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỳ diệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chủ nhật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vùng sâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tây nam': []
# --------------------
# Results for 'hồn nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tự phát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân luồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúng túng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hội chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đăng cai': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'khiêu khích': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mô phỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bộ nhớ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiền nhiệm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quần vợt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỗn loạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'i t': []
# --------------------
# Results for 'cuộc chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ghi âm': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoảng loạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'huỷ hoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trí thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sưu tầm': ["category2: 'Động từ'"]
# --------------------
# Results for 'an ủi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cẩn trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truyền cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiếp ảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'trì hoãn': ["category2: 'Động từ'"]
# --------------------
# Results for 'rút tiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'cấm vận': ["category2: 'Động từ'"]
# --------------------
# Results for 'bao phủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đắt giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đầu tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thông thoáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chính quy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'san hô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gián tiếp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bộ đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tội ác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu thốn': []
# --------------------
# Results for 'quần thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sơ mi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'địa chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản bội': ["category2: 'Động từ'"]
# --------------------
# Results for 'dư nợ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trí nhớ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đàn anh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bể bơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bán chạy': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên vẹn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biến dạng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tiến công': ["category2: 'Động từ'"]
# --------------------
# Results for 'bỗng dưng': []
# --------------------
# Results for 'hư hại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'điệp viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lung linh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rầm rộ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bầu chọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đông lạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đơn phương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'võ sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cử nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập cảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'độ ẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chậm trễ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đón tiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'che giấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy tìm': ["category2: 'Động từ'"]
# --------------------
# Results for 'dưỡng chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xót xa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đa cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ràng buộc': []
# --------------------
# Results for 'thân nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiều hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ức chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'đậm đà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xa xôi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chạm trán': ["category2: 'Động từ'"]
# --------------------
# Results for 'du thuyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thua kém': ["category2: 'Động từ'"]
# --------------------
# Results for 'cá mập': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay chân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trục trặc': []
# --------------------
# ...
# --------------------
# Results for 'đẹp trai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phòng bệnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử tế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàng tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khát khao': ["category2: 'Động từ'"]
# --------------------
# Results for 'bao trùm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ám sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'giang hồ': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vững vàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'địa danh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đá quý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỏi thăm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phòng tránh': ["category2: 'Động từ'"]
# --------------------
# Results for 'phấn khích': []
# --------------------
# Results for 'khuyến nghị': []
# --------------------
# Results for 'cầu hôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hậu cần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bà xã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao quý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bản sao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm thuê': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia công': ["category2: 'Động từ'"]
# --------------------
# Results for 'bào chữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kịch tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu gối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phương hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ví như': []
# --------------------
# Results for 'quảng trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tương xứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vội vã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lột xác': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngập lụt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'điện toán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điểm nóng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lí do': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sát thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tin tặc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thoả đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiệp hội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải khát': ["category2: 'Động từ'"]
# --------------------
# Results for 'diễu hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'phản biện': ["category2: 'Động từ'"]
# --------------------
# Results for 'đương đại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lâm nghiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yêu quý': ["category2: 'Động từ'"]
# --------------------
# Results for 'lâu đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cực đại': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'khởi sắc': []
# --------------------
# Results for 'nữ giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tràn đầy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhiệt điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuổi tác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'siêu sao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nội trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu nối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bàn tán': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiêm chủng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thông cáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trong sạch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khai quật': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt huyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưới điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trên dưới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phòng vệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dân sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bài thuốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hồi hộp': ["category2: 'Động từ'"]
# --------------------
# Results for 'kế tiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bãi bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'biên tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuế suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nam nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao tranh': ["category2: 'Động từ'"]
# --------------------
# Results for 'khởi hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'học giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ phủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biến thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phương châm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sống động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoạch định': ["category2: 'Động từ'"]
# --------------------
# Results for 'dã man': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuất thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'hối hận': ["category2: 'Động từ'"]
# --------------------
# Results for 'cổ tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dưa hấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỉ niệm': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'tái chế': ["category2: 'Động từ'"]
# --------------------
# Results for 'cổ đại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phải chăng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thang máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao độ': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'xa xỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thừa kế': ["category2: 'Động từ'"]
# --------------------
# Results for 'tồn kho': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế là': []
# --------------------
# Results for 'uỷ viên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hợp chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đột xuất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tần suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trăm năm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ứng cử': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự tính': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'cảnh tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lạnh lùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tâm trí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô lý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'điện năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khao khát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiếu sót': []
# --------------------
# Results for 'dung dịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toán học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xác thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'động mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay đua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị thực': ["category2: 'Động từ'"]
# --------------------
# Results for 'đích thực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiểm lâm': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'áp đảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'lắc đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lề đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thường ngày': []
# --------------------
# Results for 'thứ tự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thăm khám': ["category2: 'Động từ'"]
# --------------------
# Results for 'lũ quét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhiễm khuẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'trục xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vòng tay': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ lẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàng gia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liệt sỹ': []
# --------------------
# Results for 'vật nuôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn ở': ["category2: 'Động từ'"]
# --------------------
# Results for 'say mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa bão': []
# --------------------
# Results for 'mất ngủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồi sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'tận mắt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bạn đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điêu khắc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'e ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'khó tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghi thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khoáng chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kế thừa': ["category2: 'Động từ'"]
# --------------------
# Results for 'bốc thăm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn khách': ["category2: 'Động từ'"]
# --------------------
# Results for 'đóng gói': ["category2: 'Động từ'"]
# --------------------
# Results for 'chịu khó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cai nghiện': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếp diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thẻ đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lập pháp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội chiến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếp đón': ["category2: 'Động từ'"]
# --------------------
# Results for 'tượng đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triết lý': []
# --------------------
# Results for 'hình dạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miệt mài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rượu bia': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cha con': []
# --------------------
# Results for 'tấp nập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'định hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'khang trang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tình cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai giảng': ["category2: 'Động từ'"]
# --------------------
# Results for 'chẳng thể': []
# --------------------
# Results for 'tưởng nhớ': ["category2: 'Động từ'"]
# --------------------
# Results for 'bề ngoài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phạm nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yên bình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'coi thường': ["category2: 'Động từ'"]
# --------------------
# Results for 'khẩu hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toàn thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoàn trả': ["category2: 'Động từ'"]
# --------------------
# Results for 'công chiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tối ngày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ham muốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'mét vuông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tử thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khám xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'song ca': ["category2: 'Động từ'"]
# --------------------
# Results for 'tích tụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'triều đại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đóng băng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mệnh giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẩm tra': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm cao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiên cố': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàng đế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân cách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủng loại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quan trắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng cảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thư ký': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ tùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng phục': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thù địch': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'sinh dục': ["category2: 'Động từ'"]
# --------------------
# Results for 'học viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điền kinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'da cam': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định mức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mã hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'văn chương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'can ngăn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bánh chưng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thú y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bước ngoặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quấy rối': ["category2: 'Động từ'"]
# --------------------
# Results for 'mẫu giáo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu hàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'vinh quang': []
# --------------------
# Results for 'mát mẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm bạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hung thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm tư': ["category1: 'Danh từ'"]
# --------------------
# Final results have been saved to 2000word.json
