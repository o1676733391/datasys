# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '5000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 5042

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 6000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'hung dữ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thanh thoát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cận thành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tung tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quyết sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước đá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khí tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhịp nhàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trọng dụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dầu gội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trượt tuyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'liên tịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tinh nhuệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chớp nhoáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buồn cười': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thường nhật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xói mòn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành khẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngừng nghỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thiết chế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành thật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiêu đãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'triền miên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giỏi giang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đắn đo': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiên quyết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bôi nhọ': ["category2: 'Động từ'"]
# --------------------
# Results for 'lên cơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm đắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bi quan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhếch nhác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'móc túi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghèo đói': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trị vì': ["category2: 'Động từ'"]
# --------------------
# Results for 'mạo danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thoáng đãng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trước sau': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kháng nghị': []
# --------------------
# Results for 'giao cắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'rúng động': ["category2: 'Động từ'"]
# --------------------
# Results for 'tháp tùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cung đình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thịnh hành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giao phó': ["category2: 'Động từ'"]
# --------------------
# Results for 'di tản': ["category2: 'Động từ'"]
# --------------------
# Results for 'quá cảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương tật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình ca': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhút nhát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đánh rơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời kì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đón đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao nhận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tâm thư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần đồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cao trào': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mắt xanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ảo giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhân giống': []
# --------------------
# Results for 'dấu tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chạnh lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn náu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc doanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nâng niu': ["category2: 'Động từ'"]
# --------------------
# Results for 'phái sinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vui sướng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thằn lằn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đụng chạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'phần nhiều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phù sa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máy lạnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mai một': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguy cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiêu hãnh': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'địa chấn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kênh rạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu duệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'định lượng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trâu bò': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tài giỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'báu vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối xứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công tâm': []
# --------------------
# Results for 'thiên hà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngớ ngẩn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoán đổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng cỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cửa biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thám tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vu khống': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghĩa địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp bậc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mất lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa gió': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bị đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đối tượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'che phủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'luận tội': ["category2: 'Động từ'"]
# --------------------
# Results for 'hào phóng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xâm lấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bám trụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tới tấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'màu mỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tốt lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'anh dũng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chung quanh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ảo tưởng': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'đặc cách': ["category2: 'Động từ'"]
# --------------------
# Results for 'ô liu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấy ghép': ["category2: 'Động từ'"]
# --------------------
# Results for 'trực quan': ["category2: 'Động từ'"]
# --------------------
# Results for 'mày mò': ["category2: 'Động từ'"]
# --------------------
# Results for 'xét hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'chiêu thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trầy xước': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biến tấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiếng tăm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý phái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ký quỹ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trang chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chúng mình': ["category7: 'Đại từ'"]
# --------------------
# Results for 'lưu truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuyến học': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'mùa vụ': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'người xưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáng lẽ': []
# --------------------
# Results for 'phác đồ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ổ gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất thủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'khái quát': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bảo lưu': ["category2: 'Động từ'"]
# --------------------
# Results for 'số dư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đèn lồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tươi cười': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chữ cái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bệnh binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trớ trêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xà ngang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đè bẹp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thặng dư': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sự thực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cốt truyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hộp đêm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tẩy rửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngày công': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chất nổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháp lệnh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đi tiểu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ấm ức': ["category2: 'Động từ'"]
# --------------------
# Results for 'uốn lượn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hãnh diện': ["category2: 'Động từ'"]
# --------------------
# Results for 'sạch đẹp': []
# --------------------
# Results for 'giữa chừng': []
# --------------------
# Results for 'sinh kế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bà cụ': []
# --------------------
# Results for 'hài kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đen trắng': []
# --------------------
# Results for 'sâu lắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phần đông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hạnh nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phán đoán': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'căn cơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuồng trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xử tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'nặng nhọc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trên tài': []
# --------------------
# Results for 'diễu binh': ["category2: 'Động từ'"]
# --------------------
# Results for 'chần chừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xô đẩy': ["category2: 'Động từ'"]
# --------------------
# Results for 'quân hàm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'minh tinh': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chúc phúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'chân tình': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'uyển chuyển': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dây cáp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mức sống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vận mệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xâm chiếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bồng bềnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mắt cá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ điển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỳ công': []
# --------------------
# Results for 'tự nhủ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chậm rãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khẩu độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng qua': []
# --------------------
# Results for 'dã ngoại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trách móc': ["category2: 'Động từ'"]
# --------------------
# Results for 'kiểm kê': ["category2: 'Động từ'"]
# --------------------
# Results for 'đương sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung lưu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phi tang': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạch tuộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lụt bão': []
# --------------------
# Results for 'tương quan': []
# --------------------
# Results for 'đậu phộng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trắc trở': []
# --------------------
# Results for 'kết nghĩa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đúc kết': ["category2: 'Động từ'"]
# --------------------
# Results for 'trẻ thơ': []
# --------------------
# Results for 'vô tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giản đơn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phân trần': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiên thạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biện minh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bụi bặm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bực bội': ["category2: 'Động từ'"]
# --------------------
# Results for 'khuấy động': ["category2: 'Động từ'"]
# --------------------
# Results for 'giấy báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đôi mươi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần tiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khuất phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'khúc mắc': []
# --------------------
# Results for 'nghĩa tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên trạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hậu phương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trường phái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điểm ảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'già làng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thở phào': ["category2: 'Động từ'"]
# --------------------
# Results for 'hè thu': []
# --------------------
# Results for 'kỳ quan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ế ẩm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tham lam': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thanh minh': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'chóng vánh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thân chủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả thiết': []
# --------------------
# Results for 'tay chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bàn chải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân lập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cửa hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghèo khổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'say xỉn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thần tốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỳ quặc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tắm rửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'ca trù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn lẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kẻ trộm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'màu da': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cặp kè': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'phản kháng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trá hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'y như': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khả nghi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xem thường': ["category2: 'Động từ'"]
# --------------------
# Results for 'đê điều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thi viết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực hư': ["category3: 'Tính từ'"]
# --------------------
# Results for 'manh động': ["category2: 'Động từ'"]
# --------------------
# Results for 'gieo trồng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách tân': ["category2: 'Động từ'"]
# --------------------
# Results for 'học lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc tài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quanh co': []
# --------------------
# Results for 'thành danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'e dè': ["category2: 'Động từ'"]
# --------------------
# Results for 'ra chiều': []
# --------------------
# Results for 'dân nghèo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chặn đứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'lưu tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân hôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyển khoản': ["category2: 'Động từ'"]
# --------------------
# Results for 'cổ động': ["category2: 'Động từ'"]
# --------------------
# Results for 'khán phòng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hào nhoáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thụ tinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'giám mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đảng phái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đánh bật': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiệu số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giá như': []
# --------------------
# Results for 'không chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiệc tùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nổi cộm': []
# --------------------
# Results for 'miễn giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhí nhảnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bá đạo': []
# --------------------
# Results for 'truy xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'canh gác': ["category2: 'Động từ'"]
# --------------------
# Results for 'yếu thế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kì vọng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'quý nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thai sản': ["category2: 'Động từ'"]
# --------------------
# Results for 'năn nỉ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầm ấm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truyền bá': ["category2: 'Động từ'"]
# --------------------
# Results for 'trắng tinh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tai hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liêm chính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lung lay': ["category2: 'Động từ'"]
# --------------------
# Results for 'chạm khắc': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoài bão': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đổ dồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'yên ổn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bổ trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thế thì': []
# --------------------
# Results for 'thư thái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dằn mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảnh giới': ["category2: 'Động từ'"]
# --------------------
# Results for 'to tiếng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xích mích': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'đơn sơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoa khôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điệu đà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chân trời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'huyền ảo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hiểm nguy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trú ngụ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cắt cổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đảo quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vải thiều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất tinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao cấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồn trú': []
# --------------------
# Results for 'máy xúc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sát nhân': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước chấm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngập mặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bệnh án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng vốn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hổ mang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gạo nếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mù quáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cội nguồn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mời chào': ["category2: 'Động từ'"]
# --------------------
# Results for 'du nhập': ["category2: 'Động từ'"]
# --------------------
# Results for 'mẹ vợ': []
# --------------------
# Results for 'nội tiết': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thất thiệt': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'vô lăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặc cả': ["category2: 'Động từ'"]
# --------------------
# Results for 'ống xả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mất mạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dài hơi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chững chạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dằn vặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chữ số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ly thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyển phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại bàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dàn trải': []
# --------------------
# Results for 'xác suất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vấp ngã': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngại ngùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tài ba': []
# --------------------
# Results for 'kỳ dị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'gia tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phác thảo': ["category2: 'Động từ'", "category1: 'Danh từ'", "category1: 'Danh từ'", "category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cấm địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước tương': []
# --------------------
# Results for 'tầm mắt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ăn trộm': ["category2: 'Động từ'"]
# --------------------
# Results for 'người đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mù mịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ung dung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bao la': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lướt sóng': []
# --------------------
# Results for 'ruộng đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yến mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'da diết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhảy dù': ["category2: 'Động từ'"]
# --------------------
# Results for 'đằm thắm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiền bối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rừng núi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con nghiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiết niệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'chèo kéo': ["category2: 'Động từ'"]
# --------------------
# Results for 'manh mối': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'phá án': ["category2: 'Động từ'"]
# --------------------
# Results for 'áo mưa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phụ khoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sơ suất': []
# --------------------
# Results for 'thượng đế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây cỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chung khảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hở hang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nước mặn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh nghịch': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lục quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sẵn lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'che đậy': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao thủ': []
# --------------------
# Results for 'gọn nhẹ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chúng nó': ["category7: 'Đại từ'"]
# --------------------
# Results for 'kém cỏi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mặt cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thổ cẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bội thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'va đập': ["category2: 'Động từ'"]
# --------------------
# Results for 'đời mới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản thảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chào hỏi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành pháp': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuống dốc': ["category2: 'Động từ'"]
# --------------------
# Results for 'can dự': ["category2: 'Động từ'"]
# --------------------
# Results for 'thời buổi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứng cáp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'úp mở': ["category2: 'Động từ'"]
# --------------------
# Results for 'lễ tân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'siêu tốc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lầy lội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'áo quần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàu điện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cận vệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'méo mó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nảy nở': ["category2: 'Động từ'"]
# --------------------
# Results for 'tĩnh lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lễ vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiến thiết': ["category2: 'Động từ'"]
# --------------------
# Results for 'tỉ giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đội xếp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiếm muộn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trắng trợn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lòng đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trưởng thôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mua dâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiền tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sản vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mập mờ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đình trệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'châu Âu': []
# --------------------
# Results for 'tù và': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'xạ trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'đảng bộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chỉnh lý': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung du': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'để tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngao ngán': []
# --------------------
# Results for 'khốn khó': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biểu trưng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chức trách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'êm đềm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'suy nhược': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đêm ngày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập vai': []
# --------------------
# Results for 'xúc cảm': []
# --------------------
# Results for 'phản chiếu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung thu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghi ngại': ["category2: 'Động từ'"]
# --------------------
# Results for 'đô đốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mét khối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kì lạ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kênh mương': []
# --------------------
# Results for 'sàm sỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khăng khăng': []
# --------------------
# Results for 'hậu sự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chợ đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giành giật': ["category2: 'Động từ'"]
# --------------------
# Results for 'kho tàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiền phức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắc tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngược đãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'lăn lộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'săn bắn': ["category2: 'Động từ'"]
# --------------------
# Results for 'doanh trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trò đùa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàu thuỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân vân': ["category2: 'Động từ'"]
# --------------------
# Results for 'cô độc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nảy lửa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuê mua': ["category2: 'Động từ'"]
# --------------------
# Results for 'chỉ bảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'vật vã': ["category2: 'Động từ'"]
# --------------------
# Results for 'tráng miệng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu treo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhập tịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'phụ cận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rau thơm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngai vàng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào bới': ["category2: 'Động từ'"]
# --------------------
# Results for 'khung giá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tin dùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiểm hóc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'băng giá': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'phản ảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'mật mã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội chẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'giáo án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu giúp': ["category2: 'Động từ'"]
# --------------------
# Results for 'dại dột': ["category3: 'Tính từ'"]
# --------------------
# Results for 'êm ái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhóm họp': ["category2: 'Động từ'"]
# --------------------
# Results for 'rùng rợn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phục kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'pháo kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạn ngạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chống cự': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoài niệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xã giao': ["category1: 'Danh từ'", "category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lý trí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương nhớ': ["category2: 'Động từ'"]
# --------------------
# Results for 'càn quét': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngơ ngác': []
# --------------------
# Results for 'đa tài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chịu chơi': []
# --------------------
# Results for 'sâu sát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mặt biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạt nhoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cháy bỏng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đúng mực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'muôn vàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nóng bức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vượt biên': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản xứ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuyên giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đảm đang': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hãm hiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nương tựa': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhỏ xíu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trêu chọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tập tục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pha lê': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nôn mửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầu thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà trai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạc trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quan liêu': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đảm trách': ["category2: 'Động từ'"]
# --------------------
# Results for 'ban bố': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô cớ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kháu khỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'do dự': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhiệt liệt': []
# --------------------
# Results for 'ăn thua': ["category2: 'Động từ'"]
# --------------------
# Results for 'danh vọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công luận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điêu đứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rớt giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'đa nhiệm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tại trận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'loãng xương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cảnh ngộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tin yêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'ở riêng': ["category2: 'Động từ'"]
# --------------------
# Results for 'dàn nhạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lệch lạc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giao hưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỗng chốc': []
# --------------------
# Results for 'bí đỏ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mau chóng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lấy lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đương thời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vũ điệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghiệt ngã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đi ngoài': ["category2: 'Động từ'"]
# --------------------
# Results for 'khôn khéo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thụ thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'san sẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'oanh tạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh nhạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiệt tác': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'thân thương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đại uý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dây chằng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiểu sử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự vẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồi hương': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'ma quỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giãi bày': ["category2: 'Động từ'"]
# --------------------
# Results for 'lai lịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sách báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trích đoạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giả tạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỷ vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ nhặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thứ trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tái chiếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia truyền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chu cấp': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất công': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao lớn': []
# --------------------
# Results for 'tạm quyền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'yêu đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'lão thành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đăng đàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'vui đùa': ["category2: 'Động từ'"]
# --------------------
# Results for 'cần mẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thần thoại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểm đếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'di chúc': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thiên nga': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rưng rưng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kỹ xảo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vĩnh cửu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nâng giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'học thuyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mảnh mai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tập kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'sắc bén': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hình hài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kìm hãm': ["category2: 'Động từ'"]
# --------------------
# Results for 'lồng ngực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lưu vong': []
# --------------------
# Results for 'bay bổng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nữ trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thê thảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuần khiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thưa thớt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lấn lướt': ["category2: 'Động từ'"]
# --------------------
# Results for 'phế truất': ["category2: 'Động từ'"]
# --------------------
# Results for 'học bạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhâm nhi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cần cẩu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chua ngọt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'diễn đạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà chùa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'độc ác': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tan nát': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nguyên thuỷ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đảm đương': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất trộm': ["category2: 'Động từ'"]
# --------------------
# Results for 'sao băng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mạnh khoẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tím tái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tan hoang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thân thuộc': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'đông y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tức thời': []
# --------------------
# Results for 'hung hãn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kinh thành': ["category1: 'Danh từ'"]
# --------------------
# Results for 'long lanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đóng chai': ["category2: 'Động từ'"]
# --------------------
# Results for 'rút gọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'mộ điệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khai thông': ["category2: 'Động từ'"]
# --------------------
# Results for 'mã tấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô tận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghiêm chỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trót lọt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truyền dẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'kha khá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải lao': ["category2: 'Động từ'"]
# --------------------
# Results for 'bệnh dịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vụng về': ["category3: 'Tính từ'"]
# --------------------
# Results for 'luật định': ["category2: 'Động từ'"]
# --------------------
# Results for 'bài tiết': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng lương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tận thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'hỗn chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'mùa màng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đứng lớp': ["category2: 'Động từ'"]
# --------------------
# Results for 'ban tặng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảo mộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giấu giếm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bực mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'bom đạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mãn nguyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'chằng chịt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhưng mà': []
# --------------------
# Results for 'nhà gái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mãn kinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể thức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biển cả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuốc độc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thâm canh': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghi ngút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vật chứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vô hại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lạnh giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phái mạnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặt trái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nặng lãi': []
# --------------------
# Results for 'thuỷ ngân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hầm hố': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'cảnh tỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bò tót': ["category1: 'Danh từ'"]
# --------------------
# Results for 'điều ước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trai gái': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nội tại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm bàn': ["category2: 'Động từ'"]
# --------------------
# Results for 'quan khách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dã chiến': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'âm hưởng': ["category1: 'Danh từ'"]
# --------------------
# ...
# --------------------
# Results for 'công binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lăng mạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'danh pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xấu xa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thi hài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chịu thua': ["category2: 'Động từ'"]
# --------------------
# Results for 'căn cước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai hoang': ["category2: 'Động từ'"]
# --------------------
# Results for 'trang hoàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bạt ngàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đê bao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhuần nhuyễn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cho qua': ["category2: 'Động từ'"]
# --------------------
# Results for 'cơ duyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm thịt': ["category2: 'Động từ'"]
# --------------------
# Results for 'kê biên': ["category2: 'Động từ'"]
# --------------------
# Results for 'định đoạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'khai phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'non nớt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bến bãi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu vồng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng gió': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cần cù': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khiếp sợ': []
# --------------------
# Results for 'bồn tắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phát ban': ["category2: 'Động từ'"]
# --------------------
# Results for 'thánh địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hỏng hóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'gấp bội': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuỷ đậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn điệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại hạng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ thiên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáo hạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bền chặt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồn đại': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổng thu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xung yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiên đoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tưới tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quanh quẩn': []
# --------------------
# Results for 'rong ruổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tân HLV': []
# --------------------
# Results for 'rục rịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao niên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chú tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thượng tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uyên ương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bố cục': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'giã từ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỳ quái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lạnh lẽo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'âm ỉ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lười biếng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoả táng': ["category2: 'Động từ'"]
# --------------------
# Results for 'mật vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trắng xoá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành niên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thế gian': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại dịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lòng vòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tăng sản': ["category2: 'Động từ'"]
# --------------------
# Results for 'di căn': ["category2: 'Động từ'"]
# --------------------
# Results for 'quân khu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tụt hậu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuyển mộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ấu trùng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mến mộ': []
# --------------------
# Results for 'tộc người': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ép giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn năn': ["category2: 'Động từ'"]
# --------------------
# Results for 'bàn cãi': ["category2: 'Động từ'"]
# --------------------
# Results for 'siêu nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dầu diesel': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồi hồi': []
# --------------------
# Results for 'thành ra': []
# --------------------
# Results for 'thái tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lý lẽ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân phục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trùng lặp': ["category2: 'Động từ'"]
# --------------------
# Results for 'đêm tối': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hội kiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'trời đất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặc kệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'u ám': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thót tim': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên sinh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tột cùng': []
# --------------------
# Results for 'chuyên tâm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xa lánh': ["category2: 'Động từ'"]
# --------------------
# Results for 'hăng say': ["category3: 'Tính từ'"]
# --------------------
# Results for 'run rẩy': ["category2: 'Động từ'"]
# --------------------
# Results for 'hầu bao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dưa leo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nối đuôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'dùng bữa': ["category2: 'Động từ'"]
# --------------------
# Results for 'áo phao': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao thoa': ["category2: 'Động từ'"]
# --------------------
# Results for 'đau ốm': ["category2: 'Động từ'"]
# --------------------
# Results for 'sửa sang': ["category2: 'Động từ'"]
# --------------------
# Results for 'giá mà': []
# --------------------
# Results for 'đầy rẫy': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quên lãng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nông trại': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gầy gò': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đau đáu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ầm ầm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kình ngư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào tẩu': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe con': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẩm thấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'giá lạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vi tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất ngoại': ["category2: 'Động từ'"]
# --------------------
# Results for 'ổ chuột': []
# --------------------
# Results for 'phú quý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lão tướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tân trang': ["category2: 'Động từ'"]
# --------------------
# Results for 'đích danh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bản chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lận đận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dung hoà': ["category2: 'Động từ'"]
# --------------------
# Results for 'hay ho': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chết chóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'pháo sáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ít lâu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hăm doạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh thành': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước da': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quy ước': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'xoay xở': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà nông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu tá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khô ráo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thẳng tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bóng mát': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân trí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự quyết': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô vọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'um tùm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'éo le': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tai hại': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên trang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đông xuân': []
# --------------------
# Results for 'cẩu thả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chất xám': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một phép': []
# --------------------
# Results for 'kiếm ăn': ["category2: 'Động từ'"]
# --------------------
# Results for 'giả danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'thấm thía': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cảm phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'da thịt': []
# --------------------
# Results for 'thông thạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhẫn tâm': []
# --------------------
# Results for 'tiết giảm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổng cục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'biên đạo': ["category2: 'Động từ'"]
# --------------------
# Results for 'phù hộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiền hoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chân lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công quyền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đại đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tía tô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con đẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đa dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ròng rã': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đề bạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội ngoại': []
# --------------------
# Results for 'quá đỗi': []
# --------------------
# Results for 'triệt tiêu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quốc kỳ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tô điểm': ["category2: 'Động từ'"]
# --------------------
# Results for 'lúa nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ ý': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'mắt xích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cơ cực': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bán hoa': ["category2: 'Động từ'"]
# --------------------
# Results for 'da liễu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chừng mực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'non trẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhảy cầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đậu tương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giải phẫu': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sơ khảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'van xin': ["category2: 'Động từ'"]
# --------------------
# Results for 'táo tợn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tương ớt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ác tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cánh gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thức giấc': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng điệu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tại vị': []
# --------------------
# Results for 'chỉnh hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiêu sa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mào gà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'eo hẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'máu lửa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bôi trơn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tầm thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lao lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều độ': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'lương thiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ưa nhìn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiết chế': ["category1: 'Danh từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'dè chừng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhũng nhiễu': ["category2: 'Động từ'"]
# --------------------
# Results for 'lò mổ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tác quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiện tụng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tình nghĩa': []
# --------------------
# Results for 'thuyết minh': []
# --------------------
# Results for 'nam châm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chân vịt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà nhà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ giọt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chối bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại lễ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âm lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mẫu vật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sum vầy': ["category2: 'Động từ'"]
# --------------------
# Results for 'cất tiếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trừng trị': ["category2: 'Động từ'"]
# --------------------
# Results for 'hương liệu': ["category1: 'Danh từ'"]
# --------------------
# Final results have been saved to 5000word.json
