# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

import pandas as pd
import json

# %% [markdown]
# # Code chính

# %% [markdown]
# # Tiếp tục cào khởi tạo từ index cho cần

# %%
# Đường dẫn tới file JSON
json_file_path = 'vocab_frequency_new.json'
output_json_file_path = '4000word.json'

# Định nghĩa các danh mục từ loại
categories_mapping = {
    "Danh từ": "category1: 'Danh từ'",
    "Động từ": "category2: 'Động từ'",
    "Tính từ": "category3: 'Tính từ'",
    "Số từ": "category4: 'Số từ'",
    "Lượng từ": "category5: 'Lượng từ'",
    "Phó từ": "category6: 'Phó từ'",
    "Đại từ": "category7: 'Đại từ'",
    "": "category8: 'Null'"
}

# Khởi tạo WebDriver (giả sử bạn đang dùng Chrome), nếu như cần chạy hiện rõ trình duyệt thì chạy code ở dưới
browser = webdriver.Chrome()

# URL của trang web
url = "http://tratu.soha.vn/dict/vn_vn/"
browser.get(url)

# Đọc dữ liệu từ file JSON
with open(json_file_path, 'r', encoding='utf-8') as file:
    vocab_data = json.load(file)

# Tìm vị trí bắt đầu tìm kiếm (ví dụ từ vị trí 33)
start_index = 4044

# Khởi tạo danh sách kết quả
results = []

# Thực hiện tìm kiếm từ từ vị trí start_index đến hết danh sách
for index in range(start_index, 5000):
    word = vocab_data[str(index)]
    
    # Lấy lại các phần tử input và button trước mỗi lần tìm kiếm
    input_search = browser.find_element(By.ID, 'search')
    search_button = browser.find_element(By.ID, 'btnSearch')
    
    # Clear the input field
    input_search.clear()
    
    # Send the input to the webpage
    input_search.send_keys(word)
    sleep(1)
    search_button.click()
    
    # Scrap the data
    elements = browser.find_elements(By.XPATH, "//h3/span[@class='mw-headline']")
    
    # Lấy text của tất cả các phần tử và in ra
    word_categories = []
    for element in elements:
        text = element.text.strip()
        if text in categories_mapping:
            word_categories.append(categories_mapping[text])
    
    # Tạo đối tượng kết quả và thêm vào danh sách
    result = {
        "title": word,
        "categories": word_categories
    }
    results.append(result)
    
    # Mở file JSON để thêm mới kết quả
    with open(output_json_file_path, 'a', encoding='utf-8') as outfile:
        json.dump(result, outfile, ensure_ascii=False, indent=4)
        outfile.write(",\n")  # Thêm dấu phẩy và xuống dòng để đảm bảo JSON đúng định dạng
    
    print(f"Results for '{word}': {word_categories}")
    print('-' * 20)
    
    # Đợi một chút trước khi thực hiện tìm kiếm từ tiếp theo (tùy chọn)
    sleep(2)

# Đóng trình duyệt
browser.quit()

print(f"Final results have been saved to {output_json_file_path}")
# Out:
# Results for 'định kiến': []
# --------------------
# Results for 'tạo lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'kinh nguyệt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lựu đạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mặc cảm': []
# --------------------
# Results for 'dân chơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'túc trực': ["category2: 'Động từ'"]
# --------------------
# Results for 'trường lớp': []
# --------------------
# Results for 'kịch liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tường thuật': ["category2: 'Động từ'"]
# --------------------
# Results for 'phi thường': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nước rút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoảng hốt': []
# --------------------
# Results for 'cổ xưa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'rẻ tiền': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trực diện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bấy nhiêu': ["category7: 'Đại từ'"]
# --------------------
# Results for 'hồi sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn quyền': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiên định': []
# --------------------
# Results for 'bận tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tan rã': ["category2: 'Động từ'"]
# --------------------
# Results for 'đại trà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sổ sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe lăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bao tải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'treo cổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'công năng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bởi vậy': []
# --------------------
# Results for 'trữ lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rửa tiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều trần': []
# --------------------
# Results for 'đi đôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đảo lộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hùng mạnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bắt nạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy thu': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết bạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tháng ngày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản vẽ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khắc hoạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đám tang': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thân phận': ["category1: 'Danh từ'"]
# --------------------
# Results for 'củ cải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cận kề': ["category2: 'Động từ'"]
# --------------------
# Results for 'tại ngoại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nổi danh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tố chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thành thạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trọng yếu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đường biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phóng khoáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'truy quét': ["category2: 'Động từ'"]
# --------------------
# Results for 'tình ái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xí nghiệp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phong bì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chính trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đau thương': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoan ngoãn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lông mày': ["category1: 'Danh từ'"]
# --------------------
# Results for 'từ khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xét duyệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'điện máy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên chất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kết nạp': ["category2: 'Động từ'"]
# --------------------
# Results for 'lỗi thời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lén lút': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lỡ cơ': []
# --------------------
# Results for 'quá sức': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chơi đùa': ["category2: 'Động từ'"]
# --------------------
# Results for 'thị sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'ý nghĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tươi trẻ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tham luận': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'khí tài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kinh đô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vàng bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khủng long': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bàn luận': ["category2: 'Động từ'"]
# --------------------
# Results for 'lỏng lẻo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mật thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phế quản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực nghiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'tĩnh mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuổi đời': ["category1: 'Danh từ'"]
# --------------------
# Results for 'địa ngục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đương đầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nói thẳng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đương nhiệm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phá bỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ẩn chứa': ["category2: 'Động từ'"]
# --------------------
# Results for 'giằng co': ["category2: 'Động từ'"]
# --------------------
# Results for 'không tưởng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngày ngày': []
# --------------------
# Results for 'kháng cự': ["category2: 'Động từ'"]
# --------------------
# Results for 'yếu đuối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nối tiếp': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh đôi': []
# --------------------
# Results for 'kẻ gian': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường huyết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá biệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phong kiến': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhân tình': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phô diễn': ["category2: 'Động từ'"]
# --------------------
# Results for 'phản lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thắt lưng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhượng bộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tôm hùm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dự tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'học vấn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'song hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'chật chội': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầm cố': ["category2: 'Động từ'"]
# --------------------
# Results for 'vàng mã': ["category1: 'Danh từ'"]
# --------------------
# Results for 'không lưu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự ti': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dai dẳng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vô giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoại tử': []
# --------------------
# Results for 'khẩu phần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoà mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'thao túng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồng nhất': ["category3: 'Tính từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'hiểm nghèo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giáo trình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giúp ích': ["category2: 'Động từ'"]
# --------------------
# Results for 'mượt mà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'câu thơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy sụp': ["category2: 'Động từ'"]
# --------------------
# Results for 'bom mìn': []
# --------------------
# Results for 'xa xưa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghỉ hè': ["category2: 'Động từ'"]
# --------------------
# Results for 'rộng mở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lan can': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ích kỷ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tách biệt': []
# --------------------
# Results for 'ghê gớm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lãng quên': ["category2: 'Động từ'"]
# --------------------
# Results for 'chuyên chở': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạ thuỷ': ["category2: 'Động từ'"]
# --------------------
# Results for 'trữ tình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngộ nghĩnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'say sưa': ["category2: 'Động từ'"]
# --------------------
# Results for 'xe hoa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thụ hưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bò sữa': []
# --------------------
# Results for 'mai táng': ["category2: 'Động từ'"]
# --------------------
# Results for 'tuần hành': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn theo': ["category2: 'Động từ'"]
# --------------------
# Results for 'mưa đá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thụ động': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lời giải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'một mực': []
# --------------------
# Results for 'chú thích': []
# --------------------
# Results for 'mê hoặc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàu biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà trẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thôi thúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'gian dối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tụ điểm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chất lỏng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bóng đèn': []
# --------------------
# Results for 'tiểu phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất công': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hậu môn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiện dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trục vớt': ["category2: 'Động từ'"]
# --------------------
# Results for 'nợ đọng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'buồng lái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dân dã': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'trùng hợp': ["category2: 'Động từ'", "category2: 'Động từ'"]
# --------------------
# Results for 'nguyên thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cướp biển': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thú vui': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quả thực': []
# --------------------
# Results for 'chuyển tải': ["category2: 'Động từ'"]
# --------------------
# Results for 'trổ tài': ["category2: 'Động từ'"]
# --------------------
# Results for 'lãnh hải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sức mua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá hồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tỉnh lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dâu tây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tương phản': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dấn thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoà quyện': ["category2: 'Động từ'"]
# --------------------
# Results for 'cất giữ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hành hương': ["category2: 'Động từ'"]
# --------------------
# Results for 'giai cấp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thương tiếc': ["category2: 'Động từ'"]
# --------------------
# Results for 'tàn tật': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vun đắp': ["category2: 'Động từ'"]
# --------------------
# Results for 'con giống': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nền móng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ráo riết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cây bút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cộng sản': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hưu trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạp chất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'máy in': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồn thổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'thẳng đứng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phản bác': ["category2: 'Động từ'"]
# --------------------
# Results for 'đậm nét': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công kích': ["category2: 'Động từ'"]
# --------------------
# Results for 'chống trả': ["category2: 'Động từ'"]
# --------------------
# Results for 'khóc lóc': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhắm mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'mời gọi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tổ quốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bênh vực': ["category2: 'Động từ'"]
# --------------------
# Results for 'khôn lường': []
# --------------------
# Results for 'luân lưu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trị liệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán buôn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhật báo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'liên danh': []
# --------------------
# Results for 'chèn ép': ["category2: 'Động từ'"]
# --------------------
# Results for 'mệnh lệnh': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'niêm mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đảo ngược': ["category2: 'Động từ'"]
# --------------------
# Results for 'nguyên mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quân số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tham ô': ["category2: 'Động từ'"]
# --------------------
# Results for 'phi vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khâm phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'lây truyền': ["category2: 'Động từ'"]
# --------------------
# Results for 'từ ngữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phá thai': ["category2: 'Động từ'"]
# --------------------
# Results for 'tung lưới': []
# --------------------
# Results for 'lâm thời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoà nhạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'quả thật': []
# --------------------
# Results for 'xoá sổ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạm biệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'chi cục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ lạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chung thuỷ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hồ hởi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tướng lĩnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà sàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đau buồn': []
# --------------------
# Results for 'lớn tiếng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cây gỗ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đào hoa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cán cân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh thắng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gay cấn': []
# --------------------
# Results for 'chiết xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'dính líu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhức nhối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá chép': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xe tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sáng mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giúp sức': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xử lí': ["category2: 'Động từ'"]
# --------------------
# Results for 'ầm ĩ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàng hôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thừa hưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'thợ săn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhạc sỹ': []
# --------------------
# Results for 'ghen tị': ["category2: 'Động từ'"]
# --------------------
# Results for 'thị trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thô sơ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phút giây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lơ lửng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ngoại trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mê mẩn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nối liền': ["category2: 'Động từ'"]
# --------------------
# Results for 'linh mục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tận tay': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiên tài': []
# --------------------
# Results for 'mạn tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khởi tranh': ["category2: 'Động từ'"]
# --------------------
# Results for 'chung chung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nữ thần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá ngừ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá cố': ["category2: 'Động từ'"]
# --------------------
# Results for 'có giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nóng hổi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mấu chốt': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'toàn thắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hợp kim': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh hoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'qua ngày': []
# --------------------
# Results for 'định danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sinh nở': ["category2: 'Động từ'"]
# --------------------
# Results for 'phi đội': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tầm vóc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thẳng thừng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'siêu thanh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khiêu vũ': ["category2: 'Động từ'"]
# --------------------
# Results for 'ôn hoà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ra hiệu': ["category2: 'Động từ'"]
# --------------------
# Results for 'tinh gọn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tờ rơi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cồng kềnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ca từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất tận': ["category3: 'Tính từ'"]
# --------------------
# Results for 'quản lí': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thị hiếu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chủ mưu': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'sát thương': ["category2: 'Động từ'"]
# --------------------
# Results for 'ai ngờ': []
# --------------------
# Results for 'kỳ thị': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ tuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'bắp cải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lấn sân': ["category2: 'Động từ'"]
# --------------------
# Results for 'đánh lừa': ["category2: 'Động từ'"]
# --------------------
# Results for 'điêu luyện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xuyên tạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'chết đuối': ["category2: 'Động từ'"]
# --------------------
# Results for 'vốn dĩ': []
# --------------------
# Results for 'hộp đen': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đình công': ["category2: 'Động từ'"]
# --------------------
# Results for 'kết cục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuật toán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà sư': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhất thời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cờ vua': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sảng khoái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trông coi': ["category2: 'Động từ'"]
# --------------------
# Results for 'cộng hoà': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'điên rồ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vang dội': ["category2: 'Động từ'"]
# --------------------
# Results for 'mất trắng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bóng dáng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hung hăng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghẹt thở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lơ là': ["category2: 'Động từ'"]
# --------------------
# Results for 'đặt cược': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà kính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thông dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiến sỹ': []
# --------------------
# Results for 'thật ra': []
# --------------------
# Results for 'hùng hậu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ôn tập': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặt trăng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rau sạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'duyên hải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tốt bụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chật hẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thán phục': ["category2: 'Động từ'"]
# --------------------
# Results for 'kính trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'hỏi han': ["category2: 'Động từ'"]
# --------------------
# Results for 'tá hoả': ["category2: 'Động từ'"]
# --------------------
# Results for 'tạm bợ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chế phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quy đổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'máy giặt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm phiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'nói xấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'trước bạ': ["category2: 'Động từ'"]
# --------------------
# Results for 'xuất xưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sửng sốt': ["category2: 'Động từ'"]
# --------------------
# Results for 'lương y': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tái lập': ["category2: 'Động từ'"]
# --------------------
# Results for 'than phiền': ["category2: 'Động từ'"]
# --------------------
# Results for 'liều lượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kỳ thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'náo loạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghỉ mát': ["category2: 'Động từ'"]
# --------------------
# Results for 'treo giò': ["category2: 'Động từ'"]
# --------------------
# Results for 'lữ đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thất lạc': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngẫu hứng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xuất cảnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'xung kích': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nội tâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phô mai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'luật lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lỗi lầm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đáng giá': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cục diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thế kỉ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tội nghiệp': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nhân phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cấp phát': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoá dầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giao bóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'cao cả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thoả hiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăm chú': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dấu hỏi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay trong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'toạ độ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'á hậu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đen tối': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ăn hàng': ["category2: 'Động từ'"]
# --------------------
# Results for 'đào thải': ["category2: 'Động từ'"]
# --------------------
# Results for 'tường trình': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngoại thất': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dở dang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoàn vũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạt hình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ra mặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'của cải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiên tri': ["category2: 'Động từ'"]
# --------------------
# Results for 'khẩu vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'bệnh tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công ích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'viện phí': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tiếng động': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhỏ nhắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bất tiện': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắc thái': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thiếu gia': []
# --------------------
# Results for 'say đắm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầy ắp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bình thản': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hối tiếc': ["category2: 'Động từ'"]
# --------------------
# Results for 'cụ già': []
# --------------------
# Results for 'hô hoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'thanh lọc': ["category2: 'Động từ'"]
# --------------------
# Results for 'dáng vẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tinh khiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'miễn nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'đổi đời': ["category2: 'Động từ'"]
# --------------------
# Results for 'phân khu': []
# --------------------
# Results for 'bùn đất': []
# --------------------
# Results for 'xa lộ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'triết học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'kiểu mẫu': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'duy tu': ["category2: 'Động từ'"]
# --------------------
# Results for 'nghiệp dư': ["category3: 'Tính từ'"]
# --------------------
# Results for 'địa chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thật thà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phạm pháp': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhọc nhằn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cám dỗ': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhà kho': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ân hận': ["category2: 'Động từ'"]
# --------------------
# Results for 'choáng ngợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'toan tính': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'băng rôn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiểm hoạ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trang lứa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đơn độc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chữ viết': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phản diện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dễ dãi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuẩn hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'che chở': ["category2: 'Động từ'"]
# --------------------
# Results for 'lặn lội': ["category2: 'Động từ'"]
# --------------------
# Results for 'trọn gói': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hàng quán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lâm tặc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thị giác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trận địa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'suy đoán': ["category2: 'Động từ'"]
# --------------------
# Results for 'ngon lành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lâm sản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mê tín': ["category2: 'Động từ'"]
# --------------------
# Results for 'quả quyết': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'nguyên đơn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghèo nàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'diễn tả': ["category2: 'Động từ'"]
# --------------------
# Results for 'tươi sống': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hoà đồng': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'vô nghĩa': ["category3: 'Tính từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'hâm nóng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nước lọc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sặc sỡ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'vẻ vang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thầm lặng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hy hữu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bạc hà': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cứu vãn': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều lệ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồi bại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chiến tuyến': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dù sao': []
# --------------------
# Results for 'chiều chuộng': ["category2: 'Động từ'"]
# --------------------
# Results for 'quang học': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chen lấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'sao Hoả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tàn nhẫn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'súng ngắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hàng ngũ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bánh tráng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiển nhiên': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tán tỉnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'bốc hơi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tu sửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự tạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hứng khởi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'con riêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tư lệnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đói nghèo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'ẩm ướt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mang tiếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'quan họ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bộ não': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phế thải': []
# --------------------
# Results for 'đón chào': ["category2: 'Động từ'"]
# --------------------
# Results for 'yếu ớt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hạch toán': ["category2: 'Động từ'"]
# --------------------
# Results for 'cử động': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tiền thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vệ sĩ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ân cần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'náo nhiệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thiểu số': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hiếu kỳ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đồng ruộng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hơi nước': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự trọng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trôi nổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'hân hoan': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bao che': ["category2: 'Động từ'"]
# --------------------
# Results for 'dinh thự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'du kích': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'tuyên thệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thành hình': ["category2: 'Động từ'"]
# --------------------
# Results for 'quây quần': ["category2: 'Động từ'"]
# --------------------
# Results for 'biển hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đãi ngộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'hàn gắn': ["category2: 'Động từ'"]
# --------------------
# Results for 'hồng ngoại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giảng đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hết lời': []
# --------------------
# Results for 'khốn khổ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cung cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'quân chính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên biệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cấp tính': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phô trương': ["category2: 'Động từ'"]
# --------------------
# Results for 'đầy đặn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thấu đáo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đạn dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháo đài': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn giả': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đường sá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'lược dịch': ["category2: 'Động từ'"]
# --------------------
# Results for 'toàn phần': ["category3: 'Tính từ'"]
# --------------------
# Results for 'huyết mạch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quá đà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trao trả': ["category2: 'Động từ'"]
# --------------------
# Results for 'mấy ai': []
# --------------------
# Results for 'kình địch': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'trông đợi': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối ứng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sâu xa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nổi giận': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự truyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thời vụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cồng chiêng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trôi dạt': ["category2: 'Động từ'"]
# --------------------
# Results for 'biển Đông': []
# --------------------
# Results for 'luận án': ["category1: 'Danh từ'"]
# --------------------
# Results for 'làm tròn': ["category2: 'Động từ'"]
# --------------------
# Results for 'mặn nồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'không trung': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gánh vác': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiềm tàng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'băng đảng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khuynh hướng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cánh quạt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại tràng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uỷ thác': ["category2: 'Động từ'"]
# --------------------
# Results for 'sầm uất': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lệ thuộc': ["category2: 'Động từ'"]
# --------------------
# Results for 'nồng nàn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kiêm nhiệm': ["category2: 'Động từ'"]
# --------------------
# Results for 'lồng tiếng': ["category2: 'Động từ'"]
# --------------------
# Results for 'nồng nặc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hạ du': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tế nhị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cầu xin': ["category2: 'Động từ'"]
# --------------------
# Results for 'khai tử': ["category2: 'Động từ'"]
# --------------------
# Results for 'thảm kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giác mạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cha đẻ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trợ giá': ["category2: 'Động từ'"]
# --------------------
# Results for 'lá chắn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đa chiều': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nghịch lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giám thị': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'phong tặng': ["category2: 'Động từ'"]
# --------------------
# Results for 'xưa nay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gõ cửa': ["category2: 'Động từ'"]
# --------------------
# Results for 'hiểm trở': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đặc xá': ["category2: 'Động từ'"]
# --------------------
# Results for 'cầm đồ': ["category2: 'Động từ'"]
# --------------------
# Results for 'tha hồ': []
# --------------------
# Results for 'đầu tàu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trốn tránh': ["category2: 'Động từ'"]
# --------------------
# Results for 'xa cách': ["category2: 'Động từ'"]
# --------------------
# Results for 'tiểu khu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngoại khoá': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổ trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sung túc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dẫn động': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn nói': ["category2: 'Động từ'"]
# --------------------
# Results for 'hút hồn': ["category2: 'Động từ'"]
# --------------------
# Results for 'dẻo dai': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đắc địa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tuỳ thân': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đậu phụ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gạo cội': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ao ước': ["category2: 'Động từ'"]
# --------------------
# Results for 'lương tâm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bạo động': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'chiết khấu': ["category2: 'Động từ'"]
# --------------------
# Results for 'xen lẫn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thân yêu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mỗi một': []
# --------------------
# Results for 'địa giới': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xen kẽ': ["category2: 'Động từ'"]
# --------------------
# Results for 'cung bậc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bất mãn': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'kém cạnh': ["category2: 'Động từ'"]
# --------------------
# Results for 'phanh phui': ["category2: 'Động từ'"]
# --------------------
# Results for 'đối kháng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bịa đặt': ["category2: 'Động từ'"]
# --------------------
# Results for 'thường dân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghị viện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thu chi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tái hợp': ["category2: 'Động từ'"]
# --------------------
# Results for 'dâm ô': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bãi tắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sốt rét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thanh bình': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sốt ruột': ["category2: 'Động từ'"]
# --------------------
# Results for 'khiếm thị': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thanh thản': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phù hiệu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hào hùng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lên men': ["category2: 'Động từ'"]
# --------------------
# Results for 'thể xác': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mỏng manh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'in ấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'thước đo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đền đáp': ["category2: 'Động từ'"]
# --------------------
# Results for 'truy sát': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuỷ triều': ["category1: 'Danh từ'"]
# --------------------
# Results for 'yểm trợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'thư pháp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bản làng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trẻ hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'điều luật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'xạ thủ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thuần tuý': ["category3: 'Tính từ'"]
# --------------------
# Results for 'xúc xích': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nhạy bén': ["category3: 'Tính từ'"]
# --------------------
# Results for 'làm thuốc': []
# --------------------
# Results for 'vi sinh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nhà tắm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thủ trưởng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'con bạc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'níu kéo': ["category2: 'Động từ'"]
# --------------------
# Results for 'bấp bênh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiến hoá': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồ cổ': []
# --------------------
# Results for 'thực quản': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tha thiết': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phạt góc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bao quát': ["category2: 'Động từ'"]
# --------------------
# Results for 'tự hành': ["category3: 'Tính từ'"]
# --------------------
# Results for 'phim truyện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'săn bắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'tử nạn': ["category2: 'Động từ'"]
# --------------------
# Results for 'tái ngộ': ["category2: 'Động từ'"]
# --------------------
# Results for 'day dứt': []
# --------------------
# Results for 'nghĩ lại': ["category2: 'Động từ'"]
# --------------------
# Results for 'gây mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'đàn hồi': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tỏ vẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chế xuất': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký tự': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình thù': ["category1: 'Danh từ'"]
# --------------------
# Results for 'pháp nhân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'găng tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đồng lòng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thành trì': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thu dọn': ["category2: 'Động từ'"]
# --------------------
# Results for 'sáng sủa': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thập phương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bài vở': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tổng quát': ["category2: 'Động từ'"]
# --------------------
# Results for 'đồi núi': []
# --------------------
# Results for 'lo toan': ["category2: 'Động từ'"]
# --------------------
# Results for 'cổ tay': ["category1: 'Danh từ'"]
# --------------------
# Results for 'sơ cấp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bao dung': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dân vận': ["category2: 'Động từ'"]
# --------------------
# ...
# Results for 'vỡ nợ': ["category2: 'Động từ'"]
# --------------------
# Results for 'kỉ lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'viếng thăm': ["category2: 'Động từ'"]
# --------------------
# Results for 'quê quán': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tình đầu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu đường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bồ câu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tận tâm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sâu đậm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tận tuỵ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cá cược': ["category2: 'Động từ'"]
# --------------------
# Results for 'hối hả': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đóng dấu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'văn bằng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rốt cuộc': []
# --------------------
# Results for 'ví von': ["category2: 'Động từ'"]
# --------------------
# Results for 'bành trướng': ["category2: 'Động từ'"]
# --------------------
# Results for 'ký tên': ["category2: 'Động từ'"]
# --------------------
# Results for 'mỉa mai': ["category2: 'Động từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'mải mê': ["category2: 'Động từ'"]
# --------------------
# Results for 'làm ngơ': ["category2: 'Động từ'"]
# --------------------
# Results for 'quân dụng': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'bằng lòng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bản tính': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tuyến giáp': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tự thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thống đốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tay phải': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đấu nối': []
# --------------------
# Results for 'tiếp tế': ["category2: 'Động từ'"]
# --------------------
# Results for 'chăn gối': ["category2: 'Động từ'"]
# --------------------
# Results for 'thủ quân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'công phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'gia cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đầu sách': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khử trùng': ["category2: 'Động từ'"]
# --------------------
# Results for 'trầm lắng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cột dọc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phá cách': ["category2: 'Động từ'"]
# --------------------
# Results for 'an thần': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô cảm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sinh sôi': ["category2: 'Động từ'"]
# --------------------
# Results for 'tái sinh': ["category2: 'Động từ'"]
# --------------------
# Results for 'dí dỏm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giàu sang': ["category3: 'Tính từ'"]
# --------------------
# Results for 'sắc tộc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khấu trừ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chín chắn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'buôn người': []
# --------------------
# Results for 'vòng vây': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tâm thế': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần linh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tác phong': ["category1: 'Danh từ'"]
# --------------------
# Results for 'duyệt binh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sang tên': ["category2: 'Động từ'"]
# --------------------
# Results for 'cố đô': ["category1: 'Danh từ'"]
# --------------------
# Results for 'mũi tên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'danh xưng': []
# --------------------
# Results for 'rườm rà': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tỉnh uỷ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'miễn là': []
# --------------------
# Results for 'điên cuồng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hướng nghiệp': ["category2: 'Động từ'"]
# --------------------
# Results for 'trung tuần': ["category1: 'Danh từ'"]
# --------------------
# Results for 'viên mãn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhạc kịch': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giường nằm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'giờ phút': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thần dược': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thực dụng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cộng hưởng': []
# --------------------
# Results for 'vũ trường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chống đỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'rung chuyển': ["category2: 'Động từ'"]
# --------------------
# Results for 'lao đao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà ăn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'uy lực': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bực tức': ["category2: 'Động từ'"]
# --------------------
# Results for 'hẻo lánh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trả góp': ["category2: 'Động từ'"]
# --------------------
# Results for 'thuốc men': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thô bạo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bản gốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hộ vệ': ["category2: 'Động từ'"]
# --------------------
# Results for 'dự thầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'thương thảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'khô hạn': ["category3: 'Tính từ'"]
# --------------------
# Results for 'giải nhiệt': ["category2: 'Động từ'"]
# --------------------
# Results for 'vô danh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'cứng nhắc': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mỹ nữ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cây thuốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phán xét': ["category2: 'Động từ'"]
# --------------------
# Results for 'tù binh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngôn từ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nguyên tố': ["category1: 'Danh từ'"]
# --------------------
# Results for 'gây hấn': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ toạ': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tí hon': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tái phạm': ["category2: 'Động từ'"]
# --------------------
# Results for 'bảo mẫu': ["category1: 'Danh từ'"]
# --------------------
# Results for 'âu yếm': []
# --------------------
# Results for 'phơi bày': ["category2: 'Động từ'"]
# --------------------
# Results for 'ghi danh': ["category2: 'Động từ'"]
# --------------------
# Results for 'sà lan': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hai mươi': []
# --------------------
# Results for 'bàn thảo': ["category2: 'Động từ'"]
# --------------------
# Results for 'nhân thân': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trưng cầu': ["category2: 'Động từ'"]
# --------------------
# Results for 'bình minh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phục dựng': ["category2: 'Động từ'"]
# --------------------
# Results for 'phán xử': ["category2: 'Động từ'"]
# --------------------
# Results for 'để mắt': ["category2: 'Động từ'"]
# --------------------
# Results for 'hụt hẫng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'dành dụm': ["category2: 'Động từ'"]
# --------------------
# Results for 'thắng cảnh': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trụ trì': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'hiếu học': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tiêu xài': ["category2: 'Động từ'"]
# --------------------
# Results for 'hạn hẹp': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thơ ấu': ["category3: 'Tính từ'"]
# --------------------
# Results for 'lợi hại': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'ngất ngưởng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhẹ nhõm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'hướng dương': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nỗi niềm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hóm hỉnh': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà thuốc': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tặng thưởng': ["category2: 'Động từ'"]
# --------------------
# Results for 'sơ sài': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đá vôi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'dầu mỡ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đại lục': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bủa vây': ["category2: 'Động từ'"]
# --------------------
# Results for 'buồn ngủ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'chuyển mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'lấn át': ["category2: 'Động từ'"]
# --------------------
# Results for 'lẫn lộn': ["category2: 'Động từ'"]
# --------------------
# Results for 'đau xót': ["category3: 'Tính từ'"]
# --------------------
# Results for 'trong trẻo': ["category3: 'Tính từ'"]
# --------------------
# Results for 'bài trí': ["category2: 'Động từ'"]
# --------------------
# Results for 'nội quy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tính tình': ["category1: 'Danh từ'"]
# --------------------
# Results for 'vật phẩm': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nghịch ngợm': ["category3: 'Tính từ'"]
# --------------------
# Results for 'mổ xẻ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chống phá': ["category2: 'Động từ'"]
# --------------------
# Results for 'sự tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nan giải': ["category3: 'Tính từ'"]
# --------------------
# Results for 'kế vị': ["category2: 'Động từ'"]
# --------------------
# Results for 'sân thượng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đệ trình': ["category2: 'Động từ'"]
# --------------------
# Results for 'hết mực': []
# --------------------
# Results for 'liên đoàn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phiên dịch': ["category2: 'Động từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'tận cùng': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'thoát thân': ["category2: 'Động từ'"]
# --------------------
# Results for 'trực tràng': ["category1: 'Danh từ'"]
# --------------------
# Results for 'nước bọt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hình tròn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đạo lý': ["category1: 'Danh từ'"]
# --------------------
# Results for 'rùng mình': ["category2: 'Động từ'"]
# --------------------
# Results for 'tinh thể': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chinh chiến': ["category2: 'Động từ'"]
# --------------------
# Results for 'cách điệu': []
# --------------------
# Results for 'ngà voi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phân đoạn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'quý mến': ["category2: 'Động từ'"]
# --------------------
# Results for 'váy áo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngán ngẩm': ["category2: 'Động từ'"]
# --------------------
# Results for 'xua đuổi': ["category2: 'Động từ'"]
# --------------------
# Results for 'ăn xin': ["category2: 'Động từ'"]
# --------------------
# Results for 'đệ tử': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chồng chất': ["category2: 'Động từ'"]
# --------------------
# Results for 'điểm tựa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cầu mong': ["category2: 'Động từ'"]
# --------------------
# Results for 'đất sét': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngại ngần': ["category2: 'Động từ'"]
# --------------------
# Results for 'gạch đá': []
# --------------------
# Results for 'phiền toái': ["category3: 'Tính từ'"]
# --------------------
# Results for 'tình duyên': ["category1: 'Danh từ'"]
# --------------------
# Results for 'ngồi tù': ["category2: 'Động từ'"]
# --------------------
# Results for 'xa vời': ["category3: 'Tính từ'"]
# --------------------
# Results for 'nhà băng': ["category1: 'Danh từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'ngang bằng': []
# --------------------
# Results for 'lòng sông': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chuyên cơ': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chỉnh đốn': ["category2: 'Động từ'"]
# --------------------
# Results for 'giao nộp': ["category2: 'Động từ'"]
# --------------------
# Results for 'chủ nghĩa': ["category1: 'Danh từ'"]
# --------------------
# Results for 'việt vị': ["category1: 'Danh từ'"]
# --------------------
# Results for 'chiến tích': ["category1: 'Danh từ'"]
# --------------------
# Results for 'diễn văn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khai hoả': ["category2: 'Động từ'"]
# --------------------
# Results for 'gắt gao': ["category3: 'Tính từ'"]
# --------------------
# Results for 'người người': ["category1: 'Danh từ'"]
# --------------------
# Results for 'đàn áp': ["category2: 'Động từ'"]
# --------------------
# Results for 'hoàng kim': ["category1: 'Danh từ'"]
# --------------------
# Results for 'cá heo': ["category1: 'Danh từ'"]
# --------------------
# Results for 'bỡ ngỡ': []
# --------------------
# Results for 'lép vế': ["category3: 'Tính từ'"]
# --------------------
# Results for 'biến tướng': ["category3: 'Tính từ'", "category1: 'Danh từ'"]
# --------------------
# Results for 'nốt ruồi': ["category1: 'Danh từ'"]
# --------------------
# Results for 'la liệt': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thuốc phiện': ["category1: 'Danh từ'"]
# --------------------
# Results for 'trung lập': ["category3: 'Tính từ'"]
# --------------------
# Results for 'đường mòn': ["category1: 'Danh từ'"]
# --------------------
# Results for 'long trọng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thảm hại': ["category3: 'Tính từ'"]
# --------------------
# Results for 'thăng hạng': ["category2: 'Động từ'"]
# --------------------
# Results for 'bán tháo': ["category2: 'Động từ'"]
# --------------------
# Results for 'trì trệ': ["category3: 'Tính từ'"]
# --------------------
# Results for 'công đức': ["category1: 'Danh từ'"]
# --------------------
# Results for 'khu biệt': []
# --------------------
# Results for 'mẫu mực': ["category1: 'Danh từ'", "category3: 'Tính từ'"]
# --------------------
# Results for 'bỏ ngỏ': ["category2: 'Động từ'"]
# --------------------
# Results for 'chen chúc': ["category2: 'Động từ'"]
# --------------------
# Results for 'bột ngọt': ["category1: 'Danh từ'"]
# --------------------
# Results for 'u h': []
# --------------------
# Results for 'ảo thuật': ["category1: 'Danh từ'"]
# --------------------
# Results for 'thích đáng': ["category3: 'Tính từ'"]
# --------------------
# Results for 'khí thế': []
# --------------------
# Results for 'cọ xát': ["category2: 'Động từ'"]
# --------------------
# Results for 'suy ngẫm': ["category2: 'Động từ'"]
# --------------------
# Results for 'nâng đỡ': ["category2: 'Động từ'"]
# --------------------
# Results for 'đòn bẩy': ["category1: 'Danh từ'"]
# --------------------
# Results for 'phố phường': ["category1: 'Danh từ'"]
# --------------------
# Results for 'hoạ sỹ': []
# --------------------
# Results for 'ngọc trai': ["category1: 'Danh từ'"]
# --------------------
# Results for 'tử tù': ["category1: 'Danh từ'"]
# --------------------
# Final results have been saved to 4000word.json
